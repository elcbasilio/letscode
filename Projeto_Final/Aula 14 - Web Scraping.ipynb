# %% [markdown]
# # Web Scraping
#
# Execute o comando `pip install bs4` para instalar o pacote beautiful soup, a biblioteca que faz o parse e nos ajuda a navegar dentro das tags HTML.

# %%
from bs4 import BeautifulSoup

html_doc = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

soup = BeautifulSoup(html_doc, 'html.parser')
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %%
soup.title
# Out:
# <title>The Dormouse's story</title>

# %%
soup.title.name
# Out:
# 'title'

# %%
soup.title.text
# Out:
# "The Dormouse's story"

# %%
soup.title.parent.name
# Out:
# 'head'

# %%
soup.p
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %%
soup.find_all('p')
# Out:
# [<p class="title"><b>The Dormouse's story</b></p>,
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>,
#  <p class="story">...</p>]

# %%
soup.p['class']
# Out:
# ['title']

# %%
soup.a
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
soup.find_all('a')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.find(id="link3")
# Out:
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %%
soup.find('a', {'id': 'link3'})
# Out:
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %% [markdown]
# ## Usando Requests

# %%
import requests
from bs4 import BeautifulSoup

riot_articles = []

# Buscando a página da Riot Games
page = requests.get('https://technology.riotgames.com/')
# Criar o objeto BeautifulSoup
soup = BeautifulSoup(page.text, 'html.parser')

# %%
page.text
# Out:
# '<!DOCTYPE html>\n<!--[if IEMobile 7]><html class="iem7"  lang="en" dir="ltr"><![endif]-->\n<!--[if lte IE 6]><html class="lt-ie9 lt-ie8 lt-ie7"  lang="en" dir="ltr"><![endif]-->\n<!--[if (IE 7)&(!IEMobile)]><html class="lt-ie9 lt-ie8"  lang="en" dir="ltr"><![endif]-->\n<!--[if IE 8]><html class="lt-ie9"  lang="en" dir="ltr"><![endif]-->\n<!--[if (gte IE 9)|(gt IEMobile 7)]><!--><html lang="en" dir="ltr" prefix="content: http://purl.org/rss/1.0/modules/content/ dc: http://purl.org/dc/terms/ foaf: http://xmlns.com/foaf/0.1/ og: http://ogp.me/ns# rdfs: http://www.w3.org/2000/01/rdf-schema# sioc: http://rdfs.org/sioc/ns# sioct: http://rdfs.org/sioc/types# skos: http://www.w3.org/2004/02/skos/core# xsd: http://www.w3.org/2001/XMLSchema#"><!--<![endif]-->\n<head>\n<meta charset="utf-8" /><script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={licenseKey:"25a156d569",applicationID:"7806507"};window.NREUM||(NREUM={}),__nr_require=function(e,n,t){function r(t){if(!n[t]){var o=n[t]={exports:{}};e[t][0].call(o.exports,function(n){var o=e[t][1][n];return r(o||n)},o,o.exports)}return n[t].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<t.length;o++)r(t[o]);return r}({1:[function(e,n,t){function r(){}function o(e,n,t){return function(){return i(e,[c.now()].concat(u(arguments)),n?null:this,t),n?void 0:this}}var i=e("handle"),a=e(3),u=e(4),f=e("ee").get("tracer"),c=e("loader"),s=NREUM;"undefined"==typeof window.newrelic&&(newrelic=s);var p=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],d="api-",l=d+"ixn-";a(p,function(e,n){s[n]=o(d+n,!0,"api")}),s.addPageAction=o(d+"addPageAction",!0),s.setCurrentRouteName=o(d+"routeName",!0),n.exports=newrelic,s.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(e,n){var t={},r=this,o="function"==typeof n;return i(l+"tracer",[c.now(),e,t],r),function(){if(f.emit((o?"":"no-")+"fn-start",[c.now(),r,o],t),o)try{return n.apply(this,arguments)}catch(e){throw f.emit("fn-err",[arguments,this,e],t),e}finally{f.emit("fn-end",[c.now()],t)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(e,n){m[n]=o(l+n)}),newrelic.noticeError=function(e,n){"string"==typeof e&&(e=new Error(e)),i("err",[e,c.now(),!1,n])}},{}],2:[function(e,n,t){function r(e,n){if(!o)return!1;if(e!==o)return!1;if(!n)return!0;if(!i)return!1;for(var t=i.split("."),r=n.split("."),a=0;a<r.length;a++)if(r[a]!==t[a])return!1;return!0}var o=null,i=null,a=/Version\\/(\\S+)\\s+Safari/;if(navigator.userAgent){var u=navigator.userAgent,f=u.match(a);f&&u.indexOf("Chrome")===-1&&u.indexOf("Chromium")===-1&&(o="Safari",i=f[1])}n.exports={agent:o,version:i,match:r}},{}],3:[function(e,n,t){function r(e,n){var t=[],r="",i=0;for(r in e)o.call(e,r)&&(t[i]=n(r,e[r]),i+=1);return t}var o=Object.prototype.hasOwnProperty;n.exports=r},{}],4:[function(e,n,t){function r(e,n,t){n||(n=0),"undefined"==typeof t&&(t=e?e.length:0);for(var r=-1,o=t-n||0,i=Array(o<0?0:o);++r<o;)i[r]=e[n+r];return i}n.exports=r},{}],5:[function(e,n,t){n.exports={exists:"undefined"!=typeof window.performance&&window.performance.timing&&"undefined"!=typeof window.performance.timing.navigationStart}},{}],ee:[function(e,n,t){function r(){}function o(e){function n(e){return e&&e instanceof r?e:e?f(e,u,i):i()}function t(t,r,o,i){if(!d.aborted||i){e&&e(t,r,o);for(var a=n(o),u=v(t),f=u.length,c=0;c<f;c++)u[c].apply(a,r);var p=s[y[t]];return p&&p.push([b,t,r,a]),a}}function l(e,n){h[e]=v(e).concat(n)}function m(e,n){var t=h[e];if(t)for(var r=0;r<t.length;r++)t[r]===n&&t.splice(r,1)}function v(e){return h[e]||[]}function g(e){return p[e]=p[e]||o(t)}function w(e,n){c(e,function(e,t){n=n||"feature",y[t]=n,n in s||(s[n]=[])})}var h={},y={},b={on:l,addEventListener:l,removeEventListener:m,emit:t,get:g,listeners:v,context:n,buffer:w,abort:a,aborted:!1};return b}function i(){return new r}function a(){(s.api||s.feature)&&(d.aborted=!0, ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if IEMobile 7]><html class="iem7"  lang="en" dir="ltr"><![endif]-->
# <!--[if lte IE 6]><html class="lt-ie9 lt-ie8 lt-ie7"  lang="en" dir="ltr"><![endif]-->
# <!--[if (IE 7)&(!IEMobile)]><html class="lt-ie9 lt-ie8"  lang="en" dir="ltr"><![endif]-->
# <!--[if IE 8]><html class="lt-ie9"  lang="en" dir="ltr"><![endif]-->
# <!--[if (gte IE 9)|(gt IEMobile 7)]><!-->
# <html dir="ltr" lang="en" prefix="content: http://purl.org/rss/1.0/modules/content/ dc: http://purl.org/dc/terms/ foaf: http://xmlns.com/foaf/0.1/ og: http://ogp.me/ns# rdfs: http://www.w3.org/2000/01/rdf-schema# sioc: http://rdfs.org/sioc/ns# sioct: http://rdfs.org/sioc/types# skos: http://www.w3.org/2004/02/skos/core# xsd: http://www.w3.org/2001/XMLSchema#">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <script type="text/javascript">
#    (window.NREUM||(NREUM={})).loader_config={licenseKey:"25a156d569",applicationID:"7806507"};window.NREUM||(NREUM={}),__nr_require=function(e,n,t){function r(t){if(!n[t]){var o=n[t]={exports:{}};e[t][0].call(o.exports,function(n){var o=e[t][1][n];return r(o||n)},o,o.exports)}return n[t].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<t.length;o++)r(t[o]);return r}({1:[function(e,n,t){function r(){}function o(e,n,t){return function(){return i(e,[c.now()].concat(u(arguments)),n?null:this,t),n?void 0:this}}var i=e("handle"),a=e(3),u=e(4),f=e("ee").get("tracer"),c=e("loader"),s=NREUM;"undefined"==typeof window.newrelic&&(newrelic=s);var p=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],d="api-",l=d+"ixn-";a(p,function(e,n){s[n]=o(d+n,!0,"api")}),s.addPageAction=o(d+"addPageAction",!0),s.setCurrentRouteName=o(d+"routeName",!0),n.exports=newrelic,s.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(e,n){var t={},r=this,o="function"==typeof n;return i(l+"tracer",[c.now(),e,t],r),function(){if(f.emit((o?"":"no-")+"fn-start",[c.now(),r,o],t),o)try{return n.apply(this,arguments)}catch(e){throw f.emit("fn-err",[arguments,this,e],t),e}finally{f.emit("fn-end",[c.now()],t)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(e,n){m[n]=o(l+n)}),newrelic.noticeError=function(e,n){"string"==typeof e&&(e=new Error(e)),i("err",[e,c.now(),!1,n])}},{}],2:[function(e,n,t){function r(e,n){if(!o)return!1;if(e!==o)return!1;if(!n)return!0;if(!i)return!1;for(var t=i.split("."),r=n.split("."),a=0;a<r.length;a++)if(r[a]!==t[a])return!1;return!0}var o=null,i=null,a=/Version\/(\S+)\s+Safari/;if(navigator.userAgent){var u=navigator.userAgent,f=u.match(a);f&&u.indexOf("Chrome")===-1&&u.indexOf("Chromium")===-1&&(o="Safari",i=f[1])}n.exports={agent:o,version:i,match:r}},{}],3:[function(e,n,t){function r(e,n){var t=[],r="",i=0;for(r in e)o.call(e,r)&&(t[i]=n(r,e[r]),i+=1);return t}var o=Object.prototype.hasOwnProperty;n.exports=r},{}],4:[function(e,n,t){function r(e,n,t){n||(n=0),"undefined"==typeof t&&(t=e?e.length:0);for(var r=-1,o=t-n||0,i=Array(o<0?0:o);++r<o;)i[r]=e[n+r];return i}n.exports=r},{}],5:[function(e,n,t){n.exports={exists:"undefined"!=typeof window.performance&&window.performance.timing&&"undefined"!=typeof window.performance.timing.navigationStart}},{}],ee:[function(e,n,t){function r(){}function o(e){function n(e){return e&&e instanceof r?e:e?f(e,u,i):i()}function t(t,r,o,i){if(!d.aborted||i){e&&e(t,r,o);for(var a=n(o),u=v(t),f=u.length,c=0;c<f;c++)u[c].apply(a,r);var p=s[y[t]];return p&&p.push([b,t,r,a]),a}}function l(e,n){h[e]=v(e).concat(n)}function m(e,n){var t=h[e];if(t)for(var r=0;r<t.length;r++)t[r]===n&&t.splice(r,1)}function v(e){return h[e]||[]}function g(e){return p[e]=p[e]||o(t)}function w(e,n){c(e,function(e,t){n=n||"feature",y[t]=n,n in s||(s[n]=[])})}var h={},y={},b={on:l,addEventListener:l,removeEventListener:m,emit:t,get:g,listeners:v,context:n,buffer:w,abort:a,aborted:!1};return b}function i(){return new r}function a(){(s.api||s.feature)&&(d.aborted=!0,s=d.backlog={})}var u="nr@context",f=e("gos"),c=e(3),s={},p={},d=n.exports=o();d.backlog=s},{}],gos:[function(e,n,t){function r(e,n,t){if(o.call(e,n))return e[n];var r=t();if(Object.defineProperty&&Object.keys)try{return Object.defineProperty(e,n,{value:r,writable:!0,enumerable:!1}),r}catch(i){}return e[n]=r,r}var o=Object.prototype.hasOwnProperty;n.exports=r},{}],handle:[function(e,n,t){function r(e,n,t,r){o.buffer([e],r),o.emit(e,n,t)}var o=e("ee").get("handle");n.exports=r,r.ee=o},{}],id:[function(e,n,t){function r(e){var n=typeof e;return!e||"object"!==n&&"function"!==n?-1:e===window?0:a(e,i,function(){return o++})}var o=1,i="nr@id",a=e("gos");n.exports=r},{}],loader:[function(e,n,t){function r(){if(!E++){var e=x.info=NREUM.info,n=l.getElementsByTagName("script")[0];if(setTimeout(s.abort,3e4),!(e&&e.licenseKey ...
#   </script>
#   <meta content="Drupal 7 (http://drupal.org)" name="Generator"/>
#   <link href="https://technology.riotgames.com/rss.xml" rel="alternate" title="Riot Games Technology RSS" type="application/rss+xml"/>
#   <link href="https://technology.riotgames.com/sites/default/files/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
#   <title>
#    Riot Games Technology
#   </title>
#   <meta content="What’s it like to be a part of Riot Tech? Explore everything from titles and personal development to tech challenges and philosophies." name="description"/>
#   <meta content="width" name="MobileOptimized"/>
#   <meta content="true" name="HandheldFriendly"/>
#   <meta content="width=device-width" name="viewport"/>
#   <meta content="on" http-equiv="cleartype"/>
#   <meta content="The Riot Games Tech Blog" property="og:title">
#    <meta content="website" property="og:type">
#     <meta content="http://technology.riotgames.com/" property="og:url">
#      <meta content="http://technology.riotgames.com/sites/all/themes/riot_games_engineering/images/share/riot_share_1024x1024.jpg" property="og:image">
#       <meta content="What’s it like to be a part of Riot Tech? Explore everything from titles and personal development to tech challenges and philosophies." property="og:description">
#        <link href="/sites/all/themes/riot_games_engineering/images/icons/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
#        <link href="/sites/all/themes/riot_games_engineering/images/icons/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
#        <link href="/sites/all/themes/riot_games_engineering/images/icons/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#        <link href="/sites/all/themes/riot_games_engineering/images/icons/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
#        <link href="/sites/all/themes/riot_games_engineering/images/icons/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#        <link href="/sites/all/themes/riot_games_engineering/images/icons/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#        <link href="/sites/all/themes/riot_games_engineering/images/icons/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
#        <link href="/sites/all/themes/riot_games_engineering/images/icons/apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#        <link href="/sites/all/themes/riot_games_engineering/images/icons/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
#        <link href="/sites/all/themes/riot_games_engineering/images/icons/android-icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
#        <link href="/sites/all/themes/riot_games_engineering/images/icons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#        <link href="/sites/all/themes/riot_games_engineering/images/icons/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
#        <link href="/sites/all/themes/riot_games_engineering/images/icons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#        <link href="/sites/all/themes/riot_games_engineering/images/icons/manifest.json" rel="manifest"/>
#        <meta content="#ffffff" name="msapplication-TileColor"/>
#        <meta content="/sites/all/themes/riot_games_engineering/images/icons/ms-icon-144x144.png" name="msapplication-TileImage"/>
#        <meta content="#ffffff" name="theme-color"/>
#        <link href="//use.typekit.net" rel="dns-prefetch"/>
#        <link href="//connect.facebook.net" rel="dns-prefetch"/>
#        <link href="//platform.linkedin.com" rel="dns-prefetch"/>
#        <link href="//fast.fonts.net" rel="dns-prefetch"/>
#        <link href="https://technology.riotgames.com/sites/default/files/css/css_rEI_5cK_B9hB4So2yZUtr5weuEV3heuAllCDE6XsIkI.css" media="all" rel="stylesheet" type="text/css">
#         <link href="https://technology.riotgames.com/sites/default/files/css/css_y8Lc50-poLV7IkeZhymHAJosNFjQWQ8eoqw_J7PKqKQ.css" media="all" rel="stylesheet" type="text/css">
#          <link href="https://technology.riotgames.com/sites/default/files/css/css_ku0l2qaoDIWuvn_GC8yjVDMK2TXBYNLutjZyiWz65Lg.css" media="all" rel="stylesheet" type="text/css">
#           <style>
#            .c-header--page {
#             clip-path: url(#clippath);
#             -webkit-clip-path: polygon(50% 0%, 100% 0, 100% 92%, 50% 100%, 50% 100%, 0 92%, 0 0);
#             clip-path: polygon(50% 0%, 100% 0, 100% 92%, 50% 100%, 50% 100%, 0 92%, 0 0);
#         }
#
#         @media (min-width: 768px) {
#
#             .c-header--page {
#                 clip-path: url(#clippath-sm);
#                 -webkit-clip-path: polygon(50% 0%, 100% 0, 100% 88%, 50% 100%, 50% 100%, 0 88%, 0 0);
#                 clip-path: polygon(50% 0%, 100% 0, 100% 88%, 50% 100%, 50% 100%, 0 88%, 0 0);
#             }
#
#         }
#
#         @media (min-width: 1200px) {
#
#             .c-header--page {
#                 clip-path: url(#clippath-lg);
#                 -webkit-clip-path: polygon(50% 0%, 100% 0, 100% 84%, 50% 100%, 50% 100%, 0 84%, 0 0);
#                 clip-path: polygon(50% 0%, 100% 0, 100% 84%, 50% 100%, 50% 100%, 0 84%, 0 0);
#             }
#
#         }
#
#         @media (min-width: 1500px) {
#
#             .c-header--page {
#                 clip-path: url(#clippath-xl);
#                 -webkit-clip-path: polygon(50% 0%, 100% 0, 100% 80%, 50% 100%, 50% 100%, 0 80%, 0 0);
#                 clip-path: polygon(50% 0%, 100% 0, 100% 80%, 50% 100%, 50% 100%, 0 80%, 0 0);
#             }
#
#         }
#
#         @media (min-width: 1600px) {
#
#             .c-header--page {
#                 clip-path: url(#clippath-cxl);
#                 -webkit-clip-path: polygon(50% 0%, 100% 0, 100% 78%, 50% 100%, 50% 100%, 0 78%, 0 0);
#                 clip-path: polygon(50% 0%, 100% 0, 100% 78%, 50% 100%, 50% 100%, 0 78%, 0 0);
#             }
#
#         }
#           </style>
#           <!--[if lte IE 9]>
#         <style type="text/css">
#
#             .c-header--page:before {
#                 background: url("/sites/all/themes/riot_games_engineering/images/header-overlay-ie-bottom.png") center bottom repeat-x;
#                 bottom: -50px;
#             }
#
#             .c-header__overlay {
#                 display: block;
#                 position: absolute;
#                 bottom: 0;
#                 width: 100%;
#                 height: auto;
#                 margin-bottom: 0;
#             }
#
#             .c-header-typed {
#                 max-width: 390px;
#                 width: 390px;
#             }
#
#             .page-404 .c-header-typed  {
#                 max-width: 160px;
#                 width: 160px;
#             }
#
#             .c-header-typed:before, .c-header-typed:after {
#                 opacity: 1;
#             }
#
#             .c-header-typed .typed-cursor {
#                 visibility: hidden;
#             }
#
#         </style>
#     <![endif]-->
#           <!--[if lt IE 9]>
#             <script src="/sites/all/themes/zen/js/html5-respond.js"></script>
#         <![endif]-->
#          </link>
#         </link>
#        </link>
#       </meta>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body class="html front not-logged-in one-sidebar sidebar-first page-node">
#   <noscript>
#    <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-KWJH" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-KWJH');
#   </script>
#   <script>
#    window.fbAsyncInit = function() {
#             FB.init({
#                 appId      : '505056592980080',
#                 xfbml      : true,
#                 version    : 'v2.4'
#             });
#         };
#
#         (function(d, s, id){
#             var js, fjs = d.getElementsByTagName(s)[0];
#             if (d.getElementById(id)) {return;}
#             js = d.createElement(s); js.id = id;
#             js.src = "//connect.facebook.net/en_US/sdk.js";
#             fjs.parentNode.insertBefore(js, fjs);
#         }(document, 'script', 'facebook-jssdk'));
#   </script>
#   <p id="skip-link">
#    <a class="element-invisible element-focusable" href="#main-menu">
#     Jump to navigation
#    </a>
#   </p>
#   <div class="c-mobile-menu js-mobile-menu">
#    <div class="c-mobile-menu__header">
#     <div class="c-mobile-menu__search">
#      <form action="/search" class="c-search-drawer__form">
#       <div class="c-form-group c-mobile-menu__from-group">
#        <input class="c-mobile-menu__input c-form-group__input" name="search" placeholder="Search..." type="text" value=""/>
#       </div>
#       <button class="c-mobile-menu__search-btn" type="submit">
#        <i class="c-icon--search">
#        </i>
#       </button>
#      </form>
#     </div>
#    </div>
#    <a class="c-mobile-menu__close js-mobile-menu-toggle" href="">
#     <i class="c-icon--cancel">
#     </i>
#    </a>
#    <ul class="o-list-unstyled c-mobile-menu__list">
#     <li class="c-mobile-menu__item">
#      <a class="c-mobile-menu__link" href="http://www.riotgames.com/riot-manifesto" target="_blank" title="Riots Games - Our Story">
#       <span>
#        Our Story
#       </span>
#      </a>
#     </li>
#     <li class="c-mobile-menu__item c-mobile-menu__item--bg3">
#      <a class="c-mobile-menu__link" href="https://www.riotgames.com/work-with-us/disciplines/engineering" target="_blank" title="Search open jobs at Riot Games">
#       <span>
#        Careers
#       </span>
#      </a>
#     </li>
#     <li class="c-mobile-menu__item c-mobile-menu__item--bg2">
#      <a class="c-mobile-menu__link" href="http://www.riotgames.com/our-games" target="_blank" title="Our Games">
#       <span>
#        Games
#       </span>
#      </a>
#     </li>
#     <li class="c-mobile-menu__item">
#      <a class="c-mobile-menu__link" href="http://www.riotgames.com/news" target="_blank" title="Riot News">
#       <span>
#        News
#       </span>
#      </a>
#     </li>
#    </ul>
#    <a class="c-btn c-btn--primary c-btn--small c-btn--transparent c-btn--white c-mobile-menu__riot" href="http://www.riotgames.com/">
#     Riotgames.com
#     <i class="c-icon c-icon--angle-right">
#     </i>
#    </a>
#   </div>
#   <div class="o-container c-nav">
#    <nav class="c-nav__inner" role="navigation">
#     <a class="c-nav__logo-link" href="/" title="Riot Games Tech">
#      <h1 class="c-nav__site-title">
#       <img class="c-nav__logo" src="/sites/all/themes/riot_games_engineering/images/logo-fist-white.png"/>
#       <span class="c-nav__title">
#        Riot Games
#       </span>
#      </h1>
#     </a>
#     <ul class="o-list-unstyled c-nav__list">
#      <li class="c-nav__item">
#       <a class="c-nav__link" href="http://www.riotgames.com/riot-manifesto" target="_blank" title="Riots Games - Our Story">
#        Our Story
#       </a>
#      </li>
#      <li class="c-nav__item">
#       <a class="c-nav__link" href="https://www.riotgames.com/work-with-us/disciplines/engineering" target="_blank" title="Search open jobs at Riot Games">
#        Careers
#       </a>
#      </li>
#      <li class="c-nav__item">
#       <a class="c-nav__link" href="http://www.riotgames.com/our-games" target="_blank" title="Our Games">
#        Games
#       </a>
#      </li>
#      <li class="c-nav__item">
#       <a class="c-nav__link" href="http://www.riotgames.com/news" target="_blank" title="Riot News">
#        News
#       </a>
#      </li>
#     </ul>
#     <a class="c-nav__link c-nav__ham-menu js-mobile-menu-toggle" href="">
#      <i class="c-icon--menu">
#      </i>
#     </a>
#    </nav>
#    <div class="c-nav__search c-search-drawer js-search-drawer">
#     <form action="/search" class="c-search-drawer__form">
#      <div class="c-form-group">
#       <input class="c-form-group__input c-search-drawer__input" name="search" placeholder="Search..." type="text" value=""/>
#      </div>
#     </form>
#    </div>
#   </div>
#   <svg class="c-svg">
#    <defs>
#     <clippath clippathunits="objectBoundingBox" id="clippath">
#      <polygon points="0,0 0,0.92 0.5,1 1,0.92 1,0">
#      </polygon>
#     </clippath>
#     <clippath clippathunits="objectBoundingBox" id="clippath-sm">
#      <polygon points="0,0 0,0.88 0.5,1 1,0.88 1,0">
#      </polygon>
#     </clippath>
#     <clippath clippathunits="objectBoundingBox" id="clippath-lg">
#      <polygon points="0,0 0,0.84 0.5,1 1,0.84 1,0">
#      </polygon>
#     </clippath>
#     <clippath clippathunits="objectBoundingBox" id="clippath-xl">
#      <polygon points="0,0 0,0.80 0.5,1 1,0.80 1,0">
#      </polygon>
#     </clippath>
#     <clippath clippathunits="objectBoundingBox" id="clippath-cxl">
#      <polygon points="0,0 0,0.78 0.5,1 1,0.78 1,0">
#      </polygon>
#     </clippath>
#    </defs>
#   </svg>
#   <header class="c-header c-header--page" role="banner" style="background: url(https://technology.riotgames.com/sites/default/files/theme/backgrounds/header_0.jpg) top center no-repeat; ">
#    <div class="c-header-typed js-typed-container">
#     <span class="c-header-typed__text js-typed" data-page="front">
#     </span>
#    </div>
#    <img class="c-header__overlay" src="/sites/all/themes/riot_games_engineering/images/header-overlay-ie.png"/>
#    <!--[if lte IE 9]>
#     <img src="/sites/all/themes/riot_games_engineering/images/header-overlay-ie.png" class="c-header__overlay" />
#     <![endif]-->
#   </header>
#   <div class="o-wrapper o-wrapper--main o-wrapper--page">
#    <div class="o-container o-container--content" id="content" role="main">
#     <div class="o-layout">
#      <div class="o-layout__item o-layout__item--content c-content">
#       <div class="view view-recent-news-articles view-id-recent_news_articles view-display-id-block view-dom-id-1e78c4ba60e49dc42521b1d3e444be71">
#        <div class="view-content c-excerpt__list">
#         <article class="c-excerpt views-row views-row-1 views-row-odd views-row-first" role="article">
#          <h1 class="c-excerpt__title">
#           <a href="/news/engineering-esports-tech-powers-worlds">
#            Engineering Esports: The Tech That Powers Worlds
#           </a>
#          </h1>
#          <a href="/news/engineering-esports-tech-powers-worlds">
#           <img alt="" class="u-images-respond c-excerpt__image" src="https://technology.riotgames.com/sites/default/files/articles/102/engineeringesportsheader.png"/>
#          </a>
#          <p dir="ltr">
#           We’re the Esports Technology Group, and we’re responsible for the tech behind Riot’s biggest esports events, from reliable network connectivity to global broadcast capabilities to specialty tournament servers to the custom PC fleet used by pros. Part of our role at Riot is to approach typical broadcast and live production challenges with scalable and technology-driven solutions.
#          </p>
#          <div class="c-excerpt-meta">
#           <a class="c-excerpt-meta__read-more c-content__link" href="/news/engineering-esports-tech-powers-worlds">
#            Full Story
#            <i class="c-icon c-icon--right-circle">
#            </i>
#           </a>
#           <div class="c-excerpt-meta__group">
#            <span class="c-excerpt-meta__author">
#             Posted by The Esports Technology Group
#            </span>
#            <ul class="o-list-inline c-excerpt-meta__social">
#             <li class="c-social__item c-excerpt-meta__item">
#              <a class="c-social__link c-social__link--mail-alt c-excerpt-meta__link" href="/cdn-cgi/l/email-protection#">
#               <i class="c-icon c-icon--mail-alt">
#               </i>
#              </a>
#             </li>
#             <li class="c-social__item c-excerpt-meta__item">
#              <a class="c-social__link c-social__link--facebook c-excerpt-meta__link js-share" data-desc="This article describes the technical backbone of events like Worlds, including our networking solutions, broadcast tech, and PC fleet. " data-image="https://technology.riotgames.com/sites/default/files/articles/102/engineeringesportsheader.png" data-target="facebook" data-title="Engineering Esports: The Tech That Powers Worlds" data-url="https://technology.riotgames.com/news/engineering-esports-tech-powers-worlds" href="">
#               <i class="c-icon c-icon--facebook">
#               </i>
#              </a>
#             </li>
#             <li class="c-social__item c-excerpt-meta__item">
#              <a class="c-social__link c-social__link--twitter c-excerpt-meta__link js-share" data-target="twitter" data-title="Engineering Esports: The Tech That Powers Worlds https://riot.com/2IA6xi3" data-url="https://technology.riotgames.com/news/engineering-esports-tech-powers-worlds" href="">
#               <i class="c-icon c-icon--twitter">
#               </i>
#              </a>
#             </li>
#             <li class="c-social__item c-excerpt-meta__item">
#              <a class="c-social__link c-social__link--linkedin c-excerpt-meta__link js-share" data-desc="This article describes the technical backbone of events like Worlds, including our networking solutions, broadcast tech, and PC fleet. " data-target="linkedin" data-title="Engineering Esports: The Tech That Powers Worlds" data-url="https://technology.riotgames.com/news/engineering-esports-tech-powers-worlds" href="">
#               <i class="c-icon c-icon--linkedin">
#               </i>
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </article>
#         <hr class="c-rule c-rule--content"/>
#         <article class="c-excerpt views-row views-row-2 views-row-even" role="article">
#          <h1 class="c-excerpt__title">
#           <a href="/news/future-leagues-engine">
#            The Future of League's Engine
#           </a>
#          </h1>
#          <a href="/news/future-leagues-engine">
#           <img alt="" class="u-images-respond c-excerpt__image" src="https://technology.riotgames.com/sites/default/files/articles/101/leagueengineheader.png"/>
#          </a>
#          <p>
#           Hiya folks, Brian "Penrif" Bossé, your local friendly Tech Lead of
#           <em>
#            League
#           </em>
#           here. I'm taking some time in between matches of TFT to wax philosophic about game engines and how we on
#           <em>
#            League
#           </em>
#           make decisions around what direction to take our custom game engine. Join me on a moderately long look at one dimension of game engine design, where
#           <em>
#            League
#           </em>
#           currently exists on that dimension, and where we're taking the game from there.
#          </p>
#          <div class="c-excerpt-meta">
#           <a class="c-excerpt-meta__read-more c-content__link" href="/news/future-leagues-engine">
#            Full Story
#            <i class="c-icon c-icon--right-circle">
#            </i>
#           </a>
#           <div class="c-excerpt-meta__group">
#            <span class="c-excerpt-meta__author">
#             Posted by Brian Bossé
#            </span>
#            <ul class="o-list-inline c-excerpt-meta__social">
#             <li class="c-social__item c-excerpt-meta__item">
#              <a class="c-social__link c-social__link--mail-alt c-excerpt-meta__link" href="/cdn-cgi/l/email-protection#">
#               <i class="c-icon c-icon--mail-alt">
#               </i>
#              </a>
#             </li>
#             <li class="c-social__item c-excerpt-meta__item">
#              <a class="c-social__link c-social__link--facebook c-excerpt-meta__link js-share" data-desc="Gaze into the future of the League of Legends game engine." data-image="https://technology.riotgames.com/sites/default/files/articles/101/leagueengineheader.png" data-target="facebook" data-title="The Future of League's Engine" data-url="https://technology.riotgames.com/news/future-leagues-engine" href="">
#               <i class="c-icon c-icon--facebook">
#               </i>
#              </a>
#             </li>
#             <li class="c-social__item c-excerpt-meta__item">
#              <a class="c-social__link c-social__link--twitter c-excerpt-meta__link js-share" data-target="twitter" data-title="The Future of League's Engine https://riot.com/2mtnKlf" data-url="https://technology.riotgames.com/news/future-leagues-engine" href="">
#               <i class="c-icon c-icon--twitter">
#               </i>
#              </a>
#             </li>
#             <li class="c-social__item c-excerpt-meta__item">
#              <a class="c-social__link c-social__link--linkedin c-excerpt-meta__link js-share" data-desc="Gaze into the future of the League of Legends game engine." data-target="linkedin" data-title="The Future of League's Engine" data-url="https://technology.riotgames.com/news/future-leagues-engine" href="">
#               <i class="c-icon c-icon--linkedin">
#               </i>
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </article>
#         <hr class="c-rule c-rule--content"/>
#         <article class="c-excerpt views-row views-row-3 views-row-odd" role="article">
#          <h1 class="c-excerpt__title">
#           <a href="/news/down-rabbit-hole-performance-monitoring">
#            Down The Rabbit Hole of Performance Monitoring
#           </a>
#          </h1>
#          <a href="/news/down-rabbit-hole-performance-monitoring">
#           <img alt="" class="u-images-respond c-excerpt__image" src="https://technology.riotgames.com/sites/default/files/articles/100/rabbitholeheader.png"/>
#          </a>
#          <p>
#           Hi, I’m Tony, and I’m an engineer on
#           <em>
#            League
#           </em>
#           . This article is a followup to my
#           <a href="https://technology.riotgames.com/news/profiling-measurement-and-analysis" target="_blank">
#            performance series
#           </a>
#           , where I talk about optimisation and profiling. This will be a high level overview of how we monitor game performance in
#           <em>
#            League of Legends
#           </em>
#           , how we detect when a performance degradation has slipped through QA and escaped into the wild, and how we track global trends in frame times over many patches and millions of players. I hope you enjoy it!
#          </p>
#          <div class="c-excerpt-meta">
#           <a class="c-excerpt-meta__read-more c-content__link" href="/news/down-rabbit-hole-performance-monitoring">
#            Full Story
#            <i class="c-icon c-icon--right-circle">
#            </i>
#           </a>
#           <div class="c-excerpt-meta__group">
#            <span class="c-excerpt-meta__author">
#             Posted by Tony Albrecht
#            </span>
#            <ul class="o-list-inline c-excerpt-meta__social">
#             <li class="c-social__item c-excerpt-meta__item">
#              <a class="c-social__link c-social__link--mail-alt c-excerpt-meta__link" href="/cdn-cgi/l/email-protection#">
#               <i class="c-icon c-icon--mail-alt">
#               </i>
#              </a>
#             </li>
#             <li class="c-social__item c-excerpt-meta__item">
#              <a class="c-social__link c-social__link--facebook c-excerpt-meta__link js-share" data-desc="Join Tony on his trip down the rabbit hole of monitoring frame rates to track game performance in League of Legends." data-image="https://technology.riotgames.com/sites/default/files/articles/100/rabbitholeheader.png" data-target="facebook" data-title="Down The Rabbit Hole of Performance Monitoring" data-url="https://technology.riotgames.com/news/down-rabbit-hole-performance-monitoring" href="">
#               <i class="c-icon c-icon--facebook">
#               </i>
#              </a>
#             </li>
#             <li class="c-social__item c-excerpt-meta__item">
#              <a class="c-social__link c-social__link--twitter c-excerpt-meta__link js-share" data-target="twitter" data-title="Down The Rabbit Hole of Performance Monitoring https://riot.com/2ZgWWSV" data-url="https://technology.riotgames.com/news/down-rabbit-hole-performance-monitoring" href="">
#               <i class="c-icon c-icon--twitter">
#               </i>
#              </a>
#             </li>
#             <li class="c-social__item c-excerpt-meta__item">
#              <a class="c-social__link c-social__link--linkedin c-excerpt-meta__link js-share" data-desc="Join Tony on his trip down the rabbit hole of monitoring frame rates to track game performance in League of Legends." data-target="linkedin" data-title="Down The Rabbit Hole of Performance Monitoring" data-url="https://technology.riotgames.com/news/down-rabbit-hole-performance-monitoring" href="">
#               <i class="c-icon c-icon--linkedin">
#               </i>
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </article>
#         <hr class="c-rule c-rule--content"/>
#         <article class="c-excerpt views-row views-row-4 views-row-even" role="article">
#          <h1 class="c-excerpt__title">
#           <a href="/news/supercharging-data-delivery-new-league-patcher">
#            Supercharging Data Delivery: The New League Patcher
#           </a>
#          </h1>
#          <a href="/news/supercharging-data-delivery-new-league-patcher">
#           <img alt="" class="u-images-respond c-excerpt__image" src="https://technology.riotgames.com/sites/default/files/articles/99/750x260b.jpg"/>
#          </a>
#          <p>
#           For the past 8 years,
#           <em>
#            League
#           </em>
#           has been using a patching system called RADS (Riot Application Distribution System) to deliver updates. RADS is a custom patching solution based on binary deltas that we built with
#           <em>
#            League
#           </em>
#           in mind. While RADS has served us well, we felt we had an opportunity to improve some key areas of the patching experience. We knew we could deliver updates much more quickly and more reliably by using a fundamentally different approach to patching, so we set out to build a brand new patcher based on content-defined chunking.
#          </p>
#          <div class="c-excerpt-meta">
#           <a class="c-excerpt-meta__read-more c-content__link" href="/news/supercharging-data-delivery-new-league-patcher">
#            Full Story
#            <i class="c-icon c-icon--right-circle">
#            </i>
#           </a>
#           <div class="c-excerpt-meta__group">
#            <span class="c-excerpt-meta__author">
#             Posted by Javier Blazquez
#            </span>
#            <ul class="o-list-inline c-excerpt-meta__social">
#             <li class="c-social__item c-excerpt-meta__item">
#              <a class="c-social__link c-social__link--mail-alt c-excerpt-meta__link" href="/cdn-cgi/l/email-protection#">
#               <i class="c-icon c-icon--mail-alt">
#               </i>
#              </a>
#             </li>
#             <li class="c-social__item c-excerpt-meta__item">
#              <a class="c-social__link c-social__link--facebook c-excerpt-meta__link js-share" data-desc="Learn more about the tech powering League's new patcher." data-image="https://technology.riotgames.com/sites/default/files/articles/99/750x260b.jpg" data-target="facebook" data-title="Supercharging Data Delivery: The New League Patcher" data-url="https://technology.riotgames.com/news/supercharging-data-delivery-new-league-patcher" href="">
#               <i class="c-icon c-icon--facebook">
#               </i>
#              </a>
#             </li>
#             <li class="c-social__item c-excerpt-meta__item">
#              <a class="c-social__link c-social__link--twitter c-excerpt-meta__link js-share" data-target="twitter" data-title="Supercharging Data Delivery: The New League Patcher https://riot.com/2JFu5De" data-url="https://technology.riotgames.com/news/supercharging-data-delivery-new-league-patcher" href="">
#               <i class="c-icon c-icon--twitter">
#               </i>
#              </a>
#             </li>
#             <li class="c-social__item c-excerpt-meta__item">
#              <a class="c-social__link c-social__link--linkedin c-excerpt-meta__link js-share" data-desc="Learn more about the tech powering League's new patcher." data-target="linkedin" data-title="Supercharging Data Delivery: The New League Patcher" data-url="https://technology.riotgames.com/news/supercharging-data-delivery-new-league-patcher" href="">
#               <i class="c-icon c-icon--linkedin">
#               </i>
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </article>
#         <hr class="c-rule c-rule--content"/>
#         <article class="c-excerpt views-row views-row-5 views-row-odd" role="article">
#          <h1 class="c-excerpt__title">
#           <a href="/news/riot-games-api-transforms">
#            The Riot Games API: Transforms
#           </a>
#          </h1>
#          <a href="/news/riot-games-api-transforms">
#           <img alt="" class="u-images-respond c-excerpt__image" src="https://technology.riotgames.com/sites/default/files/articles/98/apitransformsheader.png"/>
#          </a>
#          <p>
#           Hello all, Leigh Estes, aka RiotSchmick, here. I’m a software engineer at Riot Games working on the Riot Developer Experience team. Our responsibilities include providing the edge infrastructure that supports both internal and external developers. I previously wrote
#           <a href="https://engineering.riotgames.com/news/riot-games-api-goals-and-design" target="_blank">
#            a series
#           </a>
#           on the infrastructure that supports our public API product. I’m excited to revisit this series to tell you more about a new part of our infrastructure - the feature we call transforms.
#          </p>
#          <div class="c-excerpt-meta">
#           <a class="c-excerpt-meta__read-more c-content__link" href="/news/riot-games-api-transforms">
#            Full Story
#            <i class="c-icon c-icon--right-circle">
#            </i>
#           </a>
#           <div class="c-excerpt-meta__group">
#            <span class="c-excerpt-meta__author">
#             Posted by Leigh Estes
#            </span>
#            <ul class="o-list-inline c-excerpt-meta__social">
#             <li class="c-social__item c-excerpt-meta__item">
#              <a class="c-social__link c-social__link--mail-alt c-excerpt-meta__link" href="/cdn-cgi/l/email-protection#">
#               <i class="c-icon c-icon--mail-alt">
#               </i>
#              </a>
#             </li>
#             <li class="c-social__item c-excerpt-meta__item">
#              <a class="c-social__link c-social__link--facebook c-excerpt-meta__link js-share" data-desc="Learn how the Riot Games API team used transforms to build a generic, robust, and extensible system. " data-image="https://technology.riotgames.com/sites/default/files/articles/98/apitransformsheader.png" data-target="facebook" data-title="The Riot Games API: Transforms" data-url="https://technology.riotgames.com/news/riot-games-api-transforms" href="">
#               <i class="c-icon c-icon--facebook">
#               </i>
#              </a>
#             </li>
#             <li class="c-social__item c-excerpt-meta__item">
#              <a class="c-social__link c-social__link--twitter c-excerpt-meta__link js-share" data-target="twitter" data-title="The Riot Games API: Transforms https://riot.com/2LwfH1w" data-url="https://technology.riotgames.com/news/riot-games-api-transforms" href="">
#               <i class="c-icon c-icon--twitter">
#               </i>
#              </a>
#             </li>
#             <li class="c-social__item c-excerpt-meta__item">
#              <a class="c-social__link c-social__link--linkedin c-excerpt-meta__link js-share" data-desc="Learn how the Riot Games API team used transforms to build a generic, robust, and extensible system. " data-target="linkedin" data-title="The Riot Games API: Transforms" data-url="https://technology.riotgames.com/news/riot-games-api-transforms" href="">
#               <i class="c-icon c-icon--linkedin">
#               </i>
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </article>
#         <hr class="c-rule c-rule--content"/>
#         <article class="c-excerpt views-row views-row-6 views-row-even" role="article">
#          <h1 class="c-excerpt__title">
#           <a href="/news/key-conjurer-our-policy-least-privilege">
#            Key Conjurer: Our Policy of Least Privilege
#           </a>
#          </h1>
#          <a href="/news/key-conjurer-our-policy-least-privilege">
#           <img alt="" class="u-images-respond c-excerpt__image" src="https://technology.riotgames.com/sites/default/files/articles/97/keyconjurerheader.png"/>
#          </a>
#          <p>
#           Hi, my name is Reza Nikoopour and I’m a security engineer on the Security team at Riot. My team is responsible for securing Riot infrastructure wherever we’re deployed - whether that means internal or external data centers or clouds. We provide cloud security guidance to the rest of Riot, and we’re responsible for
#           <a href="https://github.com/RiotGames/key-conjurer" target="_blank">
#            Key Conjurer
#           </a>
#           , our open source AWS API programmatic access solution.
#          </p>
#          <div class="c-excerpt-meta">
#           <a class="c-excerpt-meta__read-more c-content__link" href="/news/key-conjurer-our-policy-least-privilege">
#            Full Story
#            <i class="c-icon c-icon--right-circle">
#            </i>
#           </a>
#           <div class="c-excerpt-meta__group">
#            <span class="c-excerpt-meta__author">
#             Posted by Reza Nikoopour
#            </span>
#            <ul class="o-list-inline c-excerpt-meta__social">
#             <li class="c-social__item c-excerpt-meta__item">
#              <a class="c-social__link c-social__link--mail-alt c-excerpt-meta__link" href="/cdn-cgi/l/email-protection#">
#               <i class="c-icon c-icon--mail-alt">
#               </i>
#              </a>
#             </li>
#             <li class="c-social__item c-excerpt-meta__item">
#              <a class="c-social__link c-social__link--facebook c-excerpt-meta__link js-share" data-desc="Learn more about Key Conjurer, our open-sourced temporary AWS API key solution." data-image="https://technology.riotgames.com/sites/default/files/articles/97/keyconjurerheader.png" data-target="facebook" data-title="Key Conjurer: Our Policy of Least Privilege" data-url="https://technology.riotgames.com/news/key-conjurer-our-policy-least-privilege" href="">
#               <i class="c-icon c-icon--facebook">
#               </i>
#              </a>
#             </li>
#             <li class="c-social__item c-excerpt-meta__item">
#              <a class="c-social__link c-social__link--twitter c-excerpt-meta__link js-share" data-target="twitter" data-title="Key Conjurer: Our Policy of Least Privilege https://riot.com/2Fn5QXH" data-url="https://technology.riotgames.com/news/key-conjurer-our-policy-least-privilege" href="">
#               <i class="c-icon c-icon--twitter">
#               </i>
#              </a>
#             </li>
#             <li class="c-social__item c-excerpt-meta__item">
#              <a class="c-social__link c-social__link--linkedin c-excerpt-meta__link js-share" data-desc="Learn more about Key Conjurer, our open-sourced temporary AWS API key solution." data-target="linkedin" data-title="Key Conjurer: Our Policy of Least Privilege" data-url="https://technology.riotgames.com/news/key-conjurer-our-policy-least-privilege" href="">
#               <i class="c-icon c-icon--linkedin">
#               </i>
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </article>
#         <hr class="c-rule c-rule--content"/>
#         <article class="c-excerpt views-row views-row-7 views-row-odd" role="article">
#          <h1 class="c-excerpt__title">
#           <a href="/news/better-apps-react-server-side-rendering">
#            Better Apps with React Server-Side Rendering
#           </a>
#          </h1>
#          <a href="/news/better-apps-react-server-side-rendering">
#           <img alt="" class="u-images-respond c-excerpt__image" src="https://technology.riotgames.com/sites/default/files/articles/96/betterappsheader.png"/>
#          </a>
#          <p dir="ltr">
#           Imagine you're a web developer. You have to create an app that leverages five different data sources. The project has 26 different views built in - and don’t forget to make it fast, easy to test, and reliable. I work on creating the tools that make this kind of app as easy as possible for developers to build and manage. My name is Matthew Drake and I’m a member of the Riot Data team.
#          </p>
#          <div class="c-excerpt-meta">
#           <a class="c-excerpt-meta__read-more c-content__link" href="/news/better-apps-react-server-side-rendering">
#            Full Story
#            <i class="c-icon c-icon--right-circle">
#            </i>
#           </a>
#           <div class="c-excerpt-meta__group">
#            <span class="c-excerpt-meta__author">
#             Posted by Matthew Drake
#            </span>
#            <ul class="o-list-inline c-excerpt-meta__social">
#             <li class="c-social__item c-excerpt-meta__item">
#              <a class="c-social__link c-social__link--mail-alt c-excerpt-meta__link" href="/cdn-cgi/l/email-protection#">
#               <i class="c-icon c-icon--mail-alt">
#               </i>
#              </a>
#             </li>
#             <li class="c-social__item c-excerpt-meta__item">
#              <a class="c-social__link c-social__link--facebook c-excerpt-meta__link js-share" data-desc="Try out this tutorial on using React server-side rendering with data store injection to make your web apps more responsive, easier to test, and better at scale. " data-image="https://technology.riotgames.com/sites/default/files/articles/96/betterappsheader.png" data-target="facebook" data-title="Better Apps with React Server-Side Rendering" data-url="https://technology.riotgames.com/news/better-apps-react-server-side-rendering" href="">
#               <i class="c-icon c-icon--facebook">
#               </i>
#              </a>
#             </li>
#             <li class="c-social__item c-excerpt-meta__item">
#              <a class="c-social__link c-social__link--twitter c-excerpt-meta__link js-share" data-target="twitter" data-title="Better Apps with React Server-Side Rendering https://riot.com/2X2gNER" data-url="https://technology.riotgames.com/news/better-apps-react-server-side-rendering" href="">
#               <i class="c-icon c-icon--twitter">
#               </i>
#              </a>
#             </li>
#             <li class="c-social__item c-excerpt-meta__item">
#              <a class="c-social__link c-social__link--linkedin c-excerpt-meta__link js-share" data-desc="Try out this tutorial on using React server-side rendering with data store injection to make your web apps more responsive, easier to test, and better at scale. " data-target="linkedin" data-title="Better Apps with React Server-Side Rendering" data-url="https://technology.riotgames.com/news/better-apps-react-server-side-rendering" href="">
#               <i class="c-icon c-icon--linkedin">
#               </i>
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </article>
#         <hr class="c-rule c-rule--content"/>
#         <article class="c-excerpt views-row views-row-8 views-row-even" role="article">
#          <h1 class="c-excerpt__title">
#           <a href="/news/stocking-your-shop-data-science">
#            Stocking Your Shop With Data Science
#           </a>
#          </h1>
#          <a href="/news/stocking-your-shop-data-science">
#           <img alt="" class="u-images-respond c-excerpt__image" src="https://technology.riotgames.com/sites/default/files/articles/95/recommenderheader.png"/>
#          </a>
#          <p dir="ltr">
#           Hey there, my name is Riley “WhoaNonstop” Howsden, and I’m a Data Scientist who works on
#           <em>
#            League of Legends
#           </em>
#           , focusing mainly on personalization. Over the last few years I’ve been a part of the launch team for “
#           <a href="https://na.leagueoflegends.com/en/tag/your-shop" target="_blank">
#            Your Shop
#           </a>
#           ,” a product within
#           <em>
#            League
#           </em>
#           that creates personalized offers for every player around the globe. Data scientists like me work with engineers, analysts, artists, and publishing to create experiences that players love. From matchmaking and player behavior to artificial intelligence and game balance, data science is a key contributor for many initiatives at Riot.
#          </p>
#          <div class="c-excerpt-meta">
#           <a class="c-excerpt-meta__read-more c-content__link" href="/news/stocking-your-shop-data-science">
#            Full Story
#            <i class="c-icon c-icon--right-circle">
#            </i>
#           </a>
#           <div class="c-excerpt-meta__group">
#            <span class="c-excerpt-meta__author">
#             Posted by Riley Howsden
#            </span>
#            <ul class="o-list-inline c-excerpt-meta__social">
#             <li class="c-social__item c-excerpt-meta__item">
# ...
#          </p>
#          <div class="c-excerpt-meta">
#           <a class="c-excerpt-meta__read-more c-content__link" href="/news/reducing-rendering-complexity-gun-goddess-miss-fortune">
#            Full Story
#            <i class="c-icon c-icon--right-circle">
#            </i>
#           </a>
#           <div class="c-excerpt-meta__group">
#            <span class="c-excerpt-meta__author">
#             Posted by Eric Friedman
#            </span>
#            <ul class="o-list-inline c-excerpt-meta__social">
#             <li class="c-social__item c-excerpt-meta__item">
#              <a class="c-social__link c-social__link--mail-alt c-excerpt-meta__link" href="/cdn-cgi/l/email-protection#">
#               <i class="c-icon c-icon--mail-alt">
#               </i>
#              </a>
#             </li>
#             <li class="c-social__item c-excerpt-meta__item">
#              <a class="c-social__link c-social__link--facebook c-excerpt-meta__link js-share" data-desc="Building a new tool called SkinnedRenderable to improve content pipelines and reduce rendering complexity." data-image="https://technology.riotgames.com/sites/default/files/articles/93/ggmfheader.png" data-target="facebook" data-title="Reducing Rendering Complexity with Gun Goddess Miss Fortune" data-url="https://technology.riotgames.com/news/reducing-rendering-complexity-gun-goddess-miss-fortune" href="">
#               <i class="c-icon c-icon--facebook">
#               </i>
#              </a>
#             </li>
#             <li class="c-social__item c-excerpt-meta__item">
#              <a class="c-social__link c-social__link--twitter c-excerpt-meta__link js-share" data-target="twitter" data-title="Reducing Rendering Complexity with Gun Goddess Miss Fortune https://riot.com/2TOzoCG" data-url="https://technology.riotgames.com/news/reducing-rendering-complexity-gun-goddess-miss-fortune" href="">
#               <i class="c-icon c-icon--twitter">
#               </i>
#              </a>
#             </li>
#             <li class="c-social__item c-excerpt-meta__item">
#              <a class="c-social__link c-social__link--linkedin c-excerpt-meta__link js-share" data-desc="Building a new tool called SkinnedRenderable to improve content pipelines and reduce rendering complexity." data-target="linkedin" data-title="Reducing Rendering Complexity with Gun Goddess Miss Fortune" data-url="https://technology.riotgames.com/news/reducing-rendering-complexity-gun-goddess-miss-fortune" href="">
#               <i class="c-icon c-icon--linkedin">
#               </i>
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </article>
#         <hr class="c-rule c-rule--content"/>
#        </div>
#        <div class="item-list">
#         <ul class="pager pager-load-more">
#          <li class="pager-next first last">
#           <a href="/node?page=1">
#            Load More Articles
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#      <div class="o-layout__item o-layout__item--aside">
#       <aside class="c-sidebar c-sidebar--paneled" role="complementary">
#        <form action="/search" class="c-search-form" method="get">
#         <input class="c-form-group__input c-search-form__input" name="search" placeholder="Search Articles and Tags" type="text" value=""/>
#         <button class="c-search-form__submit" type="submit">
#          <i class="c-icon--search">
#          </i>
#         </button>
#        </form>
#        <div class="c-tag-block c-tag-block--thick">
#         <ul class="c-tag-block__list o-list-unstyled">
#          <li class="c-tag-block__item">
#           <a class="c-tag-block__link" href="/tags/architecture">
#            architecture
#            <span>
#             (22)
#            </span>
#           </a>
#          </li>
#          <li class="c-tag-block__item">
#           <a class="c-tag-block__link" href="/tags/automation">
#            automation
#            <span>
#             (3)
#            </span>
#           </a>
#          </li>
#          <li class="c-tag-block__item">
#           <a class="c-tag-block__link" href="/tags/ci">
#            ci
#            <span>
#             (11)
#            </span>
#           </a>
#          </li>
#          <li class="c-tag-block__item">
#           <a class="c-tag-block__link" href="/tags/data">
#            data
#            <span>
#             (7)
#            </span>
#           </a>
#          </li>
#          <li class="c-tag-block__item">
#           <a class="c-tag-block__link" href="/tags/deployment">
#            deployment
#            <span>
#             (15)
#            </span>
#           </a>
#          </li>
#          <li class="c-tag-block__item">
#           <a class="c-tag-block__link" href="/tags/game">
#            game
#            <span>
#             (25)
#            </span>
#           </a>
#          </li>
#          <li class="c-tag-block__item">
#           <a class="c-tag-block__link" href="/tags/infrastructure">
#            infrastructure
#            <span>
#             (23)
#            </span>
#           </a>
#          </li>
#          <li class="c-tag-block__item">
#           <a class="c-tag-block__link" href="/tags/leadership">
#            leadership
#            <span>
#             (4)
#            </span>
#           </a>
#          </li>
#          <li class="c-tag-block__item">
#           <a class="c-tag-block__link" href="/tags/performance">
#            performance
#            <span>
#             (15)
#            </span>
#           </a>
#          </li>
#          <li class="c-tag-block__item">
#           <a class="c-tag-block__link" href="/tags/rendering">
#            rendering
#            <span>
#             (5)
#            </span>
#           </a>
#          </li>
#          <li class="c-tag-block__item">
#           <a class="c-tag-block__link" href="/tags/security">
#            security
#            <span>
#             (4)
#            </span>
#           </a>
#          </li>
#          <li class="c-tag-block__item">
#           <a class="c-tag-block__link" href="/tags/testing">
#            testing
#            <span>
#             (3)
#            </span>
#           </a>
#          </li>
#          <li class="c-tag-block__item">
#           <a class="c-tag-block__link" href="/tags/video">
#            video
#            <span>
#             (5)
#            </span>
#           </a>
#          </li>
#          <li class="c-tag-block__item">
#           <a class="c-tag-block__link" href="/tags/web">
#            web
#            <span>
#             (5)
#            </span>
#           </a>
#          </li>
#         </ul>
#        </div>
#       </aside>
#      </div>
#     </div>
#     <hr class="c-rule c-rule--content"/>
#    </div>
#   </div>
#   <div class="o-wrapper o-wrapper--footer">
#    <div class="o-container o-container--footer" style="background: url(https://technology.riotgames.com/sites/default/files/theme/backgrounds/footer.jpg) bottom no-repeat; ">
#     <footer class="c-footer" role="contentinfo">
#      <div class="c-lower-content">
#       <footer class="region region-footer" id="footer">
#        <img alt="Footer callout image" class="c-logo" src="/sites/default/files/blocks/logo-fist-red_0.png" title="Footer Callout Image">
#         <h2 class="c-lower-content__title">
#          Player Driven Technology
#         </h2>
#         <hr class="c-rule c-rule--darker c-rule--short">
#          <div class="c-lower-content__text">
#           <p>
#            We're not technologists who just happen to be gamers, nor are we gamers who just happen to be technologists.  These are fundamental to our identity and we embrace them both. We’ve been absolutely delighted by games and we’ve been sorely disappointed by them.  At Riot we create technology to deliver players the former and shield them from the latter.
#           </p>
#          </div>
#         </hr>
#        </img>
#       </footer>
#       <section class="o-container c-footer__inner">
#        <a class="c-logo" href="http://www.riotgames.com/">
#         Riot Games
#         <img alt="" class="c-footer__logo" src="/sites/all/themes/riot_games_engineering/images/logo-riot.png">
#         </img>
#        </a>
#        <div class="c-footer__columms">
#         <div class="c-footer__column">
#          <h4 class="c-footer__title">
#           Company
#          </h4>
#          <ul class="o-list-unstyled c-footer__list">
#           <li class="c-footer__list-item">
#            <a class="c-footer__link" href="http://www.riotgames.com/riot-manifesto" target="_blank" title="">
#             Who we are
#            </a>
#           </li>
#           <li class="c-footer__list-item">
#            <a class="c-footer__link" href="http://www.riotgames.com/news" target="_blank" title="">
#             News
#            </a>
#           </li>
#           <li class="c-footer__list-item">
#            <a class="c-footer__link" href="http://www.riotgames.com/legal-jibber-jabber" target="_blank" title="">
#             Legal jibber jabber
#            </a>
#           </li>
#           <li class="c-footer__list-item">
#            <a class="c-footer__link" href="http://www.riotgames.com/riot-games-security" target="_blank" title="">
#             Security
#            </a>
#           </li>
#           <li class="c-footer__list-item">
#            <a class="c-footer__link" href="http://www.riotgames.com/contact" target="_blank" title="">
#             Contact infos
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="c-footer__column">
#          <h4 class="c-footer__title">
#           Careers
#          </h4>
#          <ul class="o-list-unstyled c-footer__list">
#           <li class="c-footer__list-item">
#            <a class="c-footer__link" href="https://www.riotgames.com/en/work-with-us/welcome" target="_blank" title="">
#             Riot with us
#            </a>
#           </li>
#           <li class="c-footer__list-item">
#            <a class="c-footer__link" href="https://www.riotgames.com/work-with-us/disciplines/engineering" target="_blank" title="">
#             Search open jobs
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="c-footer__column c-footer__column--language">
#          <h4 class="c-footer__title">
#           Social
#          </h4>
#          <ul class="o-list-inline c-footer__social">
#           <li class="c-social__item c-footer__social-item">
#            <a class="c-social__link c-social__link--rss c-footer__social-link" href="https://technology.riotgames.com/news/feed" target="_blank">
#             <i class="c-icon c-icon--rss">
#             </i>
#            </a>
#           </li>
#          </ul>
#          <ul class="o-list-inline c-footer__social">
#           <li class="c-social__item c-footer__social-item">
#            <a class="c-social__link c-social__link--facebook c-footer__social-link" href="https://www.facebook.com/RiotGames" target="_blank">
#             <i class="c-icon c-icon--facebook">
#             </i>
#            </a>
#           </li>
#           <li class="c-social__item c-footer__social-item">
#            <a class="c-social__link c-social__link--twitter c-footer__social-link" href="https://twitter.com/riotgames" target="_blank">
#             <i class="c-icon c-icon--twitter">
#             </i>
#            </a>
#           </li>
#           <li class="c-social__item c-footer__social-item">
#            <a class="c-social__link c-social__link--youtube c-footer__social-link" href="https://www.youtube.com/user/RiotGamesInc" target="_blank">
#             <i class="c-icon c-icon--youtube-play">
#             </i>
#            </a>
#           </li>
#           <li class="c-social__item c-footer__social-item">
#            <a class="c-social__link c-social__link--linkedin c-footer__social-link" href="https://www.linkedin.com/company/riot-games" target="_blank">
#             <i class="c-icon c-icon--linkedin">
#             </i>
#            </a>
#           </li>
#           <li class="c-social__item c-footer__social-item">
#            <a class="c-social__link c-social__link--glassdoor c-footer__social-link" href="http://www.glassdoor.com/Overview/Working-at-Riot-Games-EI_IE247538.11,21.htm" target="_blank">
#             <i class="c-icon c-icon--glassdoor">
#             </i>
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <p class="c-footer__copyright">
#         © 2019 Riot Games, Inc. All rights reserved. League of Legends and Riot Games are trademarks, service
# marks, or registered trademarks of Riot Games, Inc.
#        </p>
#       </section>
#      </div>
#     </footer>
#    </div>
#   </div>
#   <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js">
#   </script>
#   <script src="https://technology.riotgames.com/sites/default/files/js/js_vIYJMoKYoMWkVusn3iML8i0Lt7Is3CRaFcqWuXJaFrM.js">
#   </script>
#   <script src="https://technology.riotgames.com/sites/default/files/js/js_BLxotNs2yt7YGlf9QRI9L9AMfdnkQfnN-_ADBTW3SiE.js">
#   </script>
#   <script src="https://technology.riotgames.com/sites/default/files/js/js_LfSIuvPVhbHVWh6VesAkSHhmd0wlIAMcNsYxGQOr6ts.js">
#   </script>
#   <script src="https://technology.riotgames.com/sites/default/files/js/js_DvB3MRpE5ntAa8-jjWpWRbQM-y589pkxFGJoqUmMnAY.js">
#   </script>
#   <script>
#    jQuery.extend(Drupal.settings, {"basePath":"\/","pathPrefix":"","ajaxPageState":{"theme":"riot_games_engineering","theme_token":"1F5p39rz78uidzXnmRou3llrMdqnyCuXaNOfCQgEN3Q","jquery_version":"1.11","js":{"sites\/all\/modules\/jquery_update\/replace\/jquery\/1.11\/jquery.min.js":1,"misc\/jquery.once.js":1,"misc\/drupal.js":1,"sites\/all\/modules\/jquery_update\/replace\/ui\/external\/jquery.cookie.js":1,"sites\/all\/modules\/jquery_update\/replace\/misc\/jquery.form.min.js":1,"misc\/ajax.js":1,"sites\/all\/modules\/jquery_update\/js\/jquery_update.js":1,"sites\/all\/modules\/views_load_more\/views_load_more.js":1,"sites\/all\/modules\/views\/js\/base.js":1,"misc\/progress.js":1,"sites\/all\/modules\/views\/js\/ajax_view.js":1,"sites\/all\/themes\/riot_games_engineering\/dist\/production.min.js":1},"css":{"modules\/system\/system.base.css":1,"modules\/system\/system.messages.css":1,"sites\/all\/modules\/date\/date_api\/date.css":1,"sites\/all\/modules\/ckeditor\/css\/ckeditor.css":1,"sites\/all\/themes\/riot_games_engineering\/dist\/production.min.css":1}},"views":{"ajax_path":"\/views\/ajax","ajaxViews":{"views_dom_id:1e78c4ba60e49dc42521b1d3e444be71":{"view_name":"recent_news_articles","view_display_id":"block","view_args":"","view_path":"node","view_base_path":"news\/feed","view_dom_id":"1e78c4ba60e49dc42521b1d3e444be71","pager_element":0}}},"urlIsAjaxTrusted":{"\/views\/ajax":true}});
#   </script>
#   <script>
#    /**
#          * Pageview tracking - Fonts.com
#          */
#         eval(function(p,a,c,k,e,r){e=function(c){return c.toString(a)};if(!''.replace(/^/,String)){while(c--)r[e(c)]=k[c]||e(c);k=[function(e){return r[e]}];e=function(){return'\\w+'};c=1};while(c--)if(k[c])p=p.replace(new RegExp('\\b'+e(c)+'\\b','g'),k[c]);return p}('4 7=g.b;4 2=3.p(\'r\');2.9=\'a/5\';2.c=\'d\';2.e=(\'6:\'==3.u.h?\'6:\':\'i:\')+\'//j.k.l/t/1.5?m=n&o=\'+7;(3.8(\'q\')[0]||3.8(\'s\')[0]).f(2);',31,31,'||mtiTracking|document|var|css|https|projectId|getElementsByTagName|type|text|MTIProjectId|rel|stylesheet|href|appendChild|window|protocol|http|fast|fonts|net|apiType|css|projectid|createElement|head|link|body||location'.split('|'),0,{}))
#   </script>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","licenseKey":"25a156d569","applicationID":"7806507","transactionName":"NAdQYEtTVkJXWhBeWw1NZ0ZQHRdYWF0BTxoTCkI=","queueTime":0,"applicationTime":12,"atts":"GEBTFgNJRUw=","errorBeacon":"bam.nr-data.net","agent":""}
#   </script>
#  </body>
# </html>

# %%
print(soup.get_text())
# Out:
# (window.NREUM||(NREUM={})).loader_config={licenseKey:"25a156d569",applicationID:"7806507"};window.NREUM||(NREUM={}),__nr_require=function(e,n,t){function r(t){if(!n[t]){var o=n[t]={exports:{}};e[t][0].call(o.exports,function(n){var o=e[t][1][n];return r(o||n)},o,o.exports)}return n[t].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<t.length;o++)r(t[o]);return r}({1:[function(e,n,t){function r(){}function o(e,n,t){return function(){return i(e,[c.now()].concat(u(arguments)),n?null:this,t),n?void 0:this}}var i=e("handle"),a=e(3),u=e(4),f=e("ee").get("tracer"),c=e("loader"),s=NREUM;"undefined"==typeof window.newrelic&&(newrelic=s);var p=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],d="api-",l=d+"ixn-";a(p,function(e,n){s[n]=o(d+n,!0,"api")}),s.addPageAction=o(d+"addPageAction",!0),s.setCurrentRouteName=o(d+"routeName",!0),n.exports=newrelic,s.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(e,n){var t={},r=this,o="function"==typeof n;return i(l+"tracer",[c.now(),e,t],r),function(){if(f.emit((o?"":"no-")+"fn-start",[c.now(),r,o],t),o)try{return n.apply(this,arguments)}catch(e){throw f.emit("fn-err",[arguments,this,e],t),e}finally{f.emit("fn-end",[c.now()],t)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(e,n){m[n]=o(l+n)}),newrelic.noticeError=function(e,n){"string"==typeof e&&(e=new Error(e)),i("err",[e,c.now(),!1,n])}},{}],2:[function(e,n,t){function r(e,n){if(!o)return!1;if(e!==o)return!1;if(!n)return!0;if(!i)return!1;for(var t=i.split("."),r=n.split("."),a=0;a<r.length;a++)if(r[a]!==t[a])return!1;return!0}var o=null,i=null,a=/Version\/(\S+)\s+Safari/;if(navigator.userAgent){var u=navigator.userAgent,f=u.match(a);f&&u.indexOf("Chrome")===-1&&u.indexOf("Chromium")===-1&&(o="Safari",i=f[1])}n.exports={agent:o,version:i,match:r}},{}],3:[function(e,n,t){function r(e,n){var t=[],r="",i=0;for(r in e)o.call(e,r)&&(t[i]=n(r,e[r]),i+=1);return t}var o=Object.prototype.hasOwnProperty;n.exports=r},{}],4:[function(e,n,t){function r(e,n,t){n||(n=0),"undefined"==typeof t&&(t=e?e.length:0);for(var r=-1,o=t-n||0,i=Array(o<0?0:o);++r<o;)i[r]=e[n+r];return i}n.exports=r},{}],5:[function(e,n,t){n.exports={exists:"undefined"!=typeof window.performance&&window.performance.timing&&"undefined"!=typeof window.performance.timing.navigationStart}},{}],ee:[function(e,n,t){function r(){}function o(e){function n(e){return e&&e instanceof r?e:e?f(e,u,i):i()}function t(t,r,o,i){if(!d.aborted||i){e&&e(t,r,o);for(var a=n(o),u=v(t),f=u.length,c=0;c<f;c++)u[c].apply(a,r);var p=s[y[t]];return p&&p.push([b,t,r,a]),a}}function l(e,n){h[e]=v(e).concat(n)}function m(e,n){var t=h[e];if(t)for(var r=0;r<t.length;r++)t[r]===n&&t.splice(r,1)}function v(e){return h[e]||[]}function g(e){return p[e]=p[e]||o(t)}function w(e,n){c(e,function(e,t){n=n||"feature",y[t]=n,n in s||(s[n]=[])})}var h={},y={},b={on:l,addEventListener:l,removeEventListener:m,emit:t,get:g,listeners:v,context:n,buffer:w,abort:a,aborted:!1};return b}function i(){return new r}function a(){(s.api||s.feature)&&(d.aborted=!0,s=d.backlog={})}var u="nr@context",f=e("gos"),c=e(3),s={},p={},d=n.exports=o();d.backlog=s},{}],gos:[function(e,n,t){function r(e,n,t){if(o.call(e,n))return e[n];var r=t();if(Object.defineProperty&&Object.keys)try{return Object.defineProperty(e,n,{value:r,writable:!0,enumerable:!1}),r}catch(i){}return e[n]=r,r}var o=Object.prototype.hasOwnProperty;n.exports=r},{}],handle:[function(e,n,t){function r(e,n,t,r){o.buffer([e],r),o.emit(e,n,t)}var o=e("ee").get("handle");n.exports=r,r.ee=o},{}],id:[function(e,n,t){function r(e){var n=typeof e;return!e||"object"!==n&&"function"!==n?-1:e===window?0:a(e,i,function(){return o++})}var o=1,i="nr@id",a=e("gos");n.exports=r},{}],loader:[function(e,n,t){function r(){if(!E++){var e=x.info=NREUM.info,n=l.getElementsByTagName("script")[0];if(setTimeout(s.abort,3e4),!(e&&e.licenseKey&&e ...
#
#
#
# Riot Games Technology
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         .c-header--page {
#             clip-path: url(#clippath);
#             -webkit-clip-path: polygon(50% 0%, 100% 0, 100% 92%, 50% 100%, 50% 100%, 0 92%, 0 0);
#             clip-path: polygon(50% 0%, 100% 0, 100% 92%, 50% 100%, 50% 100%, 0 92%, 0 0);
#         }
#
#         @media (min-width: 768px) {
#
#             .c-header--page {
#                 clip-path: url(#clippath-sm);
#                 -webkit-clip-path: polygon(50% 0%, 100% 0, 100% 88%, 50% 100%, 50% 100%, 0 88%, 0 0);
#                 clip-path: polygon(50% 0%, 100% 0, 100% 88%, 50% 100%, 50% 100%, 0 88%, 0 0);
#             }
#
#         }
#
#         @media (min-width: 1200px) {
#
#             .c-header--page {
#                 clip-path: url(#clippath-lg);
#                 -webkit-clip-path: polygon(50% 0%, 100% 0, 100% 84%, 50% 100%, 50% 100%, 0 84%, 0 0);
#                 clip-path: polygon(50% 0%, 100% 0, 100% 84%, 50% 100%, 50% 100%, 0 84%, 0 0);
#             }
#
#         }
#
#         @media (min-width: 1500px) {
#
#             .c-header--page {
#                 clip-path: url(#clippath-xl);
#                 -webkit-clip-path: polygon(50% 0%, 100% 0, 100% 80%, 50% 100%, 50% 100%, 0 80%, 0 0);
#                 clip-path: polygon(50% 0%, 100% 0, 100% 80%, 50% 100%, 50% 100%, 0 80%, 0 0);
#             }
#
#         }
#
#         @media (min-width: 1600px) {
#
#             .c-header--page {
#                 clip-path: url(#clippath-cxl);
#                 -webkit-clip-path: polygon(50% 0%, 100% 0, 100% 78%, 50% 100%, 50% 100%, 0 78%, 0 0);
#                 clip-path: polygon(50% 0%, 100% 0, 100% 78%, 50% 100%, 50% 100%, 0 78%, 0 0);
#             }
#
#         }
#
#
#
#
#
#
#
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-KWJH');
#
#         window.fbAsyncInit = function() {
#             FB.init({
#                 appId      : '505056592980080',
#                 xfbml      : true,
#                 version    : 'v2.4'
#             });
#         };
#
#         (function(d, s, id){
#             var js, fjs = d.getElementsByTagName(s)[0];
#             if (d.getElementById(id)) {return;}
#             js = d.createElement(s); js.id = id;
#             js.src = "//connect.facebook.net/en_US/sdk.js";
#             fjs.parentNode.insertBefore(js, fjs);
#         }(document, 'script', 'facebook-jssdk'));
#
#
# Jump to navigation
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Our Story
#
#
#
#
# Careers
#
#
#
#
# Games
#
#
#
#
# News
#
#
#
# Riotgames.com
#
#
#
#
#
#
#
# Riot Games
#
#
#
#
# Our Story
#
#
# Careers
#
#
# Games
#
#
# News
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Engineering Esports: The Tech That Powers Worlds
#
#
#
# We’re the Esports Technology Group, and we’re responsible for the tech behind Riot’s biggest esports events, from reliable network connectivity to global broadcast capabilities to specialty tournament servers to the custom PC fleet used by pros. Part of our role at Riot is to approach typical broadcast and live production challenges with scalable and technology-driven solutions.
#
#
# Full Story
#
#
# Posted by The Esports Technology Group
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The Future of League's Engine
#
#
#
# Hiya folks, Brian "Penrif" Bossé, your local friendly Tech Lead of League here. I'm taking some time in between matches of TFT to wax philosophic about game engines and how we on League make decisions around what direction to take our custom game engine. Join me on a moderately long look at one dimension of game engine design, where League currently exists on that dimension, and where we're taking the game from there.
#
#
# Full Story
#
#
# Posted by Brian Bossé
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Down The Rabbit Hole of Performance Monitoring
#
#
#
# Hi, I’m Tony, and I’m an engineer on League. This article is a followup to my performance series, where I talk about optimisation and profiling. This will be a high level overview of how we monitor game performance in League of Legends, how we detect when a performance degradation has slipped through QA and escaped into the wild, and how we track global trends in frame times over many patches and millions of players. I hope you enjoy it!
#
#
# Full Story
#
#
# Posted by Tony Albrecht
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Supercharging Data Delivery: The New League Patcher
#
#
#
# For the past 8 years, League has been using a patching system called RADS (Riot Application Distribution System) to deliver updates. RADS is a custom patching solution based on binary deltas that we built with League in mind. While RADS has served us well, we felt we had an opportunity to improve some key areas of the patching experience. We knew we could deliver updates much more quickly and more reliably by using a fundamentally different approach to patching, so we set out to build a brand new patcher based on content-defined chunking.
#
#
# Full Story
#
#
# Posted by Javier Blazquez
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The Riot Games API: Transforms
#
#
#
# Hello all, Leigh Estes, aka RiotSchmick, here. I’m a software engineer at Riot Games working on the Riot Developer Experience team. Our responsibilities include providing the edge infrastructure that supports both internal and external developers. I previously wrote a series on the infrastructure that supports our public API product. I’m excited to revisit this series to tell you more about a new part of our infrastructure - the feature we call transforms.
#
#
# Full Story
#
#
# Posted by Leigh Estes
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Key Conjurer: Our Policy of Least Privilege
#
#
#
# Hi, my name is Reza Nikoopour and I’m a security engineer on the Security team at Riot. My team is responsible for securing Riot infrastructure wherever we’re deployed - whether that means internal or external data centers or clouds. We provide cloud security guidance to the rest of Riot, and we’re responsible for Key Conjurer, our open source AWS API programmatic access solution.
#
#
# Full Story
#
#
# Posted by Reza Nikoopour
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Better Apps with React Server-Side Rendering
#
#
#
# Imagine you're a web developer. You have to create an app that leverages five different data sources. The project has 26 different views built in - and don’t forget to make it fast, easy to test, and reliable. I work on creating the tools that make this kind of app as easy as possible for developers to build and manage. My name is Matthew Drake and I’m a member of the Riot Data team.
#
#
# Full Story
#
#
# Posted by Matthew Drake
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Stocking Your Shop With Data Science
#
#
#
# Hey there, my name is Riley “WhoaNonstop” Howsden, and I’m a Data Scientist who works on League of Legends, focusing mainly on personalization. Over the last few years I’ve been a part of the launch team for “Your Shop,” a product within League that creates personalized offers for every player around the globe. Data scientists like me work with engineers, analysts, artists, and publishing to create experiences that players love. From matchmaking and player behavior to artificial intelligence and game balance, data science is a key contributor for many initiatives at Riot.
#
#
# Full Story
#
#
# Posted by Riley Howsden
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 404 Tech Blog Not Found: Welcome to the Bug Blog
#
#
#
# So, why do Bug Blogs? Well, at Riot, we believe that a fundamental component of the development process is understanding that failures can and do happen. We make mistakes because we’re humans, and humans are far from perfect. And that’s okay! What’s important is to recognize failures for what they are, work to understand why they happened, learn from them, and make needed changes based on those learnings. That’s how we grow and that’s how we get better.
#
#
# Full Story
#
#
# Posted by Jane Jeffers
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Reducing Rendering Complexity with Gun Goddess Miss Fortune
#
#
#
# Hi, my name is Eric Friedman, and I’m a Software Engineer who has been working on League of Legends for 8 years, focusing mainly on gameplay systems. For the last several years, I’ve been working in the Player Immersion and Expression (PIE) initiative, bringing you skins like Elementalist Lux and personalization options like Emotes. If you’re interested in how Elementalist Lux was implemented, check out our previous article. I’m excited to bring you another article about an ultimate skin, Gun Goddess Miss Fortune, and the technology it took to bring her to players.
#
#
# Full Story
#
#
# Posted by Eric Friedman
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Load More Articles
#
#
#
#
#
#
#
#
#
# architecture (22)automation (3)ci (11)data (7)deployment (15)game (25)infrastructure (23)leadership (4)performance (15)rendering (5)security (4)testing (3)video (5)web (5)
#
#
#
#
#
#
#
#
#
#
#
# Player Driven TechnologyWe're not technologists who just happen to be gamers, nor are we gamers who just happen to be technologists.  These are fundamental to our identity and we embrace them both. We’ve been absolutely delighted by games and we’ve been sorely disappointed by them.  At Riot we create technology to deliver players the former and shield them from the latter.
#
#
# Riot Games
#
#
#
#
# Company
#
#
# Who we are
#
#
# News
#
#
# Legal jibber jabber
#
#
# Security
#
#
# Contact infos
#
#
#
#
# Careers
#
#
# Riot with us
#
#
# Search open jobs
#
#
#
#
# Social
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# © 2019 Riot Games, Inc. All rights reserved. League of Legends and Riot Games are trademarks, service
# marks, or registered trademarks of Riot Games, Inc.
#
#
#
#
#
#
#
#
#
# jQuery.extend(Drupal.settings, {"basePath":"\/","pathPrefix":"","ajaxPageState":{"theme":"riot_games_engineering","theme_token":"1F5p39rz78uidzXnmRou3llrMdqnyCuXaNOfCQgEN3Q","jquery_version":"1.11","js":{"sites\/all\/modules\/jquery_update\/replace\/jquery\/1.11\/jquery.min.js":1,"misc\/jquery.once.js":1,"misc\/drupal.js":1,"sites\/all\/modules\/jquery_update\/replace\/ui\/external\/jquery.cookie.js":1,"sites\/all\/modules\/jquery_update\/replace\/misc\/jquery.form.min.js":1,"misc\/ajax.js":1,"sites\/all\/modules\/jquery_update\/js\/jquery_update.js":1,"sites\/all\/modules\/views_load_more\/views_load_more.js":1,"sites\/all\/modules\/views\/js\/base.js":1,"misc\/progress.js":1,"sites\/all\/modules\/views\/js\/ajax_view.js":1,"sites\/all\/themes\/riot_games_engineering\/dist\/production.min.js":1},"css":{"modules\/system\/system.base.css":1,"modules\/system\/system.messages.css":1,"sites\/all\/modules\/date\/date_api\/date.css":1,"sites\/all\/modules\/ckeditor\/css\/ckeditor.css":1,"sites\/all\/themes\/riot_games_engineering\/dist\/production.min.css":1}},"views":{"ajax_path":"\/views\/ajax","ajaxViews":{"views_dom_id:1e78c4ba60e49dc42521b1d3e444be71":{"view_name":"recent_news_articles","view_display_id":"block","view_args":"","view_path":"node","view_base_path":"news\/feed","view_dom_id":"1e78c4ba60e49dc42521b1d3e444be71","pager_element":0}}},"urlIsAjaxTrusted":{"\/views\/ajax":true}});
#
#
#         /**
#          * Pageview tracking - Fonts.com
#          */
#         eval(function(p,a,c,k,e,r){e=function(c){return c.toString(a)};if(!''.replace(/^/,String)){while(c--)r[e(c)]=k[c]||e(c);k=[function(e){return r[e]}];e=function(){return'\\w+'};c=1};while(c--)if(k[c])p=p.replace(new RegExp('\\b'+e(c)+'\\b','g'),k[c]);return p}('4 7=g.b;4 2=3.p(\'r\');2.9=\'a/5\';2.c=\'d\';2.e=(\'6:\'==3.u.h?\'6:\':\'i:\')+\'//j.k.l/t/1.5?m=n&o=\'+7;(3.8(\'q\')[0]||3.8(\'s\')[0]).f(2);',31,31,'||mtiTracking|document|var|css|https|projectId|getElementsByTagName|type|text|MTIProjectId|rel|stylesheet|href|appendChild|window|protocol|http|fast|fonts|net|apiType|css|projectid|createElement|head|link|body||location'.split('|'),0,{}))
#
#
# window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","licenseKey":"25a156d569","applicationID":"7806507","transactionName":"NAdQYEtTVkJXWhBeWw1NZ0ZQHRdYWF0BTxoTCkI=","queueTime":0,"applicationTime":12,"atts":"GEBTFgNJRUw=","errorBeacon":"bam.nr-data.net","agent":""}

# %%
soup.title
# Out:
# <title>Riot Games Technology</title>

# %%
soup.title.text
# Out:
# 'Riot Games Technology'

# %%
articles = soup.find_all('article')

# %%
articles
# Out:
# [<article class="c-excerpt views-row views-row-1 views-row-odd views-row-first" role="article">
#  <h1 class="c-excerpt__title">
#  <a href="/news/engineering-esports-tech-powers-worlds">Engineering Esports: The Tech That Powers Worlds</a></h1>
#  <a href="/news/engineering-esports-tech-powers-worlds">
#  <img alt="" class="u-images-respond c-excerpt__image" src="https://technology.riotgames.com/sites/default/files/articles/102/engineeringesportsheader.png"/>
#  </a>
#  <p dir="ltr">We’re the Esports Technology Group, and we’re responsible for the tech behind Riot’s biggest esports events, from reliable network connectivity to global broadcast capabilities to specialty tournament servers to the custom PC fleet used by pros. Part of our role at Riot is to approach typical broadcast and live production challenges with scalable and technology-driven solutions.</p>
#  <div class="c-excerpt-meta">
#  <a class="c-excerpt-meta__read-more c-content__link" href="/news/engineering-esports-tech-powers-worlds">
#  Full Story <i class="c-icon c-icon--right-circle"></i>
#  </a>
#  <div class="c-excerpt-meta__group">
#  <span class="c-excerpt-meta__author">Posted by The Esports Technology Group</span>
#  <ul class="o-list-inline c-excerpt-meta__social">
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--mail-alt c-excerpt-meta__link" href="/cdn-cgi/l/email-protection#">
#  <i class="c-icon c-icon--mail-alt"></i>
#  </a>
#  </li>
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--facebook c-excerpt-meta__link js-share" data-desc="This article describes the technical backbone of events like Worlds, including our networking solutions, broadcast tech, and PC fleet. " data-image="https://technology.riotgames.com/sites/default/files/articles/102/engineeringesportsheader.png" data-target="facebook" data-title="Engineering Esports: The Tech That Powers Worlds" data-url="https://technology.riotgames.com/news/engineering-esports-tech-powers-worlds" href="">
#  <i class="c-icon c-icon--facebook"></i>
#  </a>
#  </li>
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--twitter c-excerpt-meta__link js-share" data-target="twitter" data-title="Engineering Esports: The Tech That Powers Worlds https://riot.com/2IA6xi3" data-url="https://technology.riotgames.com/news/engineering-esports-tech-powers-worlds" href="">
#  <i class="c-icon c-icon--twitter"></i>
#  </a>
#  </li>
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--linkedin c-excerpt-meta__link js-share" data-desc="This article describes the technical backbone of events like Worlds, including our networking solutions, broadcast tech, and PC fleet. " data-target="linkedin" data-title="Engineering Esports: The Tech That Powers Worlds" data-url="https://technology.riotgames.com/news/engineering-esports-tech-powers-worlds" href="">
#  <i class="c-icon c-icon--linkedin"></i>
#  </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </article>,
#  <article class="c-excerpt views-row views-row-2 views-row-even" role="article">
#  <h1 class="c-excerpt__title">
#  <a href="/news/future-leagues-engine">The Future of League's Engine</a></h1>
#  <a href="/news/future-leagues-engine">
#  <img alt="" class="u-images-respond c-excerpt__image" src="https://technology.riotgames.com/sites/default/files/articles/101/leagueengineheader.png"/>
#  </a>
#  <p>Hiya folks, Brian "Penrif" Bossé, your local friendly Tech Lead of <em>League</em> here. I'm taking some time in between matches of TFT to wax philosophic about game engines and how we on <em>League</em> make decisions around what direction to take our custom game engine. Join me on a moderately long look at one dimension of game engine design, where <em>League</em> currently exists on that dimension, and where we're taking the game from there.</p>
#  <div class="c-excerpt-meta">
#  <a class="c-excerpt-meta__read-more c-content__link" href="/news/future-leagues-engine">
#  Full Story <i class="c-icon c-icon--right-circle"></i>
#  </a>
#  <div class="c-excerpt-meta__group">
#  <span class="c-excerpt-meta__author">Posted by Brian Bossé</span>
#  <ul class="o-list-inline c-excerpt-meta__social">
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--mail-alt c-excerpt-meta__link" href="/cdn-cgi/l/email-protection#">
#  <i class="c-icon c-icon--mail-alt"></i>
#  </a>
#  </li>
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--facebook c-excerpt-meta__link js-share" data-desc="Gaze into the future of the League of Legends game engine." data-image="https://technology.riotgames.com/sites/default/files/articles/101/leagueengineheader.png" data-target="facebook" data-title="The Future of League's Engine" data-url="https://technology.riotgames.com/news/future-leagues-engine" href="">
#  <i class="c-icon c-icon--facebook"></i>
#  </a>
#  </li>
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--twitter c-excerpt-meta__link js-share" data-target="twitter" data-title="The Future of League's Engine https://riot.com/2mtnKlf" data-url="https://technology.riotgames.com/news/future-leagues-engine" href="">
#  <i class="c-icon c-icon--twitter"></i>
#  </a>
#  </li>
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--linkedin c-excerpt-meta__link js-share" data-desc="Gaze into the future of the League of Legends game engine." data-target="linkedin" data-title="The Future of League's Engine" data-url="https://technology.riotgames.com/news/future-leagues-engine" href="">
#  <i class="c-icon c-icon--linkedin"></i>
#  </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </article>,
#  <article class="c-excerpt views-row views-row-3 views-row-odd" role="article">
#  <h1 class="c-excerpt__title">
#  <a href="/news/down-rabbit-hole-performance-monitoring">Down The Rabbit Hole of Performance Monitoring</a></h1>
#  <a href="/news/down-rabbit-hole-performance-monitoring">
#  <img alt="" class="u-images-respond c-excerpt__image" src="https://technology.riotgames.com/sites/default/files/articles/100/rabbitholeheader.png"/>
#  </a>
#  <p>Hi, I’m Tony, and I’m an engineer on <em>League</em>. This article is a followup to my <a href="https://technology.riotgames.com/news/profiling-measurement-and-analysis" target="_blank">performance series</a>, where I talk about optimisation and profiling. This will be a high level overview of how we monitor game performance in <em>League of Legends</em>, how we detect when a performance degradation has slipped through QA and escaped into the wild, and how we track global trends in frame times over many patches and millions of players. I hope you enjoy it!</p>
#  <div class="c-excerpt-meta">
#  <a class="c-excerpt-meta__read-more c-content__link" href="/news/down-rabbit-hole-performance-monitoring">
#  Full Story <i class="c-icon c-icon--right-circle"></i>
#  </a>
#  <div class="c-excerpt-meta__group">
#  <span class="c-excerpt-meta__author">Posted by Tony Albrecht</span>
#  <ul class="o-list-inline c-excerpt-meta__social">
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--mail-alt c-excerpt-meta__link" href="/cdn-cgi/l/email-protection#">
#  <i class="c-icon c-icon--mail-alt"></i>
#  </a>
#  </li>
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--facebook c-excerpt-meta__link js-share" data-desc="Join Tony on his trip down the rabbit hole of monitoring frame rates to track game performance in League of Legends." data-image="https://technology.riotgames.com/sites/default/files/articles/100/rabbitholeheader.png" data-target="facebook" data-title="Down The Rabbit Hole of Performance Monitoring" data-url="https://technology.riotgames.com/news/down-rabbit-hole-performance-monitoring" href="">
#  <i class="c-icon c-icon--facebook"></i>
#  </a>
#  </li>
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--twitter c-excerpt-meta__link js-share" data-target="twitter" data-title="Down The Rabbit Hole of Performance Monitoring https://riot.com/2ZgWWSV" data-url="https://technology.riotgames.com/news/down-rabbit-hole-performance-monitoring" href="">
#  <i class="c-icon c-icon--twitter"></i>
#  </a>
#  </li>
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--linkedin c-excerpt-meta__link js-share" data-desc="Join Tony on his trip down the rabbit hole of monitoring frame rates to track game performance in League of Legends." data-target="linkedin" data-title="Down The Rabbit Hole of Performance Monitoring" data-url="https://technology.riotgames.com/news/down-rabbit-hole-performance-monitoring" href="">
#  <i class="c-icon c-icon--linkedin"></i>
#  </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </article>,
#  <article class="c-excerpt views-row views-row-4 views-row-even" role="article">
#  <h1 class="c-excerpt__title">
#  <a href="/news/supercharging-data-delivery-new-league-patcher">Supercharging Data Delivery: The New League Patcher</a></h1>
#  <a href="/news/supercharging-data-delivery-new-league-patcher">
#  <img alt="" class="u-images-respond c-excerpt__image" src="https://technology.riotgames.com/sites/default/files/articles/99/750x260b.jpg"/>
#  </a>
#  <p>For the past 8 years,<em> League</em> has been using a patching system called RADS (Riot Application Distribution System) to deliver updates. RADS is a custom patching solution based on binary deltas that we built with <em>League</em> in mind. While RADS has served us well, we felt we had an opportunity to improve some key areas of the patching experience. We knew we could deliver updates much more quickly and more reliably by using a fundamentally different approach to patching, so we set out to build a brand new patcher based on content-defined chunking.</p>
#  <div class="c-excerpt-meta">
#  <a class="c-excerpt-meta__read-more c-content__link" href="/news/supercharging-data-delivery-new-league-patcher">
#  Full Story <i class="c-icon c-icon--right-circle"></i>
#  </a>
#  <div class="c-excerpt-meta__group">
#  <span class="c-excerpt-meta__author">Posted by Javier Blazquez</span>
#  <ul class="o-list-inline c-excerpt-meta__social">
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--mail-alt c-excerpt-meta__link" href="/cdn-cgi/l/email-protection#">
#  <i class="c-icon c-icon--mail-alt"></i>
#  </a>
#  </li>
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--facebook c-excerpt-meta__link js-share" data-desc="Learn more about the tech powering League's new patcher." data-image="https://technology.riotgames.com/sites/default/files/articles/99/750x260b.jpg" data-target="facebook" data-title="Supercharging Data Delivery: The New League Patcher" data-url="https://technology.riotgames.com/news/supercharging-data-delivery-new-league-patcher" href="">
#  <i class="c-icon c-icon--facebook"></i>
#  </a>
#  </li>
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--twitter c-excerpt-meta__link js-share" data-target="twitter" data-title="Supercharging Data Delivery: The New League Patcher https://riot.com/2JFu5De" data-url="https://technology.riotgames.com/news/supercharging-data-delivery-new-league-patcher" href="">
#  <i class="c-icon c-icon--twitter"></i>
#  </a>
#  </li>
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--linkedin c-excerpt-meta__link js-share" data-desc="Learn more about the tech powering League's new patcher." data-target="linkedin" data-title="Supercharging Data Delivery: The New League Patcher" data-url="https://technology.riotgames.com/news/supercharging-data-delivery-new-league-patcher" href="">
#  <i class="c-icon c-icon--linkedin"></i>
#  </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </article>,
#  <article class="c-excerpt views-row views-row-5 views-row-odd" role="article">
#  <h1 class="c-excerpt__title">
#  <a href="/news/riot-games-api-transforms">The Riot Games API: Transforms</a></h1>
#  <a href="/news/riot-games-api-transforms">
#  <img alt="" class="u-images-respond c-excerpt__image" src="https://technology.riotgames.com/sites/default/files/articles/98/apitransformsheader.png"/>
#  </a>
#  <p>Hello all, Leigh Estes, aka RiotSchmick, here. I’m a software engineer at Riot Games working on the Riot Developer Experience team. Our responsibilities include providing the edge infrastructure that supports both internal and external developers. I previously wrote <a href="https://engineering.riotgames.com/news/riot-games-api-goals-and-design" target="_blank">a series</a> on the infrastructure that supports our public API product. I’m excited to revisit this series to tell you more about a new part of our infrastructure - the feature we call transforms.</p>
#  <div class="c-excerpt-meta">
#  <a class="c-excerpt-meta__read-more c-content__link" href="/news/riot-games-api-transforms">
#  Full Story <i class="c-icon c-icon--right-circle"></i>
#  </a>
#  <div class="c-excerpt-meta__group">
#  <span class="c-excerpt-meta__author">Posted by Leigh Estes</span>
#  <ul class="o-list-inline c-excerpt-meta__social">
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--mail-alt c-excerpt-meta__link" href="/cdn-cgi/l/email-protection#">
#  <i class="c-icon c-icon--mail-alt"></i>
#  </a>
#  </li>
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--facebook c-excerpt-meta__link js-share" data-desc="Learn how the Riot Games API team used transforms to build a generic, robust, and extensible system. " data-image="https://technology.riotgames.com/sites/default/files/articles/98/apitransformsheader.png" data-target="facebook" data-title="The Riot Games API: Transforms" data-url="https://technology.riotgames.com/news/riot-games-api-transforms" href="">
#  <i class="c-icon c-icon--facebook"></i>
#  </a>
#  </li>
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--twitter c-excerpt-meta__link js-share" data-target="twitter" data-title="The Riot Games API: Transforms https://riot.com/2LwfH1w" data-url="https://technology.riotgames.com/news/riot-games-api-transforms" href="">
#  <i class="c-icon c-icon--twitter"></i>
#  </a>
#  </li>
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--linkedin c-excerpt-meta__link js-share" data-desc="Learn how the Riot Games API team used transforms to build a generic, robust, and extensible system. " data-target="linkedin" data-title="The Riot Games API: Transforms" data-url="https://technology.riotgames.com/news/riot-games-api-transforms" href="">
#  <i class="c-icon c-icon--linkedin"></i>
#  </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </article>,
#  <article class="c-excerpt views-row views-row-6 views-row-even" role="article">
#  <h1 class="c-excerpt__title">
#  <a href="/news/key-conjurer-our-policy-least-privilege">Key Conjurer: Our Policy of Least Privilege</a></h1>
#  <a href="/news/key-conjurer-our-policy-least-privilege">
#  <img alt="" class="u-images-respond c-excerpt__image" src="https://technology.riotgames.com/sites/default/files/articles/97/keyconjurerheader.png"/>
#  </a>
#  <p>Hi, my name is Reza Nikoopour and I’m a security engineer on the Security team at Riot. My team is responsible for securing Riot infrastructure wherever we’re deployed - whether that means internal or external data centers or clouds. We provide cloud security guidance to the rest of Riot, and we’re responsible for <a href="https://github.com/RiotGames/key-conjurer" target="_blank">Key Conjurer</a>, our open source AWS API programmatic access solution. </p>
#  <div class="c-excerpt-meta">
#  <a class="c-excerpt-meta__read-more c-content__link" href="/news/key-conjurer-our-policy-least-privilege">
#  Full Story <i class="c-icon c-icon--right-circle"></i>
#  </a>
#  <div class="c-excerpt-meta__group">
#  <span class="c-excerpt-meta__author">Posted by Reza Nikoopour</span>
#  <ul class="o-list-inline c-excerpt-meta__social">
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--mail-alt c-excerpt-meta__link" href="/cdn-cgi/l/email-protection#">
#  <i class="c-icon c-icon--mail-alt"></i>
#  </a>
#  </li>
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--facebook c-excerpt-meta__link js-share" data-desc="Learn more about Key Conjurer, our open-sourced temporary AWS API key solution." data-image="https://technology.riotgames.com/sites/default/files/articles/97/keyconjurerheader.png" data-target="facebook" data-title="Key Conjurer: Our Policy of Least Privilege" data-url="https://technology.riotgames.com/news/key-conjurer-our-policy-least-privilege" href="">
#  <i class="c-icon c-icon--facebook"></i>
#  </a>
#  </li>
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--twitter c-excerpt-meta__link js-share" data-target="twitter" data-title="Key Conjurer: Our Policy of Least Privilege https://riot.com/2Fn5QXH" data-url="https://technology.riotgames.com/news/key-conjurer-our-policy-least-privilege" href="">
#  <i class="c-icon c-icon--twitter"></i>
#  </a>
#  </li>
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--linkedin c-excerpt-meta__link js-share" data-desc="Learn more about Key Conjurer, our open-sourced temporary AWS API key solution." data-target="linkedin" data-title="Key Conjurer: Our Policy of Least Privilege" data-url="https://technology.riotgames.com/news/key-conjurer-our-policy-least-privilege" href="">
#  <i class="c-icon c-icon--linkedin"></i>
#  </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </article>,
#  <article class="c-excerpt views-row views-row-7 views-row-odd" role="article">
#  <h1 class="c-excerpt__title">
#  <a href="/news/better-apps-react-server-side-rendering">Better Apps with React Server-Side Rendering</a></h1>
#  <a href="/news/better-apps-react-server-side-rendering">
#  <img alt="" class="u-images-respond c-excerpt__image" src="https://technology.riotgames.com/sites/default/files/articles/96/betterappsheader.png"/>
#  </a>
#  <p dir="ltr">Imagine you're a web developer. You have to create an app that leverages five different data sources. The project has 26 different views built in - and don’t forget to make it fast, easy to test, and reliable. I work on creating the tools that make this kind of app as easy as possible for developers to build and manage. My name is Matthew Drake and I’m a member of the Riot Data team.</p>
#  <div class="c-excerpt-meta">
#  <a class="c-excerpt-meta__read-more c-content__link" href="/news/better-apps-react-server-side-rendering">
#  Full Story <i class="c-icon c-icon--right-circle"></i>
#  </a>
#  <div class="c-excerpt-meta__group">
#  <span class="c-excerpt-meta__author">Posted by Matthew Drake</span>
#  <ul class="o-list-inline c-excerpt-meta__social">
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--mail-alt c-excerpt-meta__link" href="/cdn-cgi/l/email-protection#">
#  <i class="c-icon c-icon--mail-alt"></i>
#  </a>
#  </li>
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--facebook c-excerpt-meta__link js-share" data-desc="Try out this tutorial on using React server-side rendering with data store injection to make your web apps more responsive, easier to test, and better at scale. " data-image="https://technology.riotgames.com/sites/default/files/articles/96/betterappsheader.png" data-target="facebook" data-title="Better Apps with React Server-Side Rendering" data-url="https://technology.riotgames.com/news/better-apps-react-server-side-rendering" href="">
#  <i class="c-icon c-icon--facebook"></i>
#  </a>
#  </li>
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--twitter c-excerpt-meta__link js-share" data-target="twitter" data-title="Better Apps with React Server-Side Rendering https://riot.com/2X2gNER" data-url="https://technology.riotgames.com/news/better-apps-react-server-side-rendering" href="">
#  <i class="c-icon c-icon--twitter"></i>
#  </a>
#  </li>
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--linkedin c-excerpt-meta__link js-share" data-desc="Try out this tutorial on using React server-side rendering with data store injection to make your web apps more responsive, easier to test, and better at scale. " data-target="linkedin" data-title="Better Apps with React Server-Side Rendering" data-url="https://technology.riotgames.com/news/better-apps-react-server-side-rendering" href="">
#  <i class="c-icon c-icon--linkedin"></i>
#  </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </article>,
#  <article class="c-excerpt views-row views-row-8 views-row-even" role="article">
#  <h1 class="c-excerpt__title">
#  <a href="/news/stocking-your-shop-data-science"> Stocking Your Shop With Data Science</a></h1>
#  <a href="/news/stocking-your-shop-data-science">
#  <img alt="" class="u-images-respond c-excerpt__image" src="https://technology.riotgames.com/sites/default/files/articles/95/recommenderheader.png"/>
#  </a>
#  <p dir="ltr">Hey there, my name is Riley “WhoaNonstop” Howsden, and I’m a Data Scientist who works on <em>League of Legends</em>, focusing mainly on personalization. Over the last few years I’ve been a part of the launch team for “<a href="https://na.leagueoflegends.com/en/tag/your-shop" target="_blank">Your Shop</a>,” a product within <em>League </em>that creates personalized offers for every player around the globe. Data scientists like me work with engineers, analysts, artists, and publishing to create experiences that players love. From matchmaking and player behavior to artificial intelligence and game balance, data science is a key contributor for many initiatives at Riot. </p>
#  <div class="c-excerpt-meta">
#  <a class="c-excerpt-meta__read-more c-content__link" href="/news/stocking-your-shop-data-science">
#  Full Story <i class="c-icon c-icon--right-circle"></i>
#  </a>
#  <div class="c-excerpt-meta__group">
#  <span class="c-excerpt-meta__author">Posted by Riley Howsden</span>
#  <ul class="o-list-inline c-excerpt-meta__social">
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--mail-alt c-excerpt-meta__link" href="/cdn-cgi/l/email-protection#">
#  <i class="c-icon c-icon--mail-alt"></i>
#  </a>
#  </li>
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--facebook c-excerpt-meta__link js-share" data-desc="Learn about the data science and machine learning behind Your Shop." data-image="https://technology.riotgames.com/sites/default/files/articles/95/recommenderheader.png" data-target="facebook" data-title="Stocking Your Shop With Data Science " data-url="https://technology.riotgames.com/news/stocking-your-shop-data-science" href="">
#  <i class="c-icon c-icon--facebook"></i>
#  </a>
#  </li>
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--twitter c-excerpt-meta__link js-share" data-target="twitter" data-title="Stocking Your Shop With Data Science https://riot.com/2J1O8f7" data-url="https://technology.riotgames.com/news/stocking-your-shop-data-science" href="">
#  <i class="c-icon c-icon--twitter"></i>
#  </a>
#  </li>
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--linkedin c-excerpt-meta__link js-share" data-desc="Learn about the data science and machine learning behind Your Shop." data-target="linkedin" data-title="Stocking Your Shop With Data Science " data-url="https://technology.riotgames.com/news/stocking-your-shop-data-science" href="">
#  <i class="c-icon c-icon--linkedin"></i>
#  </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </article>,
#  <article class="c-excerpt views-row views-row-9 views-row-odd" role="article">
#  <h1 class="c-excerpt__title">
#  <a href="/news/404-tech-blog-not-found-welcome-bug-blog">404 Tech Blog Not Found: Welcome to the Bug Blog</a></h1>
#  <a href="/news/404-tech-blog-not-found-welcome-bug-blog">
#  <img alt="" class="u-images-respond c-excerpt__image" src="https://technology.riotgames.com/sites/default/files/articles/94/bugseriesheaderlogofinal.png"/>
#  </a>
#  <p dir="ltr">So, why do Bug Blogs? Well, at Riot, we believe that a fundamental component of the development process is understanding that failures can and do happen. We make mistakes because we’re humans, and humans are far from perfect. And that’s okay! What’s important is to recognize failures for what they are, work to understand why they happened, learn from them, and make needed changes based on those learnings. That’s how we grow and that’s how we get better.</p>
#  <div class="c-excerpt-meta">
#  <a class="c-excerpt-meta__read-more c-content__link" href="/news/404-tech-blog-not-found-welcome-bug-blog">
#  Full Story <i class="c-icon c-icon--right-circle"></i>
#  </a>
#  <div class="c-excerpt-meta__group">
#  <span class="c-excerpt-meta__author">Posted by Jane Jeffers</span>
#  <ul class="o-list-inline c-excerpt-meta__social">
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--mail-alt c-excerpt-meta__link" href="/cdn-cgi/l/email-protection#">
#  <i class="c-icon c-icon--mail-alt"></i>
#  </a>
#  </li>
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--facebook c-excerpt-meta__link js-share" data-desc="Jane the QA de-tech-tive reveals the story of the fearless technologists who saved the Worlds 2014 patches, and the tech behind the bugs they squashed." data-image="https://technology.riotgames.com/sites/default/files/articles/94/bugseriesheaderlogofinal.png" data-target="facebook" data-title="404 Tech Blog Not Found: Welcome to the Bug Blog" data-url="https://technology.riotgames.com/news/404-tech-blog-not-found-welcome-bug-blog" href="">
#  <i class="c-icon c-icon--facebook"></i>
#  </a>
#  </li>
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--twitter c-excerpt-meta__link js-share" data-target="twitter" data-title="404 Tech Blog Not Found: Welcome to the Bug Blog https://riot.com/2Ofx7P0" data-url="https://technology.riotgames.com/news/404-tech-blog-not-found-welcome-bug-blog" href="">
#  <i class="c-icon c-icon--twitter"></i>
#  </a>
#  </li>
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--linkedin c-excerpt-meta__link js-share" data-desc="Jane the QA de-tech-tive reveals the story of the fearless technologists who saved the Worlds 2014 patches, and the tech behind the bugs they squashed." data-target="linkedin" data-title="404 Tech Blog Not Found: Welcome to the Bug Blog" data-url="https://technology.riotgames.com/news/404-tech-blog-not-found-welcome-bug-blog" href="">
#  <i class="c-icon c-icon--linkedin"></i>
#  </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </article>,
#  <article class="c-excerpt views-row views-row-10 views-row-even views-row-last" role="article">
#  <h1 class="c-excerpt__title">
#  <a href="/news/reducing-rendering-complexity-gun-goddess-miss-fortune">Reducing Rendering Complexity with Gun Goddess Miss Fortune</a></h1>
#  <a href="/news/reducing-rendering-complexity-gun-goddess-miss-fortune">
#  <img alt="" class="u-images-respond c-excerpt__image" src="https://technology.riotgames.com/sites/default/files/articles/93/ggmfheader.png"/>
#  </a>
#  <p>Hi, my name is Eric Friedman, and I’m a Software Engineer who has been working on <em>League of Legend</em>s for 8 years, focusing mainly on gameplay systems. For the last several years, I’ve been working in the Player Immersion and Expression (PIE) initiative, bringing you skins like <a href="https://www.youtube.com/watch?v=fjrfYZsZLJA" target="_blank">Elementalist Lux</a> and personalization options like <a href="https://na.leagueoflegends.com/en/page/emotes-are-live" target="_blank">Emotes</a>. If you’re interested in how Elementalist Lux was implemented, check out <a href="https://engineering.riotgames.com/news/elementalist-lux" target="_blank">our previous article</a>. I’m excited to bring you another article about an ultimate skin, Gun Goddess Miss Fortune, and the technology it took to bring her to players.</p>
#  <div class="c-excerpt-meta">
#  <a class="c-excerpt-meta__read-more c-content__link" href="/news/reducing-rendering-complexity-gun-goddess-miss-fortune">
#  Full Story <i class="c-icon c-icon--right-circle"></i>
#  </a>
#  <div class="c-excerpt-meta__group">
#  <span class="c-excerpt-meta__author">Posted by Eric Friedman</span>
#  <ul class="o-list-inline c-excerpt-meta__social">
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--mail-alt c-excerpt-meta__link" href="/cdn-cgi/l/email-protection#">
#  <i class="c-icon c-icon--mail-alt"></i>
#  </a>
#  </li>
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--facebook c-excerpt-meta__link js-share" data-desc="Building a new tool called SkinnedRenderable to improve content pipelines and reduce rendering complexity." data-image="https://technology.riotgames.com/sites/default/files/articles/93/ggmfheader.png" data-target="facebook" data-title="Reducing Rendering Complexity with Gun Goddess Miss Fortune" data-url="https://technology.riotgames.com/news/reducing-rendering-complexity-gun-goddess-miss-fortune" href="">
#  <i class="c-icon c-icon--facebook"></i>
#  </a>
#  </li>
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--twitter c-excerpt-meta__link js-share" data-target="twitter" data-title="Reducing Rendering Complexity with Gun Goddess Miss Fortune https://riot.com/2TOzoCG" data-url="https://technology.riotgames.com/news/reducing-rendering-complexity-gun-goddess-miss-fortune" href="">
#  <i class="c-icon c-icon--twitter"></i>
#  </a>
#  </li>
#  <li class="c-social__item c-excerpt-meta__item">
#  <a class="c-social__link c-social__link--linkedin c-excerpt-meta__link js-share" data-desc="Building a new tool called SkinnedRenderable to improve content pipelines and reduce rendering complexity." data-target="linkedin" data-title="Reducing Rendering Complexity with Gun Goddess Miss Fortune" data-url="https://technology.riotgames.com/news/reducing-rendering-complexity-gun-goddess-miss-fortune" href="">
#  <i class="c-icon c-icon--linkedin"></i>
#  </a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </article>]

# %%
len(articles)
# Out:
# 10

# %%
articles[0]
# Out:
# <article class="c-excerpt views-row views-row-1 views-row-odd views-row-first" role="article">
# <h1 class="c-excerpt__title">
# <a href="/news/engineering-esports-tech-powers-worlds">Engineering Esports: The Tech That Powers Worlds</a></h1>
# <a href="/news/engineering-esports-tech-powers-worlds">
# <img alt="" class="u-images-respond c-excerpt__image" src="https://technology.riotgames.com/sites/default/files/articles/102/engineeringesportsheader.png"/>
# </a>
# <p dir="ltr">We’re the Esports Technology Group, and we’re responsible for the tech behind Riot’s biggest esports events, from reliable network connectivity to global broadcast capabilities to specialty tournament servers to the custom PC fleet used by pros. Part of our role at Riot is to approach typical broadcast and live production challenges with scalable and technology-driven solutions.</p>
# <div class="c-excerpt-meta">
# <a class="c-excerpt-meta__read-more c-content__link" href="/news/engineering-esports-tech-powers-worlds">
# Full Story <i class="c-icon c-icon--right-circle"></i>
# </a>
# <div class="c-excerpt-meta__group">
# <span class="c-excerpt-meta__author">Posted by The Esports Technology Group</span>
# <ul class="o-list-inline c-excerpt-meta__social">
# <li class="c-social__item c-excerpt-meta__item">
# <a class="c-social__link c-social__link--mail-alt c-excerpt-meta__link" href="/cdn-cgi/l/email-protection#">
# <i class="c-icon c-icon--mail-alt"></i>
# </a>
# </li>
# <li class="c-social__item c-excerpt-meta__item">
# <a class="c-social__link c-social__link--facebook c-excerpt-meta__link js-share" data-desc="This article describes the technical backbone of events like Worlds, including our networking solutions, broadcast tech, and PC fleet. " data-image="https://technology.riotgames.com/sites/default/files/articles/102/engineeringesportsheader.png" data-target="facebook" data-title="Engineering Esports: The Tech That Powers Worlds" data-url="https://technology.riotgames.com/news/engineering-esports-tech-powers-worlds" href="">
# <i class="c-icon c-icon--facebook"></i>
# </a>
# </li>
# <li class="c-social__item c-excerpt-meta__item">
# <a class="c-social__link c-social__link--twitter c-excerpt-meta__link js-share" data-target="twitter" data-title="Engineering Esports: The Tech That Powers Worlds https://riot.com/2IA6xi3" data-url="https://technology.riotgames.com/news/engineering-esports-tech-powers-worlds" href="">
# <i class="c-icon c-icon--twitter"></i>
# </a>
# </li>
# <li class="c-social__item c-excerpt-meta__item">
# <a class="c-social__link c-social__link--linkedin c-excerpt-meta__link js-share" data-desc="This article describes the technical backbone of events like Worlds, including our networking solutions, broadcast tech, and PC fleet. " data-target="linkedin" data-title="Engineering Esports: The Tech That Powers Worlds" data-url="https://technology.riotgames.com/news/engineering-esports-tech-powers-worlds" href="">
# <i class="c-icon c-icon--linkedin"></i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </article>

# %%
articles[0].find('h1')
# Out:
# <h1 class="c-excerpt__title">
# <a href="/news/engineering-esports-tech-powers-worlds">Engineering Esports: The Tech That Powers Worlds</a></h1>

# %%
articles[0].find('h1').text
# Out:
# '\nEngineering Esports: The Tech That Powers Worlds'

# %%
links = articles[0].find('a')
links
# Out:
# <a href="/news/engineering-esports-tech-powers-worlds">Engineering Esports: The Tech That Powers Worlds</a>

# %%
links['href']
# Out:
# '/news/engineering-esports-tech-powers-worlds'

# %%
riot_articles = []
for article in articles:
    title = article.find('h1').text
    href = article.find('a')['href']
    desc = article.find('p').text
    riot_articles.append({
        'title': title,
        'href': href,
        'desc': desc
    })

# %%
riot_articles
# Out:
# [{'title': '\nEngineering Esports: The Tech That Powers Worlds',
#   'href': '/news/engineering-esports-tech-powers-worlds',
#   'desc': 'We’re the Esports Technology Group, and we’re responsible for the tech behind Riot’s biggest esports events, from reliable network connectivity to global broadcast capabilities to specialty tournament servers to the custom PC fleet used by pros. Part of our role at Riot is to approach typical broadcast and live production challenges with scalable and technology-driven solutions.'},
#  {'title': "\nThe Future of League's Engine",
#   'href': '/news/future-leagues-engine',
#   'desc': 'Hiya folks, Brian "Penrif" Bossé, your local friendly Tech Lead of\xa0League\xa0here. I\'m taking some time in between matches of TFT to wax philosophic about game engines and how we on\xa0League\xa0make decisions around what direction to take our custom game engine. Join me on a moderately long look at one dimension of game engine design, where\xa0League\xa0currently exists on that dimension, and where we\'re taking the game from there.'},
#  {'title': '\nDown The Rabbit Hole of Performance Monitoring',
#   'href': '/news/down-rabbit-hole-performance-monitoring',
#   'desc': 'Hi, I’m Tony, and I’m an engineer on\xa0League. This article is a followup to my\xa0performance series, where I talk about optimisation and profiling. This will be a high level overview of how we monitor game performance in\xa0League of Legends, how we detect when a performance degradation has slipped through QA and escaped into the wild, and how we track global trends in frame times over many patches and millions of players. I hope you enjoy it!'},
#  {'title': '\nSupercharging Data Delivery: The New League Patcher',
#   'href': '/news/supercharging-data-delivery-new-league-patcher',
#   'desc': 'For the past 8 years,\xa0League\xa0has been using a patching system called RADS (Riot Application Distribution System) to deliver updates. RADS is a custom patching solution based on binary deltas that we built with\xa0League\xa0in mind. While RADS has served us well, we felt we had an opportunity to improve some key areas of the patching experience. We knew we could deliver updates much more quickly and more reliably by using a fundamentally different approach to patching, so we set out to build a brand new patcher based on content-defined chunking.'},
#  {'title': '\nThe Riot Games API: Transforms',
#   'href': '/news/riot-games-api-transforms',
#   'desc': 'Hello all, Leigh Estes, aka RiotSchmick, here. I’m a software engineer at Riot Games working on the Riot Developer Experience team. Our responsibilities include providing the edge infrastructure that supports both internal and external developers. I previously wrote\xa0a series\xa0on the infrastructure that supports our public API product. I’m excited to revisit this series to tell you more about a new part of our infrastructure - the feature we call transforms.'},
#  {'title': '\nKey Conjurer: Our Policy of Least Privilege',
#   'href': '/news/key-conjurer-our-policy-least-privilege',
#   'desc': 'Hi, my name is Reza Nikoopour and I’m a security engineer on the Security team at Riot. My team is responsible for securing Riot infrastructure wherever we’re deployed - whether that means internal or external data centers or clouds. We provide cloud security guidance to the rest of Riot, and we’re responsible for\xa0Key Conjurer, our open source AWS API programmatic access solution.\xa0'},
#  {'title': '\nBetter Apps with React Server-Side Rendering',
#   'href': '/news/better-apps-react-server-side-rendering',
#   'desc': "Imagine you're a web developer. You have to create an app that leverages five different data sources. The project has 26 different views built in -\xa0and don’t forget to make it fast, easy to test, and reliable. I work on creating the tools that make this kind of app as easy as possible for developers to build and manage. My name is Matthew Drake and I’m a member of the Riot Data team."},
#  {'title': '\n Stocking Your Shop With Data Science',
#   'href': '/news/stocking-your-shop-data-science',
#   'desc': 'Hey there, my name is Riley “WhoaNonstop” Howsden, and I’m a Data Scientist who works on\xa0League of Legends, focusing mainly on personalization. Over the last few years I’ve been a part of the launch team for “Your Shop,” a product within\xa0League\xa0that creates personalized offers for every player around the globe. Data scientists like me work with engineers, analysts, artists, and publishing to create experiences that players love. From matchmaking and player behavior to artificial intelligence and game balance, data science is a key contributor for many initiatives at Riot.\xa0'},
#  {'title': '\n404 Tech Blog Not Found: Welcome to the Bug Blog',
#   'href': '/news/404-tech-blog-not-found-welcome-bug-blog',
#   'desc': 'So, why do Bug Blogs? Well, at Riot, we believe that a fundamental component of the development process is understanding that failures can and do happen. We make mistakes because we’re humans, and humans are far from perfect. And that’s okay! What’s important is to recognize failures for what they are, work to understand why they happened, learn from them, and make needed changes based on those learnings. That’s how we grow and that’s how we get better.'},
#  {'title': '\nReducing Rendering Complexity with Gun Goddess Miss Fortune',
#   'href': '/news/reducing-rendering-complexity-gun-goddess-miss-fortune',
#   'desc': 'Hi, my name is Eric Friedman, and I’m a Software Engineer who has been working on\xa0League of Legends for 8 years, focusing mainly on gameplay systems. For the last several years, I’ve been working in the Player Immersion and Expression (PIE) initiative, bringing you skins like\xa0Elementalist Lux\xa0and personalization options like\xa0Emotes. If you’re interested in how Elementalist Lux was implemented, check out\xa0our previous article. I’m excited to bring you another article about an ultimate skin, Gun Goddess Miss Fortune, and the technology it took to bring her to players.'}]

# %% [markdown]
# ## Exemplo - MercadoLivre

# %%
term = 'led'
request = requests.get(f'https://lista.mercadolivre.com.br/{term}')

# %%
soup = BeautifulSoup(request.text, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html class="no-js" data-country="BR" data-device="desktop" data-site="MLB" lang="pt-BR">
#  <head prefix="">
#   <title>
#    Led no Mercado Livre Brasil
#   </title>
#   <link href="//analytics.mlstatic.com" rel="preconnect"/>
#   <link href="//resources.mlstatic.com" rel="preconnect"/>
#   <link href="//static.mlstatic.com" rel="preconnect"/>
#   <link href="https://www.google-analytics.com" rel="preconnect"/>
#   <link href="https://www.google.com" rel="preconnect"/>
#   <link href="https://data.mercadolibre.com" rel="preconnect"/>
#   <link href="https://http2.mlstatic.com" rel="preconnect"/>
#   <link href="https://www.google.com.br" rel="preconnect"/>
#   <link href="https://stats.g.doubleclick.net" rel="preconnect"/>
#   <link href="//analytics.mercadolivre.com.br" rel="preconnect"/>
#   <link href="//analytics.mercadolivre.com" rel="preconnect"/>
#   <link href="//mlb-s1-p.mlstatic.com" rel="preconnect"/>
#   <link href="//mlb-s2-p.mlstatic.com" rel="preconnect"/>
#   <script>
#    document.documentElement.className = document.documentElement.className.replace('no-js', '');
#   </script>
#   <script type="text/javascript">
#    (window.NREUM||(NREUM={})).loader_config={xpid:"XQ4OVF5VGwECVlRbAQgB",licenseKey:"3009922991",applicationID:"22259696"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(23),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{l?l-=1:o(s||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:c.now();i("err",[t,n])}var i=t("handle"),a=t(24),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,p="nr@seenError",l=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(13),t(12),"addEventListener"in window&&t(6),c.xhrWrappable&&t(14),d=!0)}s.on("fn-start",function(t,e,n){d&&(l+=1)}),s.on("fn-err",function(t,e,n){d&&!n[p]&&(f(n,p,function(){return!0}),this.thrown=!0,o(n))}),s.on("fn-end",function(){d&&!this.thrown&&l>0&&(l-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(){j++,L=y.hash,this[u]=x.now()}function o(){j--,y.hash!==L&&i(0,!0);var t=x.now();this[h]=~~this[h]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+y,e])}function a(t,e){t.on(e,function(){this[e]=x.now()})}var s="-start",c="-end",f="-body",u="fn"+s,d="fn"+c,p="cb"+s,l="cb"+c,h="jsTime",m="fetch",v="addEventListener",w=window,y=w.location,x=t("loader");if(w[v]&&x.xhrWrappable){var g=t(10),b=t(11),E=t(8),R=t(6),O=t(13),C=t(7),P=t(14),T=t(9),N=t("ee"),S=N.get("tracer");t(16),x.features.spa=!0;var L,j=0;N.on(u,r),N.on(p,r),N.on(d,o),N.on(l,o),N.buffer([u,d,"xhr-done","xhr-resolved"]),R.buffer([u]),O.buffer(["setTimeout"+c,"clearTimeout"+s,u]),P.buffer([u,"new-xhr","send-xhr"+s]),C.buffer([m+s,m+"-done",m+f+s,m+f+c]),E.buffer(["newURL"]),g.buffer([u]),b.buffer(["propagate",p,l,"executor-err","resolve"+s]),S.buffer([u,"no-"+u]),T.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(P,"send-xhr"+s),a(N,"xhr-resolved"),a(N,"xhr-done"),a(C,m+s),a(C,m+"-done"),a(T,"new-jsonp"),a(T,"jsonp-end"),a(T,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,!0),w[v]("load",i,!0),w[v]("popstate",function(){i(0,j>1)},!0)}},{}],5:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(13),s=t(12),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",p="resource",l="-start",h="-end",m="fn"+l,v="fn"+h,w="bstTimer",y="pushState",x=t("loader");x.features.stn=!0,t(8);var g=NREUM.o.EV;o.on(m,function(t,e){var n=t[0];n instanceof g&&(this.bstStart=x.now())}),o.on(v,function(t,e){var n=t[0];n instanceof g&&i("bst",[n,e,this.bstStart,x.now()])}),a.on(m,function(t,e,n){this.bstStart=x.now(),this.bstType=n}),a.on(v,function(t,e){i(w,[e,this.bstStart,x.now(),this.bstType])}),s.on(m,function(){this.bstStart=x.now()}),s.on(v,function(t,e){i(w,[e,this.bstStart,x.now(),"requestAnimationFrame"])}),o.on(y+l,function(t){this.time=x.now(),this.startPath=location.pathname+location.hash}),o.on(y+h,function(t){i("bstHist",[location ...
#   </script>
#   <meta charset="utf-8"/>
#   <noscript>
#    <meta content="0;URL=https://www.mercadolivre.com.br/gz/webdevice/config?go=https%3A%2F%2Flista.mercadolivre.com.br%2Fled&amp;noscript=true" http-equiv="refresh"/>
#   </noscript>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#   <meta content="on" http-equiv="cleartype"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <link href="https://http2.mlstatic.com/ui/navigation/5.3.5/mercadolibre/favicon.ico" rel="shortcut icon"/>
#   <link href="https://http2.mlstatic.com/ui/navigation/5.3.5/mercadolibre/60x60-precomposed.png" rel="apple-touch-icon"/>
#   <link href="https://http2.mlstatic.com/ui/navigation/5.3.5/mercadolibre/76x76-precomposed.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="https://http2.mlstatic.com/ui/navigation/5.3.5/mercadolibre/120x120-precomposed.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="https://http2.mlstatic.com/ui/navigation/5.3.5/mercadolibre/152x152-precomposed.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link as="font" crossorigin="true" href="https://http2.mlstatic.com/ui/webfonts/v4.0.0/proxima-nova/proxima-nova-300.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="true" href="https://http2.mlstatic.com/ui/webfonts/v4.0.0/proxima-nova/proxima-nova-400.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="true" href="https://http2.mlstatic.com/ui/webfonts/v4.0.0/proxima-nova/proxima-nova-600.woff2" rel="preload" type="font/woff2"/>
#   <style>
#    @font-face {
# 	font-family: 'Proxima Nova';
# 	font-weight: 300;
# 	font-style: normal;
# 	font-display: swap;
# 	src: url('https://http2.mlstatic.com/ui/webfonts/v4.0.0/proxima-nova/proxima-nova-300.eot');
# 	src: url('https://http2.mlstatic.com/ui/webfonts/v4.0.0/proxima-nova/proxima-nova-300.eot?#iefix') format('embedded-opentype'),
# 		url('https://http2.mlstatic.com/ui/webfonts/v4.0.0/proxima-nova/proxima-nova-300.woff2') format('woff2'),
# 		url('https://http2.mlstatic.com/ui/webfonts/v4.0.0/proxima-nova/proxima-nova-300.woff') format('woff'),
# 		url('https://http2.mlstatic.com/ui/webfonts/v4.0.0/proxima-nova/proxima-nova-300.ttf') format('truetype');
# }
#
# @font-face {
# 	font-family: 'Proxima Nova';
# 	font-weight: 400;
# 	font-style: normal;
# 	font-display: swap;
# 	src: url('https://http2.mlstatic.com/ui/webfonts/v4.0.0/proxima-nova/proxima-nova-400.eot');
# 	src: url('https://http2.mlstatic.com/ui/webfonts/v4.0.0/proxima-nova/proxima-nova-400.eot?#iefix') format('embedded-opentype'),
# 		url('https://http2.mlstatic.com/ui/webfonts/v4.0.0/proxima-nova/proxima-nova-400.woff2') format('woff2'),
# 		url('https://http2.mlstatic.com/ui/webfonts/v4.0.0/proxima-nova/proxima-nova-400.woff') format('woff'),
# 		url('https://http2.mlstatic.com/ui/webfonts/v4.0.0/proxima-nova/proxima-nova-400.ttf') format('truetype');
# }
#
# @font-face {
# 	font-family: 'Proxima Nova';
# 	font-weight: 600;
# 	font-style: normal;
# 	font-display: swap;
# 	src: url('https://http2.mlstatic.com/ui/webfonts/v4.0.0/proxima-nova/proxima-nova-600.eot');
# 	src: url('https://http2.mlstatic.com/ui/webfonts/v4.0.0/proxima-nova/proxima-nova-600.eot?#iefix') format('embedded-opentype'),
# 		url('https://http2.mlstatic.com/ui/webfonts/v4.0.0/proxima-nova/proxima-nova-600.woff2') format('woff2'),
# 		url('https://http2.mlstatic.com/ui/webfonts/v4.0.0/proxima-nova/proxima-nova-600.woff') format('woff'),
# 		url('https://http2.mlstatic.com/ui/webfonts/v4.0.0/proxima-nova/proxima-nova-600.ttf') format('truetype');
# }
#   </style>
#   <link href="https://http2.mlstatic.com/ui/navigation/5.3.5/mercadolibre/navigation-mobile-MLB.css" media="(max-width: 1023px)" rel="stylesheet" type="text/css"/>
#   <link href="https://http2.mlstatic.com/ui/navigation/5.3.5/mercadolibre/navigation-desktop-MLB.css" media="(min-width: 1024px)" rel="stylesheet" type="text/css"/>
#   <link href="https://http2.mlstatic.com/resources/frontend/commons-frontend/ui-dist/css/bundle__menu_ML_desktop_plus.32d5c0ba.css" rel="stylesheet" type="text/css"/>
#   <meta charset="utf-8"/>
#   <meta content="19f9f773-e2e2-4150-826b-67757d7e8b7f" name="csrf-token"/>
#   <link class="andes-pagination__link" href="https://lista.mercadolivre.com.br/led_Desde_51" rel="next"/>
#   <meta content="Encontre Led no Mercado Livre Brasil. Descubra a melhor forma de comprar online." name="description"/>
#   <link href="https://lista.mercadolivre.com.br/led" rel="canonical"/>
#   <link href="android-app://com.mercadolibre/meli/search?go=https%3A%2F%2Flista.mercadolivre.com.br%2Fled" rel="alternate"/>
#   <link href="ios-app://463624852/meli/search?go=https%3A%2F%2Flista.mercadolivre.com.br%2Fled" rel="alternate"/>
#   <link href="https://http2.mlstatic.com/resources/search-css/MLB/STD/14.23.0/bundle-core__large" rel="stylesheet" type="text/css"/>
#   <script type="text/javascript">
#    (function(a,b){a.GoogleAnalyticsObject=b;a['MeliAnalyticsData'] = {'dimensions':''};a[b]=a[b]||function(){(a[b].q=a[b].q||[]).push(arguments)};a[b].l=1*new Date})(window,"meli_ga");
# meli_ga("set", "title", "app-search-frontend-0.19.8");
# meli_ga("set", "page", "/SEARCH/LISTING/?q=led");
# meli_ga("set", "dimension22", "50");
# meli_ga("set", "dimension23", "NONE_IN");
# meli_ga("set", "dimension21", "115");
# meli_ga("set", "dimension125", "2737");
# meli_ga("set", "dimension117", "officialStore");
# meli_ga("set", "dimension25", "{'mclics\/ads-adsearch-boost-incremental-desktop-mlb':2737,'pads-in-lst':144,'mclics\/search-bottom-desktop-mlb':2434,'mclics\/search-pads-none-desktop-mlb':3485,'mclics\/upper-funnel':'DEFAULT','mclics\/search-recommended-btm-mlb':3084,'search\/sold-quantity':3292,'frontend\/assetsCdnDomainMLB':'DEFAULT'}");
# meli_ga("set", "dimension3", "(none)");
# meli_ga("set", "contentGroup1", "/MARKETPLACE/SEARCH/LISTING/");
# meli_ga("set", "contentGroup2", "/CORE/SEARCH/LISTING/");
# meli_ga("set", "contentGroup3", "/NONE/SEARCH/LISTING/");
# meli_ga("set", "dimension1", "desktop");
# meli_ga("set", "dimension6", "listing");
# meli_ga("set", "dimension7", "MARKETPLACE");
# meli_ga("set", "dimension8", "CORE");
# meli_ga("set", "dimension76", "false");
# meli_ga('send', 'pageview');
# (function(b,d){var a=b.createElement("iframe");(a.frameElement||a).style.cssText="width: 0; height: 0; border: 0; position: absolute";a.src="javascript:false";a.id="GoogleAnalyticsIframe";var c=b.getElementsByTagName("script")[0];c.parentNode.insertBefore(a,c);a=a.contentWindow.document;a.open().write("<body onload=\"var js = document.createElement('script');js.src = '"+d+"';document.body.appendChild(js);\">");a.close()})(document,"https://http2.mlstatic.com/storage/analytics-uploader/mlb-ml-analytics.min.js");
#   </script>
#   <!--[if lt IE 9]>
#             <script src="https://http2.mlstatic.com/static/org-img/ch/tools/html5shiv/html5shiv.js"></script>
#             <![endif]-->
#  </head>
#  <body class="site-MLB layout-base ML" style="">
#   <input id="nav-header-menu-switch" type="checkbox"/>
#   <header class="nav-header" data-siteid="MLB" role="banner">
#    <div class="nav-bounds nav-bounds-with-cart nav-bounds-large nav-bounds-with-cp">
#     <style>
#      a.nav-skip-to-main-content{border:0;border-bottom-left-radius:4px;border-bottom-right-radius:4px;position:absolute;color:#fff;font-weight:100;text-decoration:none;text-align:center;background:#3484fa;top:0;left:0;z-index:999;cursor:pointer;height:0;padding:0;line-height: normal}a.nav-skip-to-main-content:focus{border:1px solid #3484fa;height:54px;padding:8px 8px}.nav-skip-to-main-content>.nav-skip-to-main-content__content{display:none}.nav-skip-to-main-content:focus>.nav-skip-to-main-content__content{display:block;padding:8px;border:1px solid #fff;border-radius:4px}
#     </style>
#     <a class="nav-skip-to-main-content" href="#root-app" id="nav-skip-to-main-content" role="button" tabindex="1">
#      <span class="nav-skip-to-main-content__content">
#       Ir para conteúdo principal
#      </span>
#     </a>
#     <a class="nav-logo" href="//www.mercadolivre.com.br/" tabindex="2">
#      Mercado Livre Brasil - Onde comprar e vender de Tudo
#     </a>
#     <div class="nav-header-menu-wrapper">
#      <nav class="nav-header-menu-mobile-guest" id="nav-header-menu-mobile">
#       <div id="nav-header-menu-mobile-content">
#        <div class="nav-header-menu-mobile-guest" id="nav-header-menu-mobile-user-info">
#         <div class="nav-header-menu-mobile-guest-logo">
#          <svg class="nav-header-menu-mobile-guest-icon" height="35" width="28" xmlns="http://www.w3.org/2000/svg">
#           <path d="M27.343 33.706l-1.356.64A13.25 13.25 0 0 0 14 26.75c-5.17 0-9.8 2.988-11.978 7.578l-1.356-.643A14.75 14.75 0 0 1 14 25.25a14.75 14.75 0 0 1 13.343 8.456zM14 21.75C8.063 21.75 3.25 16.937 3.25 11S8.063.25 14 .25 24.75 5.063 24.75 11 19.937 21.75 14 21.75zm0-1.5a9.25 9.25 0 1 0 0-18.5 9.25 9.25 0 0 0 0 18.5zm0-2.5v-1.5a5.25 5.25 0 1 0 0-10.5v-1.5a6.75 6.75 0 0 1 0 13.5z" fill="#BBB" fillrule="nonzero">
#           </path>
#          </svg>
#         </div>
#         <h3 class="nav-header-menu-mobile-guest-title">
#          Bem-vindo
#         </h3>
#         <p class="nav-header-menu-mobile-guest-text">
#          Entra na sua conta para ver suas compras, favoritos etc.
#         </p>
#         <div class="nav-header-menu-mobile-guest-buttons">
#          <a class="nav-mobile-button nav-mobile-button-filled" href="https://www.mercadolivre.com/jms/mlb/lgz/login/?platform_id=ml&amp;go=https%3A%2F%2Flista.mercadolivre.com.br%2Fled&amp;loginType=explicit" rel="nofollow">
#           Entre
#          </a>
#          <a class="nav-mobile-button nav-mobile-button-outline" href="https://www.mercadolivre.com.br/registration">
#           Crie a sua conta
#          </a>
#         </div>
#        </div>
#        <ul>
#         <li class="">
#          <a href="https://home.mercadolivre.com.br#menu-user">
#           <i class="nav-icon-home">
#           </i>
#           <span>
#            Início
#           </span>
#          </a>
#         </li>
#         <li class="">
#          <a href="https://www.mercadolivre.com.br/ofertas#menu-user">
#           <i class="nav-icon-deals-mobile">
#           </i>
#           <span>
#            Ofertas
#           </span>
#           <span class="nav-link-tag">
#            Novo
#           </span>
#          </a>
#         </li>
#         <li class="">
#          <a href="https://www.mercadolivre.com.br/gz/home/navigation#menu-user">
#           <i class="nav-icon-history-mobile">
#           </i>
#           <span>
#            Histórico
#           </span>
#          </a>
#         </li>
#         <li class="">
#          <a href="https://vender.mercadolivre.com.br#menu-user">
#           <i class="nav-icon-vender-mobile">
#           </i>
#           <span>
#            Vender
#           </span>
#          </a>
#         </li>
#        </ul>
#        <ul>
#         <li class="">
#          <a href="https://www.mercadolivre.com.br/categorias#menu-user">
#           <i class="nav-icon-categories-mobile">
#           </i>
#           <span>
#            Categorias
#           </span>
#          </a>
#         </li>
#         <li class="">
#          <a href="https://www.mercadolivre.com.br/lojas-oficiais#menu-user">
#           <i class="nav-icon-stores-mobile">
#           </i>
#           <span>
#            Lojas oficiais
#           </span>
#          </a>
#         </li>
#        </ul>
#        <ul>
#         <li class="">
#          <a href="https://www.mercadolivre.com.br/ajuda#menu-user">
#           <i class="nav-icon-help-mobile">
#           </i>
#           <span>
#            Contato
#           </span>
#          </a>
#         </li>
#        </ul>
#        <ul>
#         <li class="">
#          <a data-os="" href="https://www.mercadolivre.com.br/gz/app#menu-user" id="nav-header-menu-download-mobile">
#           <i class="nav-icon-download-mobile">
#           </i>
#           <span>
#            Compre e venda com o app!
#           </span>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </nav>
#      <label aria-controls="nav-header-menu" for="nav-header-menu-switch">
#       <span class="hamburger-top-bread">
#       </span>
#       <span class="hamburger-patty">
#       </span>
#       <span class="hamburger-bottom-bread">
#       </span>
#      </label>
#      <nav id="nav-header-menu">
#       <a class="option-register" href="https://www.mercadolivre.com.br/registration#nav-header" rel="nofollow" tabindex="8">
#        <i class="nav-icon-register">
#        </i>
#        Crie a sua conta
#       </a>
#       <a class="option-login nav-header-lnk-login" href="https://www.mercadolivre.com/jms/mlb/lgz/login/?platform_id=ml&amp;go=https%3A%2F%2Flista.mercadolivre.com.br%2Fled&amp;loginType=explicit#nav-header" rel="nofollow" tabindex="8">
#        <i class="nav-icon-login">
#        </i>
#        Entre
#       </a>
#       <a href="https://myaccount.mercadolivre.com.br/purchases/list#nav-header" tabindex="8">
#        Compras
#       </a>
#       <a class="option-sell nav-header-btn-pub" href="https://vender.mercadolivre.com.br#nav-header" rel="nofollow" tabindex="8">
#        Vender
#       </a>
#      </nav>
#      <!-- Cuando el carrito esta vacio debe tener la clase "nav-cart-empty", cuando esta lleno "nav-cart-full" -->
#      <a class="nav-cart nav-cart-empty" href="https://www.mercadolivre.com.br/gz/cart#nav-header" id="nav-cart" tabindex="9" title="Carrinho de compras">
#       <i class="nav-icon-cart">
#       </i>
#       <span class="nav-icon-cart-quantity">
#        <b>
#         null
#        </b>
#       </span>
#      </a>
#     </div>
#     <a class="nav-header-cp-anchor" href="https://www.mercadolivre.com.br/navigation/addresses-hub?go=https%3A%2F%2Flista.mercadolivre.com.br%2Fled&amp;context=">
#      Informe seu CEP
#     </a>
#     <form action="//www.mercadolivre.com.br/jm/search" class="nav-search" method="GET" role="search">
#      <input aria-label="Digite o que você quer encontrar" autocapitalize="off" autocomplete="off" autocorrect="off" class="nav-search-input" max-length="120" name="as_word" placeholder="Buscar produtos, marcas e muito mais…" spellcheck="false" tabindex="3" type="text" value="led"/>
#      <button class="nav-search-clear-btn" title="menu.autocomplete.clear" type="button">
#      </button>
#      <button class="nav-search-close-btn" title="menu.autocomplete.close" type="button">
#      </button>
#      <button class="nav-search-btn" tabindex="4" type="submit">
#       <div aria-label="Buscar" class="nav-icon-search" role="img">
#       </div>
#      </button>
#     </form>
#     <div class="nav-menu">
#      <div>
#       <ul class="nav-menu-list">
#        <li class="nav-menu-item">
#         <a class="nav-menu-cp nav-menu-cp-logged" href="https://www.mercadolivre.com.br/navigation/addresses-hub?go=https%3A%2F%2Flista.mercadolivre.com.br%2Fled&amp;context=" tabindex="6">
#          <span class="nav-menu-cp-send">
#           Informe seu
#          </span>
#          <span class="nav-menu-link-cp">
#           CEP
#          </span>
#         </a>
#        </li>
#        <li class="nav-menu-item">
#         <a class="nav-menu-item-link nav-menu-categories-link" data-js="nav-menu-categories-trigger" href="https://www.mercadolivre.com.br/categorias#nav-header" rel="nofollow" tabindex="7">
#          Categorias
#         </a>
#        </li>
#        <li class="nav-menu-item">
#         <a class="nav-menu-item-link" data-js="" href="https://www.mercadolivre.com.br/ofertas#nav-header" rel="nofollow" tabindex="7">
#          Ofertas
#          <span class="nav-link-tag nav-link-tag--small">
#           Novo
#          </span>
#         </a>
#        </li>
#        <li class="nav-menu-item">
#         <a class="nav-menu-item-link" data-js="" href="https://www.mercadolivre.com.br/gz/home/navigation#nav-header" rel="nofollow" tabindex="7">
#          Histórico
#         </a>
#        </li>
#        <li class="nav-menu-item">
#         <a class="nav-menu-item-link" data-js="" href="https://www.mercadolivre.com.br/lojas-oficiais#nav-header" rel="nofollow" tabindex="7">
#          Lojas oficiais
#         </a>
#        </li>
#        <li class="nav-menu-item">
#         <a class="nav-menu-item-link" data-js="" href="https://vender.mercadolivre.com.br#nav-header" rel="nofollow" tabindex="7">
#          Vender
#         </a>
#        </li>
#        <li class="nav-menu-item">
#         <a class="nav-menu-item-link" data-js="" href="https://www.mercadolivre.com.br/ajuda#nav-header" rel="nofollow" tabindex="7">
#          Contato
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <a class="exhibitor__picture" href="https://www.mercadolivre.com.br/gz/app" tabindex="5">
#      <img src="https://http2.mlstatic.com/resources/deals/exhibitors_resources/mlb-menu-desktop-notification-picture-f1b0f097-97a4-42af-94c0-c36c2b5db114.png" title="Baixe grátis o app"/>
#     </a>
#    </div>
#   </header>
#   <main id="root-app" role="main">
#    <meta content="main" name="layout"/>
#    <div class="ml-main" id="ml-main">
#     <div class="inner-main" id="inner-main">
#      <aside class="filters stack" role="complementary">
#       <div class="breadcrumb">
#        <ol>
#        </ol>
#        <h1 class="breadcrumb__title">
#         led
#        </h1>
#       </div>
#       <div class="quantity-results">
#        2.875.790 resultados
#       </div>
#       <section class="view-options">
#        <dl>
#         <dt>
#          Organizar anúncios
#         </dt>
#         <div class="sort-by">
#          <div class="ui-dropdown custom">
#           <input autocomplete="off" class="dropdown-trigger sort-by-options-trigger" hidden="" id="sort-by-options-trigger" type="checkbox"/>
#           <label class="ui-dropdown__link" for="sort-by-options-trigger">
#            Mais relevantes
#            <div class="ui-dropdown__indicator">
#            </div>
#           </label>
#           <div class="ui-dropdown__content sorty-by-ui-dropdown__content">
#            <div class="ui-list">
#             <ul class="ui-list__content">
#              <li class="ui-list__item ui-list__item--selected">
#               <span class="ui-list__item-option" href="#">
#                Mais relevantes
#               </span>
#              </li>
#              <li class="ui-list__item">
#               <a class="ui-list__item-option" href="https://lista.mercadolivre.com.br/led_OrderId_PRICE">
#                Menor preço
#               </a>
#              </li>
#              <li class="ui-list__item">
#               <a class="ui-list__item-option" href="https://lista.mercadolivre.com.br/led_OrderId_PRICE*DESC">
#                Maior preço
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </div>
#         </div>
#         <ul class="view-options-buttons">
#          <li>
#           <div class="ico view-option-stack selected">
#           </div>
#          </li>
#          <li>
#           <a class="ico grid" href="https://lista.mercadolivre.com.br/led_DisplayType_G" title="Grilla">
#            <div class="ico view-option-grid">
#            </div>
#           </a>
#          </li>
#         </ul>
#        </dl>
#       </section>
#       <section class="filters__groups">
#        <dl class="filters__group filters__official_store" id="id_official_store" role="listbox">
#         <dt class="dt-title" role="presentation">
#          Lojas oficiais
#         </dt>
#         <dd class="filters__group__option" role="option">
#          <a class="qcat-truncate" href="https://lista.mercadolivre.com.br/led_Loja_all" style="max-width:116px;" title="Somente lojas oficiais">
#           <span class="filter-name">
#            Somente lojas oficiais
#           </span>
#           <span class="filter-results-qty">
#            (259.215)
#           </span>
#          </a>
#         </dd>
#        </dl>
#        <dl class="filters__group filters__category" id="id_category" role="listbox">
#         <dt class="dt-title" role="presentation">
#          Categorias
#         </dt>
#         <dd class="filters__group__option" role="option">
#          <h3>
#           <a class="qcat-truncate" href="https://lista.mercadolivre.com.br/casa-moveis-decoracao/iluminacao-residencial/led" style="max-width:116px;" title="Iluminação Residencial">
#            <span class="filter-name">
#             Iluminação Residencial
#            </span>
#            <span class="filter-results-qty">
#             (668.513)
#            </span>
#           </a>
#          </h3>
#         </dd>
#         <dd class="filters__group__option" role="option">
#          <h3>
#           <a class="qcat-truncate" href="https://lista.mercadolivre.com.br/acessorios-veiculos/tuning/led" style="max-width:116px;" title="Tuning">
#            <span class="filter-name">
#             Tuning
#            </span>
#            <span class="filter-results-qty">
#             (411.568)
#            </span>
#           </a>
#          </h3>
#         </dd>
#         <dd class="filters__group__option" role="option">
#          <h3>
#           <a class="qcat-truncate" href="https://lista.mercadolivre.com.br/pecas/carros/led" style="max-width:116px;" title="Peças de Carros e Caminhonetes">
#            <span class="filter-name">
#             Peças de Carros e Caminhonetes
#            </span>
#            <span class="filter-results-qty">
#             (565.639)
#            </span>
#           </a>
#          </h3>
#         </dd>
#         <dd class="filters__group__option" role="option">
#          <h3>
#           <a class="qcat-truncate" href="https://eletronicos.mercadolivre.com.br/led" style="max-width:116px;" title="Eletrônicos, Áudio e Vídeo">
#            <span class="filter-name">
#             Eletrônicos, Áudio e Vídeo
#            </span>
#            <span class="filter-results-qty">
#             (266.117)
#            </span>
#           </a>
#          </h3>
#         </dd>
#         <dd class="filters__group__option" role="option">
#          <h3>
#           <a class="qcat-truncate" href="https://informatica.mercadolivre.com.br/led" style="max-width:116px;" title="Informática">
#            <span class="filter-name">
#             Informática
#            </span>
#            <span class="filter-results-qty">
#             (252.291)
#            </span>
#           </a>
#          </h3>
#         </dd>
#         <dd class="filters__group__option" role="option">
#          <h3>
#           <a class="qcat-truncate" href="https://esportes.mercadolivre.com.br/led" style="max-width:116px;" title="Esportes e Fitness">
#            <span class="filter-name">
#             Esportes e Fitness
#            </span>
#            <span class="filter-results-qty">
#             (124.705)
#            </span>
#           </a>
#          </h3>
#         </dd>
#         <dd class="filters__group__option" role="option">
#          <h3>
#           <a class="qcat-truncate" href="https://lista.mercadolivre.com.br/acessorios-veiculos/carros/led" style="max-width:123px;" title="Aces. de Carros e Caminhonetes">
#            <span class="filter-name">
#             Aces. de Carros e Caminhonetes
#            </span>
#            <span class="filter-results-qty">
#             (65.088)
#            </span>
#           </a>
#          </h3>
#         </dd>
#         <dd class="filters__group__option" role="option">
#          <h3>
#           <a class="qcat-truncate" href="https://lista.mercadolivre.com.br/enfeites-e-decoracao-casa/led" style="max-width:123px;" title="Enfeites e Decoração da Casa">
#            <span class="filter-name">
#             Enfeites e Decoração da Casa
#            </span>
#            <span class="filter-results-qty">
#             (62.784)
#            </span>
#           </a>
#          </h3>
#         </dd>
#         <dd class="filters__group__option" role="option">
#          <h3>
#           <a class="qcat-truncate" href="https://lista.mercadolivre.com.br/beleza-cuidado-pessoal/led" style="max-width:123px;" title="Beleza e Cuidado Pessoal">
#            <span class="filter-name">
#             Beleza e Cuidado Pessoal
#            </span>
#            <span class="filter-results-qty">
#             (60.192)
#            </span>
#           </a>
#          </h3>
#         </dd>
#         <label class="see-more-category-filter see-more-filter" for="category-modal">
#          Ver todos
#         </label>
#         <input autocomplete="off" class="category-modal-trigger modal-trigger js-modal-trigger" hidden="" id="category-modal" type="checkbox"/>
#         <section class="modal-overlay modal-category">
#          <label class="modal-label" for="category-modal">
#          </label>
#          <div class="modal-container modal-container_expandable">
#           <div class="modal-header">
#            <h2 class="modal__title">
#             Escolher Categorias
#            </h2>
#            <label class="ic-close" for="category-modal">
#             <div class="icon">
#             </div>
#            </label>
#           </div>
#           <div class="modal-content modal-content_expandable">
#            <dl class="filters___expandable_list">
#             <dd class="filters__group__option" role="option">
#              <h3>
#               <a class="qcat-truncate" href="https://lista.mercadolivre.com.br/acessorios-veiculos/carros/led" style="max-width:123px;" title="Aces. de Carros e Caminhonetes">
#                <span class="filter-name">
#                 Aces. de Carros e Caminhonetes
#                </span>
#                <span class="filter-results-qty">
#                 (65.088)
#                </span>
#               </a>
#              </h3>
#             </dd>
#             <dd class="filters__group__option" role="option">
#              <h3>
#               <a class="qcat-truncate" href="https://lista.mercadolivre.com.br/acessorios-veiculos/quadriciclos/led" style="max-width:123px;" title="Aces. de Motos e Quadriciclos">
#                <span class="filter-name">
#                 Aces. de Motos e Quadriciclos
#                </span>
#                <span class="filter-results-qty">
#                 (13.248)
#                </span>
#               </a>
#              </h3>
#             </dd>
#             <dd class="filters__group__option" role="option">
#              <h3>
#               <a class="qcat-truncate" href="https://lista.mercadolivre.com.br/acessorios-veiculos/nauticos/led" style="max-width:130px;" title="Acessórios e Peças Náuticos">
#                <span class="filter-name">
#                 Acessórios e Peças Náuticos
#                </span>
#                <span class="filter-results-qty">
#                 (6.048)
#                </span>
#               </a>
#              </h3>
#             </dd>
#             <dd class="filters__group__option" role="option">
#              <h3>
#               <label class="adults__label" for="adults-modal-trigger">
#                Adultos
#                <span>
#                 (1.189)
#                </span>
#               </label>
#              </h3>
#             </dd>
#             <dd class="filters__group__option" role="option">
#              <h3>
#               <a class="qcat-truncate" href="https://lista.mercadolivre.com.br/agro-industria-comercio/led" style="max-width:130px;" title="Agro, Indústria e Comércio">
#                <span class="filter-name">
#                 Agro, Indústria e Comércio
#                </span>
#                <span class="filter-results-qty">
#                 (6.912)
#                </span>
#               </a>
#              </h3>
#             </dd>
#             <dd class="filters__group__option" role="option">
#              <h3>
#               <a class="qcat-truncate" href="https://lista.mercadolivre.com.br/alimentos-bebidas/led" style="max-width:137px;" title="Alimentos e Bebidas">
#                <span class="filter-name">
#                 Alimentos e Bebidas
#                </span>
#                <span class="filter-results-qty">
#                 (576)
#                </span>
#               </a>
#              </h3>
#             </dd>
#             <dd class="filters__group__option" role="option">
#              <h3>
#               <a class="qcat-truncate" href="https://lista.mercadolivre.com.br/animais/led" style="max-width:123px;" title="Animais">
#                <span class="filter-name">
#                 Animais
#                </span>
#                <span class="filter-results-qty">
#                 (18.432)
#                </span>
#               </a>
#              </h3>
#             </dd>
#             <dd class="filters__group__option" role="option">
#              <h3>
#               <a class="qcat-truncate" href="https://lista.mercadolivre.com.br/antiguidades/led" style="max-width:130px;" title="Antiguidades e Coleções">
#                <span class="filter-name">
#                 Antiguidades e Coleções
#                </span>
#                <span class="filter-results-qty">
#                 (2.880)
#                </span>
#               </a>
#              </h3>
#             </dd>
#             <dd class="filters__group__option" role="option">
#              <h3>
#               <a class="qcat-truncate" href="https://lista.mercadolivre.com.br/arte-artesanato/led" style="max-width:130px;" title="Arte, Papelaria e Armarinho">
#                <span class="filter-name">
#                 Arte, Papelaria e Armarinho
#                </span>
#                <span class="filter-results-qty">
#                 (7.776)
#                </span>
#               </a>
#              </h3>
#             </dd>
#             <dd class="filters__group__option" role="option">
#              <h3>
#               <a class="qcat-truncate" href="https://lista.mercadolivre.com.br/casa-moveis-decoracao/banheiros/led" style="max-width:130px;" title="Banheiros">
#                <span class="filter-name">
#                 Banheiros
#                </span>
#                <span class="filter-results-qty">
#                 (4.608)
#                </span>
#               </a>
#              </h3>
#             </dd>
#             <dd class="filters__group__option" role="option">
#              <h3>
#               <a class="qcat-truncate" href="https://lista.mercadolivre.com.br/bebes/led" style="max-width:130px;" title="Bebês">
#                <span class="filter-name">
#                 Bebês
#                </span>
#                <span class="filter-results-qty">
#                 (5.760)
#                </span>
#               </a>
#              </h3>
#             </dd>
#             <dd class="filters__group__option" role="option">
#              <h3>
#               <a class="qcat-truncate" href="https://lista.mercadolivre.com.br/beleza-cuidado-pessoal/led" style="max-width:123px;" title="Beleza e Cuidado Pessoal">
#                <span class="filter-name">
#                 Beleza e Cuidado Pessoal
#                </span>
#                <span class="filter-results-qty">
#                 (60.192)
#                </span>
#               </a>
#              </h3>
#             </dd>
#             <dd class="filters__group__option" role="option">
#              <h3>
#               <a class="qcat-truncate" href="https://lista.mercadolivre.com.br/brinquedos-hobbies/led" style="max-width:123px;" title="Brinquedos e Hobbies">
#                <span class="filter-name">
#                 Brinquedos e Hobbies
#                </span>
#                <span class="filter-results-qty">
#                 (24.192)
#                </span>
#               </a>
#              </h3>
#             </dd>
#             <dd class="filters__group__option" role="option">
#              <h3>
#               <a class="qcat-truncate" href="https://roupas.mercadolivre.com.br/led" style="max-width:123px;" title="Calçados, Roupas e Bolsas">
#                <span class="filter-name">
#                 Calçados, Roupas e Bolsas
#                </span>
#                <span class="filter-results-qty">
#                 (14.112)
#                </span>
#               </a>
#              </h3>
#             </dd>
#             <dd class="filters__group__option" role="option">
#              <h3>
#               <a class="qcat-truncate" href="https://telefonia.mercadolivre.com.br/led" style="max-width:123px;" title="Celulares e Telefones">
#                <span class="filter-name">
#                 Celulares e Telefones
#                </span>
#                <span class="filter-results-qty">
#                 (22.464)
#                </span>
#               </a>
#              </h3>
#             </dd>
#             <dd class="filters__group__option" role="option">
#              <h3>
#               <a class="qcat-truncate" href="https://lista.mercadolivre.com.br/cortinas-e-acessorios/led" style="max-width:130px;" title="Cortinas e Acessórios">
#                <span class="filter-name">
#                 Cortinas e Acessórios
#                </span>
#                <span class="filter-results-qty">
#                 (2.304)
#                </span>
#               </a>
#              </h3>
#             </dd>
#             <dd class="filters__group__option" role="option">
#              <h3>
#               <a class="qcat-truncate" href="https://lista.mercadolivre.com.br/cuidado-casa-e-lavanderia/led" style="max-width:130px;" title="Cuidado da Casa e Lavanderia">
#                <span class="filter-name">
#                 Cuidado da Casa e Lavanderia
#                </span>
#                <span class="filter-results-qty">
#                 (4.032)
#                </span>
#               </a>
#              </h3>
#             </dd>
#             <dd class="filters__group__option" role="option">
#              <h3>
#               <a class="qcat-truncate" href="https://cameras.mercadolivre.com.br/led" style="max-width:123px;" title="Câmeras e Acessórios">
#                <span class="filter-name">
#                 Câmeras e Acessórios
#                </span>
#                <span class="filter-results-qty">
#                 (35.136)
#                </span>
#               </a>
#              </h3>
#             </dd>
#             <dd class="filters__group__option" role="option">
#              <h3>
#               <a class="qcat-truncate" href="https://lista.mercadolivre.com.br/eletrodomesticos/led" style="max-width:123px;" title="Eletrodomésticos">
#                <span class="filter-name">
#                 Eletrodomésticos
#                </span>
#                <span class="filter-results-qty">
#                 (18.720)
#                </span>
#               </a>
#              </h3>
#             </dd>
#             <dd class="filters__group__option" role="option">
#              <h3>
#               <a class="qcat-truncate" href="https://eletronicos.mercadolivre.com.br/led" style="max-width:116px;" title="Eletrônicos, Áudio e Vídeo">
#                <span class="filter-name">
#                 Eletrônicos, Áudio e Vídeo
#                </span>
#                <span class="filter-results-qty">
#                 (266.117)
#                </span>
#               </a>
#              </h3>
#             </dd>
#             <dd class="filters__group__option" role="option">
#              <h3>
#               <a class="qcat-truncate" href="https://lista.mercadolivre.com.br/enfeites-e-decoracao-casa/led" style="max-width:123px;" title="Enfeites e Decoração da Casa">
#                <span class="filter-name">
#                 Enfeites e Decoração da Casa
#                </span>
#                <span class="filter-results-qty">
#                 (62.784)
#                </span>
#               </a>
#              </h3>
#             </dd>
#             <dd class="filters__group__option" role="option">
#              <h3>
#               <a class="qcat-truncate" href="https://esportes.mercadolivre.com.br/led" style="max-width:116px;" title="Esportes e Fitness">
#                <span class="filter-name">
#                 Esportes e Fitness
#                </span>
#                <span class="filter-results-qty">
#                 (124.705)
#                </span>
#               </a>
#              </h3>
#             </dd>
#             <dd class="filters__group__option" role="option">
#              <h3>
#               <a class="qcat-truncate" href="https://lista.mercadolivre.com.br/acessorios-veiculos/ferramentas/led" style="max-width:130px;" title="Ferramentas">
#                <span class="filter-name">
#                 Ferramentas
#                </span>
#                <span class="filter-results-qty">
#                 (2.592)
#                </span>
#               </a>
#              </h3>
#             </dd>
#             <dd class="filters__group__option" role="option">
#              <h3>
#               <a class="qcat-truncate" href="https://lista.mercadolivre.com.br/ferramentas-construcao/led" style="max-width:123px;" title="Ferramentas e Construção">
#                <span class="filter-name">
#                 Ferramentas e Construção
#                </span>
#                <span class="filter-results-qty">
#                 (42.048)
#                </span>
#               </a>
#              </h3>
#             </dd>
#             <dd class="filters__group__option" role="option">
#              <h3>
#               <a class="qcat-truncate" href="https://lista.mercadolivre.com.br/festas-e-lembrancinhas/led" style="max-width:123px;" title="Festas e Lembrancinhas">
#                <span class="filter-name">
#                 Festas e Lembrancinhas
#                </span>
#                <span class="filter-results-qty">
#                 (15.264)
#                </span>
#               </a>
#              </h3>
#             </dd>
#             <dd class="filters__group__option" role="option">
#              <h3>
#               <a class="qcat-truncate" href="https://games.mercadolivre.com.br/games/led" style="max-width:130px;" title="Games">
#                <span class="filter-name">
#                 Games
#                </span>
#                <span class="filter-results-qty">
#                 (2.304)
#                </span>
#               </a>
#              </h3>
#             </dd>
#             <dd class="filters__group__option" role="option">
#              <h3>
#               <a class="qcat-truncate" href="https://lista.mercadolivre.com.br/casa-moveis-decoracao/iluminacao-residencial/led" style="max-width:116px;" title="Iluminação Residencial">
#                <span class="filter-name">
#                 Iluminação Residencial
#                </span>
#                <span class="filter-results-qty">
#                 (668.513)
#                </span>
#               </a>
#              </h3>
#             </dd>
#             <dd class="filters__group__option" role="option">
#              <h3>
#               <a class="qcat-truncate" href="https://informatica.mercadolivre.com.br/led" style="max-width:116px;" title="Informática">
#                <span class="filter-name">
#                 Informática
#                </span>
#                <span class="filter-results-qty">
#                 (252.291)
#                </span>
#               </a>
#              </h3>
#             </dd>
#             <dd class="filters__group__option" role="option">
#              <h3>
#               <a class="qcat-truncate" href="https://lista.mercadolivre.com.br/instrumentos-musicais/led" style="max-width:130px;" title="Instrumentos Musicais">
#                <span class="filter-name">
#                 Instrumentos Musicais
#                </span>
#                <span class="filter-results-qty">
#                 (5.184)
#                </span>
#               </a>
#              </h3>
#             </dd>
#             <dd class="filters__group__option" role="option">
#              <h3>
#               <a class="qcat-truncate" href="https://lista.mercadolivre.com.br/jardins-e-exteriores/led" style="max-width:123px;" title="Jardins e Exteriores">
#                <span class="filter-name">
#                 Jardins e Exteriores
#                </span>
#                <span class="filter-results-qty">
#                 (28.512)
#                </span>
#               </a>
#              </h3>
#             </dd>
#             <dd class="filters__group__option" role="option">
#              <h3>
#               <a class="qcat-truncate" href="https://lista.mercadolivre.com.br/joias-relogios/led" style="max-width:123px;" title="Joias e Relógios">
#                <span class="filter-name">
#                 Joias e Relógios
#                </span>
#                <span class="filter-results-qty">
#                 (37.152)
#                </span>
#               </a>
#              </h3>
#             </dd>
#             <dd class="filters__group__option" role="option">
#              <h3>
#               <a class="qcat-truncate" href="https://lista.mercadolivre.com.br/acessorios-veiculos/limpeza-automotiva/led" style="max-width:137px;" title="Limpeza Automotiva">
#                <span class="filter-name">
#                 Limpeza Automotiva
#                </span>
#                <span class="filter-results-qty">
#                 (288)
#                </span>
#               </a>
#              </h3>
#             </dd>
#             <dd class="filters__group__option" role="option">
#              <h3>
#               <a class="qcat-truncate" href="https://livros.mercadolivre.com.br/led" style="max-width:130px;" title="Livros, Revistas e Comics">
#                <span class="filter-name">
#                 Livros, Revistas e Comics
#                </span>
#                <span class="filter-results-qty">
#                 (1.152)
#                </span>
#               </a>
#              </h3>
#             </dd>
#             <dd class="filters__group__option" role="option">
#              <h3>
#               <a class="qcat-truncate" href="https://lista.mercadolivre.com.br/mais-categorias/led" style="max-width:130px;" title="Mais Categorias">
#                <span class="filter-name">
#                 Mais Categorias
#                </span>
#                <span class="filter-results-qty">
#                 (3.456)
#                </span>
#               </a>
#              </h3>
#             </dd>
#             <dd class="filters__group__option" role="option">
#              <h3>
#               <a class="qcat-truncate" href="https://lista.mercadolivre.com.br/moveis-casa/led" style="max-width:130px;" title="Móveis para Casa">
#                <span class="filter-name">
#                 Móveis para Casa
#                </span>
#                <span class="filter-results-qty">
#                 (5.472)
#                </span>
#               </a>
#              </h3>
#             </dd>
#             <dd class="filters__group__option" role="option">
#              <h3>
#               <a class="qcat-truncate" href="https://lista.mercadolivre.com.br/musica/led" style="max-width:130px;" title="Música, Filmes e Seriados">
#                <span class="filter-name">
#                 Música, Filmes e Seriados
#                </span>
#                <span class="filter-results-qty">
#                 (4.608)
#                </span>
#               </a>
#              </h3>
#             </dd>
#             <dd class="filters__group__option" role="option">
#              <h3>
#               <a class="qcat-truncate" href="https://lista.mercadolivre.com.br/acessorios-veiculos/navegadores-gps/led" style="max-width:137px;" title="Navegadores GPS">
#                <span class="filter-name">
#                 Navegadores GPS
#                </span>
#                <span class="filter-results-qty">
#                 (288)
#                </span>
#               </a>
#              </h3>
#             </dd>
#             <dd class="filters__group__option" role="option">
#              <h3>
#               <a class="qcat-truncate" href="https://lista.mercadolivre.com.br/organizacao-casa/led" style="max-width:137px;" title="Organização para Casa">
#                <span class="filter-name">
#                 Organização para Casa
#                </span>
#                <span class="filter-results-qty">
#                 (576)
# ...
#             if (element) {
#                 element.classList.remove('active');
#             }
#         });
#
#         meli.on('bookmarks:add:success', function (itemId) {
#             var element = document.querySelector('.bookmarks.favorite[data-id="' + itemId + '"]');
#             if (element) {
#                 element.classList.remove('active');
#             }
#             if(melidata){
#                 melidata("send", "event", {
#                     path: '/bookmarks/action/post',
#                     data: {
#                         context: '/search',
#                         item_id: itemId
#                     }
#                 });
#             }
#         });
#
#         meli.on('bookmarks:add:error', function (itemId) {
#             var element = document.querySelector('.bookmarks.favorite[data-id="' + itemId + '"]');
#             if (element) {
#                 element.classList.remove('active');
#             }
#         });
#      }, function() {
#         (function () {
#             var gads = document.createElement('script');
#             gads.type = 'text/javascript';
#             gads.async = true;
#             var useSSL = 'https:' == document.location.protocol;
#             gads.src = (useSSL ? 'https:' : 'http:') + '//www.googletagservices.com/tag/js/gpt.js';
#             var node = document.getElementsByTagName('script')[0];
#
#             node.parentNode.insertBefore(gads, node)
#         })();
#      }, "https://http2.mlstatic.com/resources/frontend/commons-frontend/ui-dist/js/bundle__chico_desktop.8a20c382.js", "https://http2.mlstatic.com/resources/frontend/commons-frontend/ui-dist/js/bundle__commons_desktop.9b58e459.js", "https://http2.mlstatic.com/resources/frontend/commons-frontend/ui-dist/js/bundle__vendor-tiny-addons.c37e885e.js", function() {
# 		window.meliAsync();
# 	 }, "https://http2.mlstatic.com/resources/frontend/statics/ml-widgets/onboarding-cp/v1.0.10/onboarding-cp.js", "https://http2.mlstatic.com/ui/searchbox/2.3.1/index.js", function() {
#     (function(win) {
#       if (win.Searchbox) {
#         new Searchbox('.nav-search-input', {
#           platformId: 'ML',
#           siteId: 'MLB',
#           siteDomain: 'mercadolivre.com.br',
#           limit: 6,
#
#           searchEndpoint: 'https://lista.mercadolivre.com.br/$query',
#           categoryCheckbox: document.getElementById('categorySearch'),
#           identifiedUser: 'false',
#           bus: meli,
#           deviceType: 'desktop'
#         });
#
#         (function (doc) {
#             'use strict';
#
#             var header = doc.querySelector('.nav-header'),
#               searchInput = doc.querySelector('.nav-search-input'),
#               searchForm = doc.querySelector('.nav-search'),
#               menuSwitch = document.getElementById('nav-header-menu-switch'),
#               clearBtn = doc.querySelector('.nav-search-clear-btn'),
#               searchInputHasFocus = false,
#               searchInputFocusTimer;
#
#             function checkInputText() {
#               clearTimeout(searchInputFocusTimer);
#
#               searchInputFocusTimer = setTimeout(function() {
#                 searchForm.classList[searchInput.value.length && searchInputHasFocus ? 'add' : 'remove']('nav-search--has-text');
#               }, 100);
#             }
#
#             searchInput.addEventListener('focus', function() {
#               header.classList.add('nav-header-has-search-active');
#               header.classList.remove('nav-header--is-leave');
#               menuSwitch.checked = false;
#               searchInputHasFocus = true;
#               checkInputText();
#
#               setTimeout(function() {
#                 header.classList.add('nav-header--is-enter');
#               }, 1);
#             });
#
#             searchInput.addEventListener('blur', function() {
#               header.classList.remove('nav-header--is-enter');
#               header.classList.add('nav-header--is-leave');
#               searchInputHasFocus = false;
#               checkInputText();
#               setTimeout(function() {
#                 if (!searchInputHasFocus) {
#                   header.classList.remove('nav-header-has-search-active');
#                 }
#               }, 100);
#             });
#
#
#             searchInput.addEventListener('input', checkInputText);
#
#             clearBtn && clearBtn.addEventListener('mousedown', function(e) {
#               e.preventDefault();
#
#               searchInput.value = '';
#               checkInputText();
#
#               setTimeout(function(){
#                 searchInput.focus();
#               }, 50);
#             }, false);
#           }(document));
#       }
#     })(window);
#    }, "https://http2.mlstatic.com/resources/frontend/statics/ml-widgets/modal/v1.0.2/modal.js", "https://http2.mlstatic.com/resources/frontend/statics/ml-widgets/categories/v1.1.1/categories.js", function() {
# 										(function(win, meli) {
# 											if (win.CategoriesWidget && meli) {
# 												new CategoriesWidget({
# 													bus: meli,
# 													endpoint: 'https://www.mercadolivre.com.br/menu/departments',
# 												});
# 											}
# 										})(window, window.meli);
# 									 }, "https://http2.mlstatic.com/ui/navigation/5.3.5/scripts/messages-plus.js", "https://http2.mlstatic.com/resources/frontend/statics/ml-widgets/snackbar/v1.0.0/snackbar.js", function() {
# 	(function(win, meli) {
# 		if (win.SnackbarWidget && meli) {
# 			new SnackbarWidget({
# 				bus: meli,
# 				scope: win,
# 			});
# 		}
# 	})(window, window.meli);
#  }, function() {
# 				meli.utils.lazy('img.avatar-lazy')
# 			 }, "https://http2.mlstatic.com/resources/frontend/commons-frontend/ui-dist/js/bundle__header.84358c53.js", function() {
# 			new meli.Header({
# 				environment: 'desktop'
# 			});
# 			 }, "https://http2.mlstatic.com/resources/frontend/commons-frontend/ui-dist/js/bundle__ML-MLB.21c49c56.js", function() {
#     //Set BgLoading if is necesesary
#
#     (function(win, doc) {
#         var list = doc.getElementById('searchResults'),
#             isCpgLanding = doc.querySelector('body.layout-cpg'),
#             onlyOnSearchCheckbox= doc.getElementById('categorySearch');
#
#         if (!!isCpgLanding){
#             onlyOnSearchCheckbox.checked = true;
#         }
#
#         if (!!list) {
#             var itemsList = list.querySelectorAll('.results-item'),
#                 itemsCount = itemsList.length;
#
#             function showHideLoading(addRemove, img, statusBar) {
#                 if(addRemove == 'show') {
#                     if((typeof img.naturalWidth != "undefined" && img.naturalWidth == 0 ) || img.readyState == 'uninitialized' ) {
#                         statusBar.classList.remove('item-loading__hide');
#                     }
#                 }
#             }
#
#             function eachImage(itemsCount) {
#                 for (var i = 0; i < itemsCount; i += 1) {
#                     var img = itemsList[i].querySelector('img'),
#                         itemTarget = itemsList[i].querySelector('.rowItem'),
#                         statusBar = itemsList[i].querySelector('.item-loading__status-bar'),
#                         src = '',
#                         itemImage = '',
#                         itemInfo = '';
#
#                     if (!!itemTarget) {
#                         itemImage = itemTarget.querySelector('.item__image');
#                         itemInfo = itemTarget.querySelector('.item__info');
#                     }
#
#                     if(statusBar) {
#                         showHideLoading('show', img, statusBar);
#
#                         var mouseOutHideLoader = itemImage.addEventListener('mouseleave', function(e) {
#                             var rowItem = e.target.closest(".rowItem"),
#                                 loader = rowItem.querySelector('.item-loading__status-bar');
#                             if(!loader.classList.contains('item-loading__hide')) {
#                                 loader.classList.add('item-loading__hide');
#                             }
#                         },false);
#
#                         var mouseEnterShowLoader = itemImage.addEventListener('mouseenter', function(e) {
#                             var rowItem = e.target.closest(".rowItem"),
#                                 loader = rowItem.querySelector('.item-loading__status-bar'),
#                                 hasVariations = rowItem.classList.contains('has-variations'),
#                                 variationsSkel = rowItem.querySelector('.variation-picker__sekeleton'),
#                                 carousel = rowItem.querySelector('.ch-carousel-list');
#                             if(loader.classList.contains('item-loading__hide') && hasVariations && variationsSkel && !carousel) {
#                                 loader.classList.remove('item-loading__hide');
#                             }
#                         },false);
#
#                         var mouseEnterInfoShowLoader = itemInfo.addEventListener('mouseenter', function(e) {
#                             var rowItem = e.target.closest(".rowItem"),
#                                 loader = rowItem.querySelector('.item-loading__status-bar'),
#                                 hasVariations = rowItem.classList.contains('has-variations'),
#                                 variationsSkel = rowItem.querySelector('.variation-picker__sekeleton'),
#                                 carousel = rowItem.querySelector('.ch-carousel-list');
#                             if(loader.classList.contains('item-loading__hide') && hasVariations && variationsSkel && !carousel) {
#                                 loader.classList.remove('item-loading__hide');
#                                 loader.classList.add('variation-loading');
#                             }
#                         },false);
#
#                         img.addEventListener('load', function(e) {
#                             var loader = e.target.closest(".rowItem").querySelector('.item-loading__status-bar');
#                             loader.classList.add('item-loading__hide');
#                             mouseOutHideLoader;
#                             mouseEnterShowLoader;
#                             mouseEnterInfoShowLoader;
#                         },false);
#                     }
#                 }
#             }
#
#             if (itemsCount > 0) {
#                 eachImage(itemsCount);
#             }
#         }
#     }(window, document));
#  }, function() {
# 					(function () {
# 						var linkSkipToMainContent = document.querySelector('#nav-skip-to-main-content');
# 						if (linkSkipToMainContent) {
# 							linkSkipToMainContent.addEventListener('click', function () {
# 								if (window.meli_ga) {
# 									meli_ga('send', 'event', 'SKIP_TO_MAIN_CONTENT', 'NAVIGATION', 'search-frontend');
# 								}
# 								if (window.melidata) {
# 									melidata('cleanAndSend', 'event', {
# 										path: '/navigation/skip-to-main-content',
# 										data: {
# 											app: 'search-frontend',
# 										},
# 									});
# 								}
# 							});
# 						}
# 					}());
# 				 }, function() {
# 		(function appDownload() {
#             if ( false ){
#
#             var appDownloadLink = document.getElementById('nav-header-menu-download-mobile');
#
#             function trackEventAppDownloadAnalytics(os, pageId) {
#                 if (typeof meli_ga !== 'undefined' && (os ==='ANDROID' || os === 'IOS') ) {
#                  if(pageId) {
#                     meli_ga('send', 'event', 'MOBILE-APP-'+ os, 'DOWNLOAD-MENU', pageId);
#                     }
#                   else{
#                    meli_ga('send', 'event', 'MOBILE-APP-'+ os, 'DOWNLOAD-MENU');
#                  }
#               }
#             }
#
#             function handleAppDownload(event) {
#                 var os = event.currentTarget.getAttribute('data-os'),
#                 pageId = event.currentTarget.getAttribute('data-pageId');
#                 // track event in analytics
#                 trackEventAppDownloadAnalytics(os, pageId);
#             }
#
#             tiny.on(appDownloadLink, 'click', handleAppDownload);
#             }
# 	}());
# 	 }, function() {
#                         /*
#                             La instanciacion va en header.gsp para los que no tienen commons,
#                             en commons ver donde se agregan estos initis
#                         */
#                         meli.cart = new meli.Cart({
#                             element: document.getElementById('nav-cart'),
#                             endpoints: {
#                                 get: 'https://www.mercadolivre.com.br/gz/cart/info',
#                                 post: 'https://www.mercadolivre.com.br/gz/cart/api/item'
#                             },
#                             tr: {
#                                 legend: 'Adicionado ao seu carrinho',
#                                 action: 'Ver carrinho',
#                                 error: 'Ocorreu um erro ao adicionar o produto ao carrinho. Tente novamente.',
#                                 success: 'O produto foi adicionado corretamente'
#                             },
#                             link: 'https://www.mercadolivre.com.br/gz/cart',
#                             environment: 'desktop',
#                             newBehaviour: true,
#                             hasCombos: window.meliAppConfig ? window.meliAppConfig.hasCombos : false
#                         });
#                      }, function() {
# 						(function () {
# 							window.onBordingCP = new window.OnboardingCP({
# 								bus: window.meli,
# 								isNewBuyer: true,
# 								isMobile: false,
# 								trigger: '.nav-menu-cp',
# 								locale: 'pt_BR',
# 								domain: 'mercadolivre.com.br',
# 								siteId: 'MLB',
# 								isInferred: false,
# 							});
#                         }());
# 					 }, function() {
# 						(function () {
#                           var linkCP = document.querySelector('.nav-header-cp-anchor');
#                           if (linkCP) {
#                             linkCP.addEventListener('click', function () {
#                               if (meli_ga) {
#                                 meli_ga('send', 'event', 'CURRENT_LOCATION', 'NAVIGATION', 'PICK');
#                               }
#                                if (melidata) {
#                                 melidata('cleanAndSend', 'event', {
# 								  path: '/current_location/navigation/pick',
# 								  data: {
# 									  app: "search-frontend",
# 								  }
#                                 });
#                               }
#                             });
#                           }
#                         }());
# 					 }, function() {
# 										(function () {
# 										var linkCP = document.querySelector('.nav-menu-cp');
# 										if (linkCP) {
# 											linkCP.addEventListener('click', function () {
# 											if (meli_ga) {
# 												meli_ga('send', 'event', 'CURRENT_LOCATION', 'NAVIGATION', 'PICK');
# 											}
# 											if (melidata) {
# 												melidata('cleanAndSend', 'event', {
# 												path: '/current_location/navigation/pick'
# 												});
# 											}
# 											});
# 										}
# 										}());
# 									 }, function() {
# 	(function appDownload() {
# 	    if ( false ){
#
#             var appDownloadLink = document.getElementById('footer-applink');
#
#             function trackEventAppDownloadAnalytics(os, pageId) {
#                 if (typeof meli_ga !== 'undefined') {
#                     var osTrack = os.toUpperCase();
#                     meli_ga('send', 'event', 'MOBILE-APP-' + osTrack, 'DOWNLOAD-FOOTER', pageId);
#                 }
#             }
#
#             function handleAppDownload(event) {
#                 var os = event.currentTarget.getAttribute('data-os'),
#                     pageId = event.currentTarget.getAttribute('data-pageId');
#
#                 // track event in analytics
#                 trackEventAppDownloadAnalytics(os, pageId);
#             }
#
#             tiny.on(appDownloadLink, 'click', handleAppDownload);
#             }
# 	}());
#  }, "https://http2.mlstatic.com/storage/tag-manager/google-gtag-search-mlb.js", "https://http2.mlstatic.com/storage/tag-manager/kenshoo-ktag-mlb.js");
# 	});
#
#
# })(window, document);
#   </script>
#  </body>
# </html>

# %%
items = soup.find_all('div', {'class':'item__info'})
items
# Out:
# [<div class="item__info item--hide-right-col"><h2 class="item__title list-view-item-title"> <a class="item__info-title" href="https://produto.mercadolivre.com.br/MLB-687925636-holofote-refletor-super-led-duplo-100w-bivolt-bco-frio-_JM#position=1&amp;type=item&amp;tracking_id=be560c37-9282-4a6a-9521-582550356b55"> <span class="main-title"> Holofote Refletor Super Led Duplo 100w Bivolt - Bco Frio </span> </a> <div class="item__brand"> <a class="item__brand-link" href="https://loja.mercadolivre.com.br/coruja-mix"> <span class="item__brand-title-tos"> por Coruja Mix </span> </a> </div></h2> <div class="price__container"><div class="item__price"> <span class="price__symbol">R$</span> <span class="price__fraction">52</span> <span class="price__decimals">90</span></div> </div> <div class="item__stack_column highlighted"> <div class="item__stack_column__info"> <div class="stack_column_item installments highlighted"><span class="item-installments showInterest"> <span class="item-installments-multiplier"> 10x </span> <span class="item-installments-price"> R$ 6 <sup class="installment__decimals">01</sup> </span></span> </div> <div class="stack_column_item shipping highlighted"> <div class="item__shipping highlighted"> <p class="stack-item-info item--has-fulfillment"> </p> </div> </div> <div class="stack_column_item status"><div class="item__status"> <div class="item__condition"> 9171 vendidos </div></div> </div> </div> </div> <div class="stack_colum_right without-attributes without-reviews"> <div class="stack_column_right__bottom"> </div> </div> </div>,
#  <div class="item__info item--show-right-col"><h2 class="item__title list-view-item-title"> <a class="item__info-title" href="https://produto.mercadolivre.com.br/MLB-1167418397-lustre-luminaria-redondo-pendente-de-madeira-de-e-27-21x18cm-_JM#position=2&amp;type=item&amp;tracking_id=be560c37-9282-4a6a-9521-582550356b55"> <span class="main-title"> Lustre Luminária Redondo Pendente De Madeira De E-27 21x18cm </span> </a> <div class="item__brand"> <a class="item__brand-link" href="https://loja.mercadolivre.com.br/eled"> <span class="item__brand-title-tos"> por E-LED </span> </a> </div></h2> <div class="price__container"><div class="item__price"> <span class="price__symbol">R$</span> <span class="price__fraction">54</span> <span class="price__decimals">99</span></div> </div> <div class="item__stack_column highlighted"> <div class="item__stack_column__info"> <div class="stack_column_item installments highlighted"><span class="item-installments free-interest"> <span class="item-installments-multiplier"> 10x </span> <span class="item-installments-price"> R$ 5 <sup class="installment__decimals">50</sup> </span> <span class="item-installments-interest"> sem juros </span></span> </div> <div class="stack_column_item shipping highlighted"> <div class="item__shipping highlighted"> <p class="stack-item-info item--has-fulfillment"> </p> </div> </div> <div class="stack_column_item status"><div class="item__status"> <div class="item__condition"> 6008 vendidos </div></div> </div> </div> </div> <div class="stack_colum_right without-attributes without-reviews"> <div class="stack_column_right__bottom item__has-variations"> <div class="variation-picker__container"> <div class="ui-dropdown custom"> <input autocomplete="off" class="dropdown-trigger variation-picker__trigger" hidden="" id="dropdown-variations-1" type="checkbox"/> <label class="ui-dropdown__link" for="dropdown-variations-1"> <span class="variation-picker__label">Cor: </span> <span class="ui-dropdown__display variation-picker__label variation-picker__label-bold">Laranja-escuro</span> <div class="ui-dropdown__indicator"></div> </label> <div class="ui-dropdown__content dropdown__variations-content variation-picker cursor-wait variation-picker__size-3" data-size="3"> <ul class="variation-picker__sekeleton"> <li class="attrBox skeleton__box--0 selected-option" id="32057255518"> <img class="variation-picker__img hidden" data-src="https://http2.mlstatic.com/D_Q_NP_635992-MLB31081553995_062019-S.jpg" height="36" title="Laranja-escuro" width="36"/></li> <li class="attrBox skeleton__box--3" id="32057255524"> <img class="variation-picker__img hidden" data-src="https://http2.mlstatic.com/D_Q_NP_642064-MLB31081729093_062019-S.jpg" height="36" title="Chocolate" width="36"/></li> <li class="attrBox skeleton__box--5" id="32057255527"> <img class="variation-picker__img hidden" data-src="https://http2.mlstatic.com/D_Q_NP_624089-MLB31081721324_062019-S.jpg" height="36" title="Marrom-escuro" width="36"/></li></ul> </div> </div> </div> </div> </div> </div>,
#  <div class="item__info item--show-right-col"><h2 class="item__title list-view-item-title"> <a class="item__info-title" href="https://produto.mercadolivre.com.br/MLB-714922171-fita-led-3528-rolo-5m-300-leds-sanca-teto-dupla-face-3m-_JM#position=3&amp;type=item&amp;tracking_id=be560c37-9282-4a6a-9521-582550356b55"> <span class="main-title"> Fita Led 3528 Rolo 5m 300 Leds Sanca Teto Dupla Face 3m </span> </a></h2> <div class="price__container"><div class="item__price"> <span class="price__symbol">R$</span> <span class="price__fraction">18</span> <span class="price__decimals">90</span></div> </div> <div class="item__stack_column highlighted"> <div class="item__stack_column__info"> <div class="stack_column_item installments highlighted"><span class="item-installments showInterest"> <span class="item-installments-multiplier"> 3x </span> <span class="item-installments-price"> R$ 6 <sup class="installment__decimals">70</sup> </span></span> </div> <div class="stack_column_item shipping highlighted"> <div class="item__shipping highlighted"> <p class="stack-item-info item--has-fulfillment"> </p> </div> </div> <div class="stack_column_item status"><div class="item__status"> <div class="item__condition"> 22178 vendidos </div></div> </div> </div> </div> <div class="stack_colum_right without-attributes without-reviews"> <div class="stack_column_right__bottom item__has-variations"> <div class="variation-picker__container"> <div class="ui-dropdown custom"> <input autocomplete="off" class="dropdown-trigger variation-picker__trigger" hidden="" id="dropdown-variations-2" type="checkbox"/> <label class="ui-dropdown__link" for="dropdown-variations-2"> <span class="variation-picker__label">Cor: </span> <span class="ui-dropdown__display variation-picker__label variation-picker__label-bold">Verde</span> <div class="ui-dropdown__indicator"></div> </label> <div class="ui-dropdown__content dropdown__variations-content variation-picker cursor-wait variation-picker__size-6" data-size="7"> <ul class="variation-picker__sekeleton"> <li class="attrBox skeleton__box--0 selected-option" id="24724500735"> <img class="variation-picker__img hidden" data-src="https://http2.mlstatic.com/D_Q_NP_810586-MLB29555454664_032019-S.jpg" height="36" title="Verde" width="36"/></li> <li class="attrBox skeleton__box--1" id="24724500738"> <img class="variation-picker__img hidden" data-src="https://http2.mlstatic.com/D_Q_NP_772836-MLB29555434857_032019-S.jpg" height="36" title="Azul" width="36"/></li> <li class="attrBox skeleton__box--2" id="41236905828"> <img class="variation-picker__img hidden" data-src="https://http2.mlstatic.com/D_Q_NP_731688-MLB31643334598_072019-S.jpg" height="36" title="Ambar" width="36"/></li> <li class="attrBox skeleton__box--3" id="41236905833"> <img class="variation-picker__img hidden" data-src="https://http2.mlstatic.com/D_Q_NP_713781-MLB31643325245_072019-S.jpg" height="36" title="Rosa" width="36"/></li> <li class="attrBox skeleton__box--4" id="24724500729"> <img class="variation-picker__img hidden" data-src="https://http2.mlstatic.com/D_Q_NP_934428-MLB29555427907_032019-S.jpg" height="36" title="Branco Fio" width="36"/></li> <li class="attrBox skeleton__box--5" id="24724500732"> <img class="variation-picker__img hidden" data-src="https://http2.mlstatic.com/D_Q_NP_785978-MLB29555448715_032019-S.jpg" height="36" title="Branco Morno" width="36"/></li></ul> </div> </div> </div> </div> </div> </div>,
#  <div class="item__info item--hide-right-col"><h2 class="item__title list-view-item-title"> <a class="item__info-title" href="https://produto.mercadolivre.com.br/MLB-1200433628-par-barra-led-super-farol-drl-luz-diurna-12v-carro-moto-17cm-_JM#position=4&amp;type=item&amp;tracking_id=be560c37-9282-4a6a-9521-582550356b55"> <span class="main-title"> Par Barra Led Super Farol Drl Luz Diurna 12v Carro Moto 17cm </span> </a></h2> <div class="price__container"><div class="item__price"> <span class="price__symbol">R$</span> <span class="price__fraction">16</span> <span class="price__decimals">85</span></div> </div> <div class="item__stack_column highlighted"> <div class="item__stack_column__info"> <div class="stack_column_item installments highlighted"><span class="item-installments showInterest"> <span class="item-installments-multiplier"> 3x </span> <span class="item-installments-price"> R$ 5 <sup class="installment__decimals">97</sup> </span></span> </div> <div class="stack_column_item shipping highlighted"> <div class="item__shipping highlighted"> <p class="stack-item-info item--has-fulfillment"> </p> </div> </div> <div class="stack_column_item status"><div class="item__status"> <div class="item__condition"> 1024 vendidos </div></div> </div> </div> </div> <div class="stack_colum_right without-attributes without-reviews"> <div class="stack_column_right__bottom"> </div> </div> </div>,
#  <div class="item__info item--hide-right-col"><h2 class="item__title list-view-item-title"> <a class="item__info-title" href="https://produto.mercadolivre.com.br/MLB-813608758-fita-led-5m-rgb-16-cores-5050-pro-dagua-fonte-controle-_JM#position=5&amp;type=item&amp;tracking_id=be560c37-9282-4a6a-9521-582550356b55"> <span class="main-title"> Fita Led 5m Rgb 16 Cores 5050 Pro D'agua + Fonte + Controle </span> </a></h2> <div class="price__container"><div class="item__price"> <span class="price__symbol">R$</span> <span class="price__fraction">38</span> <span class="price__decimals">45</span></div> </div> <div class="item__stack_column highlighted"> <div class="item__stack_column__info"> <div class="stack_column_item installments highlighted"><span class="item-installments showInterest"> <span class="item-installments-multiplier"> 6x </span> <span class="item-installments-price"> R$ 7 <sup class="installment__decimals">11</sup> </span></span> </div> <div class="stack_column_item shipping highlighted"> <div class="item__shipping highlighted"> <p class="stack-item-info item--has-fulfillment"> </p> </div> </div> <div class="stack_column_item status"><div class="item__status"> <div class="item__condition"> 41725 vendidos </div></div> </div> </div> </div> <div class="stack_colum_right without-attributes without-reviews"> <div class="stack_column_right__bottom"> </div> </div> </div>,
#  <div class="item__info item--hide-right-col"><h2 class="item__title list-view-item-title"> <a class="item__info-title" href="https://produto.mercadolivre.com.br/MLB-684185577-mangueira-led-alto-brilho-decoraco-sanca-gesso-e-marcenaria-_JM#position=6&amp;type=item&amp;tracking_id=be560c37-9282-4a6a-9521-582550356b55"> <span class="main-title"> Mangueira Led Alto Brilho Decoração Sanca Gesso E Marcenaria </span> </a></h2> <div class="price__container"><div class="item__price"> <span class="price__symbol">R$</span> <span class="price__fraction">16</span> <span class="price__decimals">78</span></div> </div> <div class="item__stack_column highlighted"> <div class="item__stack_column__info"> <div class="stack_column_item installments highlighted"><span class="item-installments free-interest"> <span class="item-installments-multiplier"> 3x </span> <span class="item-installments-price"> R$ 5 <sup class="installment__decimals">59</sup> </span> <span class="item-installments-interest"> sem juros </span></span> </div> <div class="stack_column_item status"><div class="item__status"> <div class="item__condition"> 4046 vendidos - São Paulo </div></div> </div> </div> </div> <div class="stack_colum_right without-attributes without-reviews"> <div class="stack_column_right__bottom"> </div> </div> </div>,
#  <div class="item__info item--hide-right-col"><h2 class="item__title list-view-item-title"> <a class="item__info-title" href="https://produto.mercadolivre.com.br/MLB-1186663305-fita-led-digital-6803-rgb-c-controle-133-efeitos-ip67-5050-_JM#position=7&amp;type=item&amp;tracking_id=be560c37-9282-4a6a-9521-582550356b55"> <span class="main-title"> Fita Led Digital 6803 Rgb C/ Controle 133 Efeitos Ip67 5050 </span> </a></h2> <div class="price__container"><div class="item__price"> <span class="price__symbol">R$</span> <span class="price__fraction">56</span> <span class="price__decimals">90</span></div> </div> <div class="item__stack_column highlighted"> <div class="item__stack_column__info"> <div class="stack_column_item installments highlighted"><span class="item-installments showInterest"> <span class="item-installments-multiplier"> 10x </span> <span class="item-installments-price"> R$ 6 <sup class="installment__decimals">47</sup> </span></span> </div> <div class="stack_column_item shipping highlighted"> <div class="item__shipping highlighted"> <p class="stack-item-info item--has-fulfillment"> </p> </div> </div> <div class="stack_column_item status"><div class="item__status"> <div class="item__condition"> 4096 vendidos </div></div> </div> </div> </div> <div class="stack_colum_right without-attributes without-reviews"> <div class="stack_column_right__bottom"> </div> </div> </div>,
#  <div class="item__info item--hide-right-col"><h2 class="item__title list-view-item-title"> <a class="item__info-title" href="https://click1.mercadolivre.com.br/mclics/clicks/external/MLB/count?a=bhhyzYN8VdS3VrsujhtMQFv5Yua5BO7Y6BUmloSI4qtfCmyFgzsCYHDW1Er5djhspw8yCROAbGa9Hd8nqiJU36O3JifvGdXeTr6ZHIquc0L%2FDpyd%2B3wmFwqQWp9BgpsD3nWQMNXkzpXzESKJsRw3PFImcksjeFKO3AhHg0cb8EDeyFojiFqNdIbWN%2B828Esh4WVm8gRckIeA3RZ7%2F79CAroow5qF%2FtUgTfvJpfrCFpx8TqfICc5L1M3IlVthZgarHFOcsYa0syM370Uniln98lj4AAQ6PZJhuQvo21jc1pP4dHFNM07whVV8KbUpNRlNI483nsZnUtUvhnJ7Psflo6avsz%2F8cYljL3GpyquRUPtd5mSGNJMd%2Bx2ZqgaGZ2nYvK6ErD4GNLMekOW6heGp0b4zva%2B8pVTkBugunCQ%2FoQ1bE%2BKYfRjDfnQ29x%2FE%2Fqs98f6%2BRQQzFXUJOQUcndZ5I3tcPJC6ZQ3w3l2B3nIr%2FSRct6wA4fGGZGLWUYnYfcNQfDBT65TWXluBNxBWRt3Lz4x3RGRv7hioVOLvkOgFVvNLSZ8D7ngM28YdRbk3KwOuBtbe8HM3RfZLEkyiiIt3WaS8rxiK5iZfgYmtWsBB%2BmJPNHpa4oG4eJ9O%2Bi7PVrsOYYfb3jqe65ZHnkLfO4o0P3HANRZ4HIxmy5u6u42Mh%2B2e%2B5QHyyHEAqj8qUnvy3%2BuvvT4aalZknzAvbxYukORol93lo9nmVKSWKUC3qkhzVWO6I68P0YkUZTsAncxGXk2sj%2B50wM1Z%2FFhCY8z8FNcw9XLVIwgSSOrltDvGVNunSDmGj6CA28kR%2BH4nbtDYWn5poJ%2BGXRKpiOBkxqWzo24I0lKWG3uqi2dpN2PEZzOb7nwaH0kHScWsegGtv%2ByYTFtJyeH8gTWaPUyPnD4%2FYbR3h8%2F9JLSD87U%2FRk5W%2FkgwYbWtomB9s7GRFHbaarCaZG01RXIXzEWmiugoQ1rNLlwWEQw0kscGdr69lQyoY8ebCNeeXO1RtaZs6G6fzCYO%2BMreNdlF%2BONbvOZhtGCd2LIxjGP%2BgcQaWl5F77o0bWsDthmhiJ7oT5LmahXjgSfBgUnhmvfUOUrHRPKqIK9Vf1M9M0cgfDOo7R9fMcW3OxLYwT1QSg7i8W1R4ytulXGeTnFQ2%2BdWlBanU293iCjdbbY0l0O1MjaO5Ucrs7cZvQ7QEcaWZ02jq19At2o66lxZdk3bG5gQNhYb9l5bxYTfGnG0vQ%2B9wqinvPuqfDGSneYFgZU5RhtttsP1oF4KnSINZwXmOvoqqgxNhvC3Fw4QZY7JOCoUoL5u%2BgvhNITc3G0g9wigPafVcbkkQ4Xjpky1rpje6xYmZuSzUndjy4pNVVcOla8%2ByUzKlns2IfmUVqD%2Bne3oxOkSrR1EGVy4DOf9W0sareY9uUiKLiReK6y4JIRqhKKh%2BoRe8OYYWMJMBo9S2pu1ZM6qGfatH1d8YQjUEbQiRxs4Rxaf31tRv7KIoFTNkApRVqzQwC8Pd%2BChF6D6vFusFNRGzc%3D" rel="'nofollow'"> <span class="main-title"> Lustre Luminária Redondo Pendente De Madeira De E-27 21x18cm </span> </a> <div class="item__brand"> <a class="item__brand-link" href="https://loja.mercadolivre.com.br/eled"> <span class="item__brand-title-tos"> por E-LED </span> </a> </div></h2> <div class="price__container"><div class="item__price"> <span class="price__symbol">R$</span> <span class="price__fraction">54</span> <span class="price__decimals">99</span></div> </div> <div class="item__stack_column highlighted"> <div class="item__stack_column__info"> <div class="stack_column_item installments highlighted"><span class="item-installments free-interest"> <span class="item-installments-multiplier"> 10x </span> <span class="item-installments-price"> R$ 5 <sup class="installment__decimals">50</sup> </span> <span class="item-installments-interest"> sem juros </span></span> </div> <div class="stack_column_item shipping highlighted"> <div class="item__shipping highlighted"> <p class="stack-item-info item--has-fulfillment"> </p> </div> </div> <div class="stack_column_item status"><div class="item__status"> <div class="item__condition"> 6008 vendidos </div></div> </div> </div> </div> <div class="stack_colum_right without-attributes without-reviews"> <div class="stack_column_right__bottom"> </div> </div> </div>,
#  <div class="item__info item--hide-right-col"><h2 class="item__title list-view-item-title"> <a class="item__info-title" href="https://produto.mercadolivre.com.br/MLB-690224783-fita-led-3528-rolo-5m-300-leds-varias-cores-prova-dagua-sf-_JM#position=9&amp;type=item&amp;tracking_id=be560c37-9282-4a6a-9521-582550356b55"> <span class="main-title"> Fita Led 3528 Rolo 5m 300 Leds Várias Cores Prova Dágua - Sf </span> </a></h2> <div class="price__container"><div class="item__price"> <span class="price__symbol">R$</span> <span class="price__fraction">17</span> <span class="price__decimals">50</span></div> </div> <div class="item__stack_column highlighted"> <div class="item__stack_column__info"> <div class="stack_column_item installments highlighted"><span class="item-installments showInterest"> <span class="item-installments-multiplier"> 3x </span> <span class="item-installments-price"> R$ 6 <sup class="installment__decimals">20</sup> </span></span> </div> <div class="stack_column_item shipping highlighted"> <div class="item__shipping highlighted"> <p class="stack-item-info item--has-fulfillment"> </p> </div> </div> <div class="stack_column_item status"><div class="item__status"> <div class="item__condition"> 13373 vendidos </div></div> </div> </div> </div> <div class="stack_colum_right without-attributes without-reviews"> <div class="stack_column_right__bottom"> </div> </div> </div>,
#  <div class="item__info item--hide-right-col"><h2 class="item__title list-view-item-title"> <a class="item__info-title" href="https://produto.mercadolivre.com.br/MLB-1186966928-kit-lmpadas-ultra-led-full-7600l-efeito-xenon-super-branca-_JM#position=10&amp;type=item&amp;tracking_id=be560c37-9282-4a6a-9521-582550356b55"> <span class="main-title"> Kit Lâmpadas Ultra Led Full 7600l Efeito Xenon Super Branca </span> </a></h2> <div class="price__container"> <span class="price-old" itemprop="price-old"> <del> R$ 52 </del> </span><div class="item__price item__price-discount"> <span class="price__symbol">R$</span> <span class="price__fraction">45</span> <span class="price__decimals">99</span></div> <div class="item__discount">13% OFF</div> </div> <div class="item__stack_column highlighted"> <div class="item__stack_column__info"> <div class="stack_column_item installments highlighted"><span class="item-installments showInterest"> <span class="item-installments-multiplier"> 6x </span> <span class="item-installments-price"> R$ 8 <sup class="installment__decimals">51</sup> </span></span> </div> <div class="stack_column_item shipping highlighted"> <div class="item__shipping highlighted"> <p class="stack-item-info item--has-fulfillment"> </p> </div> </div> <div class="stack_column_item status"><div class="item__status"> <div class="item__condition"> 3775 vendidos </div></div> </div> </div> </div> <div class="stack_colum_right without-attributes without-reviews"> <div class="stack_column_right__bottom"> </div> </div> </div>,
#  <div class="item__info item--hide-right-col"><h2 class="item__title list-view-item-title"> <a class="item__info-title" href="https://produto.mercadolivre.com.br/MLB-1242378452-c6-lampada-led-automotiva-h1h3h4h7hb3hb4h27-xenon-_JM#position=11&amp;type=item&amp;tracking_id=be560c37-9282-4a6a-9521-582550356b55"> <span class="main-title"> C6 Lampada Led Automotiva H1/h3/h4/h7/hb3/hb4/h27 Xenon </span> </a></h2> <div class="price__container"><div class="item__price"> <span class="price__symbol">R$</span> <span class="price__fraction">39</span> <span class="price__decimals">99</span></div> </div> <div class="item__stack_column highlighted"> <div class="item__stack_column__info"> <div class="stack_column_item installments highlighted"><span class="item-installments showInterest"> <span class="item-installments-multiplier"> 6x </span> <span class="item-installments-price"> R$ 7 <sup class="installment__decimals">40</sup> </span></span> </div> <div class="stack_column_item shipping highlighted"> <div class="item__shipping highlighted"> <p class="stack-item-info item--has-fulfillment"> </p> </div> </div> <div class="stack_column_item status"><div class="item__status"> <div class="item__condition"> 1624 vendidos </div></div> </div> </div> </div> <div class="stack_colum_right without-attributes without-reviews"> <div class="stack_column_right__bottom"> </div> </div> </div>,
#  <div class="item__info item--hide-right-col"><h2 class="item__title list-view-item-title"> <a class="item__info-title" href="https://produto.mercadolivre.com.br/MLB-681351286-fita-led-5-metros-silicone-prova-dagua-diversas-cores-12v-_JM#position=12&amp;type=item&amp;tracking_id=be560c37-9282-4a6a-9521-582550356b55"> <span class="main-title"> Fita Led 5 Metros Silicone Prova Dagua Diversas Cores 12v </span> </a></h2> <div class="price__container"><div class="item__price"> <span class="price__symbol">R$</span> <span class="price__fraction">16</span> <span class="price__decimals">49</span></div> </div> <div class="item__stack_column highlighted"> <div class="item__stack_column__info"> <div class="stack_column_item installments highlighted"><span class="item-installments free-interest"> <span class="item-installments-multiplier"> 3x </span> <span class="item-installments-price"> R$ 5 <sup class="installment__decimals">50</sup> </span> <span class="item-installments-interest"> sem juros </span></span> </div> <div class="stack_column_item status"><div class="item__status"> <div class="item__condition"> 11446 vendidos - Rio de Janeiro </div></div> </div> </div> </div> <div class="stack_colum_right without-attributes without-reviews"> <div class="stack_column_right__bottom"> </div> </div> </div>,
#  <div class="item__info item--hide-right-col"><h2 class="item__title list-view-item-title"> <a class="item__info-title" href="https://produto.mercadolivre.com.br/MLB-871089449-fita-led-5m-ultra-rgb-5050-prova-dagua-controle-fonte-_JM#position=13&amp;type=item&amp;tracking_id=be560c37-9282-4a6a-9521-582550356b55"> <span class="main-title"> Fita Led 5m Ultra Rgb 5050 Prova D'agua + Controle + Fonte </span> </a> <div class="item__brand"> <a class="item__brand-link" href="https://loja.mercadolivre.com.br/arco-iris-led"> <span class="item__brand-title-tos"> por Arco Íris Led </span> </a> </div></h2> <div class="price__container"><div class="item__price"> <span class="price__symbol">R$</span> <span class="price__fraction">39</span> <span class="price__decimals">90</span></div> </div> <div class="item__stack_column highlighted"> <div class="item__stack_column__info"> <div class="stack_column_item installments highlighted"><span class="item-installments free-interest"> <span class="item-installments-multiplier"> 6x </span> <span class="item-installments-price"> R$ 6 <sup class="installment__decimals">65</sup> </span> <span class="item-installments-interest"> sem juros </span></span> </div> <div class="stack_column_item status"><div class="item__status"> <div class="item__condition"> 1371 vendidos </div></div> </div> </div> </div> <div class="stack_colum_right without-attributes without-reviews"> <div class="stack_column_right__bottom"> </div> </div> </div>,
#  <div class="item__info item--hide-right-col"><h2 class="item__title list-view-item-title"> <a class="item__info-title" href="https://click1.mercadolivre.com.br/mclics/clicks/external/MLB/count?a=am8LCpjO0mUQ2Sd2tSNpz4lFACgoB2QUP67sOCXjmi%2F%2FCBtxd%2FUSGmJnJ931L57PKlZfZ%2BRaO%2FPLahUI7HJcVYZwZAjQKCrDd1mVr8S67G0iMH65kGM1zKCtt4y4BWvCUYotfjDfyWx0Dfzg1PLW%2Bayb99HXsYDwsiIFEH8zO6i7HnTHOqca5IALL%2Fgke7%2Fg1jitAeGBe5GEUZfWD%2F8FIk6UNAGTrDkXDnbL47xT7HEwjzv1BttrK6swC2hKHjagtCekQFo3%2Bskq6UE8FslHQrGKtDmnDeAmu%2FMRN%2Brc9AcuEhduEU2TncH%2FO5Cq%2FuBuvq6nr475PGGsxo3OjTdqUy6OhXX3zTnBZqj%2F3RmDuSS9Qv1Sc3B34oS759%2BZfhRnvV6VUCETb6K420Q6EBpV5g94Olkc4n3irxdxsoB1eiLbpy21%2Fp4fnp%2Bc2jG3RkHaiOQqH1y3b3NIYxOfAxG00EpQmle0UAcp%2BYS%2B1e7viizQWXdO8WrleOdJ6iapTt5bfNDllU1WHqM%2BmeZc6x4eW3WCor2KfzEQSARwPBLNAARLzTildUbz6Ur%2FoGPX2Ad6kNw2T%2FnnRamLm3YItdzJVHLZoNZxFCc70Xf0Jk8XjeswTCIdrNCpZYSPGYnYPOmDZ15DNLSTZ%2FOp8XeuGw%2F6uRjklxXgSJJedloJ%2FWhYWj6HneDgDcx0YcR2nmoWmkkr0hO6pZbfkydta%2BMYv6f%2FLfVArwXbJKqMrLOeluxZHs9j7T5cQR0vzfvHeXh8XtLs1W7fL%2BdakoJyZy6KIeGR2RLRCvkI9KzUaGWMGayCwOw4%2FHIWDOBQKMiRvwsaMBBMixzkYm%2FYuamf528WOXQLn0%2B3wHnuXvs2TxwJr3abCLK%2FU0Dtl8V%2FQxkHgYHUlDLydLEsL%2BxCXSK%2B6Mm5WCMWMYxDfIPI%2BMQMAePtdCZRdcfRrEB%2Bm3W0AlfDZPYp4EUU4XvTpAly0ognBXXWZ3V8qomrIfkQGab0ddyozV5erV2eiouZ2qjnvvQhy1kfe4HWcHMAaVTtlL%2F7JBD0meG1cVnChXSnL7gtAqHQuiag1QZNolY2zjEZlD9G4za4Zkj90wlUuhtW0L3uBAnYcd54LiUADuRC1f%2Fq6utCzYSEI1vbipMMvInmKO6r%2BTAb2L0AlV9EAlBn2yJJ2%2BITiq9BBM%2FPUk8DtOr7Kw4z6BzcRao6r7YrrlXCDr35ErVow9pBE5hYAaH%2FP8hwKvVChf7b2cA8dhqXzXl1l5Vy50KSYOJfCqYAYjWDXDMstUkZLMNH3qcnhYFx5a6tcOLVZ6%2B37gEhbn7TKqJqpFOJUrjg27QklAp%2B5gPYMiNwwG%2Bxd4SlckJEFqiZhUqA8BAXVqcn1Z2iZu8RP1oxxLJiC37db4nBH6EjO%2B5%2BGL6MyV5AIkxJC8JMUTwufPOz6HIJkzPBLESyYp1m4TkT%2B2731hJ8had%2BWG8WZBxwKuyvsG%2FnEW%2BuJ3XZqkuufy9WuvNI7EXgS%2FXbeHiwZxDe2xCZ0NYKXMutceG0Og%3D%3D" rel="'nofollow'"> <span class="main-title"> Mangueira Led Alto Brilho Decoração Sanca Gesso E Marcenaria </span> </a></h2> <div class="price__container"><div class="item__price"> <span class="price__symbol">R$</span> <span class="price__fraction">16</span> <span class="price__decimals">78</span></div> </div> <div class="item__stack_column highlighted"> <div class="item__stack_column__info"> <div class="stack_column_item installments highlighted"><span class="item-installments free-interest"> <span class="item-installments-multiplier"> 3x </span> <span class="item-installments-price"> R$ 5 <sup class="installment__decimals">59</sup> </span> <span class="item-installments-interest"> sem juros </span></span> </div> <div class="stack_column_item status"><div class="item__status"> <div class="item__condition"> 4046 vendidos - São Paulo </div></div> </div> </div> </div> <div class="stack_colum_right without-attributes without-reviews"> <div class="stack_column_right__bottom"> </div> </div> </div>,
#  <div class="item__info item--hide-right-col"><h2 class="item__title list-view-item-title"> <a class="item__info-title" href="https://produto.mercadolivre.com.br/MLB-1178279975-lampada-bluetooth-led-rgb-branco-caixa-som-musical-bulbo-_JM#position=15&amp;type=item&amp;tracking_id=be560c37-9282-4a6a-9521-582550356b55"> <span class="main-title"> Lampada Bluetooth Led Rgb Branco Caixa Som Musical Bulbo </span> </a></h2> <div class="price__container"> <span class="price-old" itemprop="price-old"> <del> R$ 34 </del> </span><div class="item__price item__price-discount"> <span class="price__symbol">R$</span> <span class="price__fraction">30</span> <span class="price__decimals">99</span></div> <div class="item__discount">11% OFF</div> </div> <div class="item__stack_column highlighted"> <div class="item__stack_column__info"> <div class="stack_column_item installments highlighted"><span class="item-installments showInterest"> <span class="item-installments-multiplier"> 6x </span> <span class="item-installments-price"> R$ 5 <sup class="installment__decimals">73</sup> </span></span> </div> <div class="stack_column_item shipping highlighted"> <div class="item__shipping highlighted"> <p class="stack-item-info item--has-fulfillment"> </p> </div> </div> <div class="stack_column_item status"><div class="item__status"> <div class="item__condition"> 5020 vendidos </div></div> </div> </div> </div> <div class="stack_colum_right without-attributes without-reviews"> <div class="stack_column_right__bottom"> </div> </div> </div>,
#  <div class="item__info item--hide-right-col"><h2 class="item__title list-view-item-title"> <a class="item__info-title" href="https://produto.mercadolivre.com.br/MLB-1234749637-fita-led-digital-cor-6803-rgb-133-efeitoscontrole-_JM#position=16&amp;type=item&amp;tracking_id=be560c37-9282-4a6a-9521-582550356b55"> <span class="main-title"> Fita Led Digital Cor 6803 Rgb 133 Efeitos+controle </span> </a></h2> <div class="price__container"><div class="item__price"> <span class="price__symbol">R$</span> <span class="price__fraction">52</span> <span class="price__decimals">99</span></div> </div> <div class="item__stack_column highlighted"> <div class="item__stack_column__info"> <div class="stack_column_item installments highlighted"><span class="item-installments showInterest"> <span class="item-installments-multiplier"> 10x </span> <span class="item-installments-price"> R$ 6 <sup class="installment__decimals">02</sup> </span></span> </div> <div class="stack_column_item status"><div class="item__status"> <div class="item__condition"> 1079 vendidos - São Paulo </div></div> </div> </div> </div> <div class="stack_colum_right without-attributes without-reviews"> <div class="stack_column_right__bottom"> </div> </div> </div>,
#  <div class="item__info item--hide-right-col"><h2 class="item__title list-view-item-title"> <a class="item__info-title" href="https://produto.mercadolivre.com.br/MLB-1240550171-fita-led-5m-rgb-16-cores-5050-prova-dagua-fonte-controle-_JM#position=17&amp;type=item&amp;tracking_id=be560c37-9282-4a6a-9521-582550356b55"> <span class="main-title"> Fita Led 5m Rgb 16 Cores 5050 Prova D'agua + Fonte+ Controle </span> </a></h2> <div class="price__container"><div class="item__price"> <span class="price__symbol">R$</span> <span class="price__fraction">32</span> <span class="price__decimals">33</span></div> </div> <div class="item__stack_column highlighted"> <div class="item__stack_column__info"> <div class="stack_column_item installments highlighted"><span class="item-installments showInterest"> <span class="item-installments-multiplier"> 6x </span> <span class="item-installments-price"> R$ 5 <sup class="installment__decimals">98</sup> </span></span> </div> <div class="stack_column_item shipping highlighted"> <div class="item__shipping highlighted"> <p class="stack-item-info item--has-fulfillment"> </p> </div> </div> <div class="stack_column_item status"><div class="item__status"> <div class="item__condition"> 2626 vendidos </div></div> </div> </div> </div> <div class="stack_colum_right without-attributes without-reviews"> <div class="stack_column_right__bottom"> </div> </div> </div>,
#  <div class="item__info item--hide-right-col"><h2 class="item__title list-view-item-title"> <a class="item__info-title" href="https://produto.mercadolivre.com.br/MLB-1143415168-fita-super-led-5050-branco-frio-300-leds-5m-fonte-gratis-_JM#position=18&amp;type=item&amp;tracking_id=be560c37-9282-4a6a-9521-582550356b55"> <span class="main-title"> Fita Super Led 5050 Branco Frio 300 Leds 5m + Fonte Grátis </span> </a></h2> <div class="price__container"><div class="item__price"> <span class="price__symbol">R$</span> <span class="price__fraction">36</span> <span class="price__decimals">90</span></div> </div> <div class="item__stack_column highlighted"> <div class="item__stack_column__info"> <div class="stack_column_item installments highlighted"><span class="item-installments showInterest"> <span class="item-installments-multiplier"> 6x </span> <span class="item-installments-price"> R$ 6 <sup class="installment__decimals">83</sup> </span></span> </div> <div class="stack_column_item shipping highlighted"> <div class="item__shipping highlighted"> <p class="stack-item-info item--has-fulfillment"> </p> </div> </div> <div class="stack_column_item status"><div class="item__status"> <div class="item__condition"> 5192 vendidos </div></div> </div> </div> </div> <div class="stack_colum_right without-attributes without-reviews"> <div class="stack_column_right__bottom"> </div> </div> </div>,
#  <div class="item__info item--show-right-col"><h2 class="item__title list-view-item-title"> <a class="item__info-title" href="https://produto.mercadolivre.com.br/MLB-940968033-arandela-2-focos-e-frisos-externa-parede-muro-st327-_JM#position=19&amp;type=item&amp;tracking_id=be560c37-9282-4a6a-9521-582550356b55"> <span class="main-title"> Arandela 2 Focos E Frisos Externa Parede Muro St327 </span> </a></h2> <div class="price__container"><div class="item__price"> <span class="price__symbol">R$</span> <span class="price__fraction">29</span> <span class="price__decimals">90</span></div> </div> <div class="item__stack_column highlighted"> <div class="item__stack_column__info"> <div class="stack_column_item installments highlighted"><span class="item-installments free-interest"> <span class="item-installments-multiplier"> 5x </span> <span class="item-installments-price"> R$ 5 <sup class="installment__decimals">98</sup> </span> <span class="item-installments-interest"> sem juros </span></span> </div> <div class="stack_column_item shipping highlighted"> <div class="item__shipping highlighted"> <p class="stack-item-info item--has-fulfillment"> </p> </div> </div> <div class="stack_column_item status"><div class="item__status"> <div class="item__condition"> 1772 vendidos </div></div> </div> </div> </div> <div class="stack_colum_right without-attributes without-reviews"> <div class="stack_column_right__bottom item__has-variations"> <div class="variation-picker__container"> <div class="ui-dropdown custom"> <input autocomplete="off" class="dropdown-trigger variation-picker__trigger" hidden="" id="dropdown-variations-18" type="checkbox"/> <label class="ui-dropdown__link" for="dropdown-variations-18"> <span class="variation-picker__label">Cor: </span> <span class="ui-dropdown__display variation-picker__label variation-picker__label-bold">Marrom</span> <div class="ui-dropdown__indicator"></div> </label> <div class="ui-dropdown__content dropdown__variations-content variation-picker cursor-wait variation-picker__size-3" data-size="3"> <ul class="variation-picker__sekeleton"> <li class="attrBox skeleton__box--0 selected-option" id="31206173632"> <img class="variation-picker__img hidden" data-src="https://http2.mlstatic.com/D_Q_NP_627984-MLB31201550496_062019-S.jpg" height="36" title="Marrom" width="36"/></li> <li class="attrBox skeleton__box--3" id="31206173625"> <img class="variation-picker__img hidden" data-src="https://http2.mlstatic.com/D_Q_NP_627984-MLB31201550496_062019-S.jpg" height="36" title="Branco" width="36"/></li> <li class="attrBox skeleton__box--5" id="31206173639"> <img class="variation-picker__img hidden" data-src="https://http2.mlstatic.com/D_Q_NP_627984-MLB31201550496_062019-S.jpg" height="36" title="Preto" width="36"/></li></ul> </div> </div> </div> </div> </div> </div>,
#  <div class="item__info item--hide-right-col"><h2 class="item__title list-view-item-title"> <a class="item__info-title" href="https://click1.mercadolivre.com.br/mclics/clicks/external/MLB/count?a=LIFh%2FiEHImia77rtoPXdBBEsaei%2Bjcc4waTISL3o3u5uSV5CZLNOL9nIX6whqhXu3SPEn29l%2BhwvbIqE2yPMY1EQ8nHgsEw8qfWZ2ONNcIzkpPSn21KjT4vdG1griF2T3e5Hv1A%2BmurkxOIg%2B8YyBGVBCMQabTIoIVFhqOhy4opSurZ%2FRoNO67dhbx5H89MDZs%2FhVnm%2Fdr5%2FfetZnOo%2BIVSE2YXYnWy8CabhIz4cQV0assVlrPvhm12uEbbmyMAzQVAb0kwDtj1UdElDZAD9h%2F%2B1tphRbI7Xsz00elKvjtOMAYYiclTvWWSFMz7dM3EAB44REEO5vQEv%2BaWU15JUtNBQ8cKe%2FTYsOjIOfx4YqhOGV77gjH7P6LUWuo%2FgTi9coJMIIwmbYVbWH1ijxFzjl95xD88jXipLpAuq%2FPJsXiAWD7f303ItQZvXwhTbYmqWRCNdNuDYNOsMxs7zUIwBL2qrnAuF8EaQcBgukdToCRNFaCFxiYq7ZHhl0wnCQVpDG0DhHedaNWwTD13EK%2BPdfXY6%2F4lPDv8q8PO8nMTmDRAe6NmCzLfyybJsAGQifDqPqphzLzOdMIXM3VIqiN5iaalagjNwZJjONMmZuTDeLh%2FGV6H%2BPRx%2F3CAKSznQZjWCssT26cmn6m2EQnfuqbDnglfxkyh3QMEA4JB1YzxxTT3EWXw3h9mklooNXn9EcXq9M2qjqiFryRWj1dp2vCRN8QMkPW%2BJHhWBJrKwdnw2SqEoRxDmMHLyW9H%2FCMd2St5mRd0VrjP5zOHTMsKXzDJTFMHVdFqyf%2FT%2F4Ihkr2zeFoKSZVcuRZml0nZyrj6jaqubd4fkH%2BVkoEGtBpIM8pXGLp2GBdowz%2BNgwLkSsNS6ScI3gVW%2Bs%2FGY7kjcOATD3czUQlbwoEwUGW961p1dT9lWmPD91TkzUa9iGHpQkBHi%2F2DExKRbF9Csq92DBh70HyQqKomFm7is3O6oLvzNDNWMPqYX2exWOniMgk2tvI5kFAK%2FlMsZx223X14fZf%2BI9aa4m24NaWwE2tbLl2bjBOeFXjM%2Bi83UA62tcpJn%2FLtB87kA62TpHCerKHJeXZ%2BvjO1d%2FKT6fgm5alwd7avCDX3JNKG1tcXp%2FKOvoE7UKo%2F90jV3El%2BB0yseWlHkXPm2fjCelRbnYKi543U3xmW6OIOQDBRSuxbB8gRd38j8ibRRYsvR4yMIM0%2Fepm3kyllfndn0q7zdHLBxo%2BA5Xnd3EpO09GpsKhrhnqAfVG8XNexNrIRRDNaP7BotQJcr6woHHye3UPH%2By0xhyXyHWnbj0ONErKRKguRp7i0BLMp3Y%2FRgmzkuiThmyYQwluzrHa0SQyqjLqfNsdq5VnNpqd1IkdUEm3VdPJ4%2F8i8t2t1fwVVxubVmCLum5Y%2BSB%2BwhTWjn3YVbZ%2BrtZHcPvR1HlTyu%2FAE%2Bg%2BMwJA9LkuSzZX1WfNNEl4fjvOve%2BOx96ct1Dqu8B7QszmwTyR5SoOzG7%2FeBQBt8PNmJPyoRoYI4QAw%3D" rel="'nofollow'"> <span class="main-title"> Kit 2 Lampada Led H1 H3 H4 H7 Hb3 Hb4 H11 Branca </span> </a></h2> <div class="price__container"><div class="item__price"> <span class="price__symbol">R$</span> <span class="price__fraction">34</span> <span class="price__decimals">99</span></div> </div> <div class="item__stack_column highlighted"> <div class="item__stack_column__info"> <div class="stack_column_item installments highlighted"><span class="item-installments showInterest"> <span class="item-installments-multiplier"> 6x </span> <span class="item-installments-price"> R$ 6 <sup class="installment__decimals">47</sup> </span></span> </div> <div class="stack_column_item shipping highlighted"> <div class="item__shipping highlighted"> <p class="stack-item-info item--has-fulfillment"> </p> </div> </div> <div class="stack_column_item status"><div class="item__status"> <div class="item__condition"> 1362 vendidos </div></div> </div> </div> </div> <div class="stack_colum_right without-attributes without-reviews"> <div class="stack_column_right__bottom"> </div> </div> </div>,
#  <div class="item__info item--hide-right-col"><h2 class="item__title list-view-item-title"> <a class="item__info-title" href="https://produto.mercadolivre.com.br/MLB-1241667501-fita-led-5m-ultra-rgb-3528-prova-dagua-controle-fonte-_JM#position=21&amp;type=item&amp;tracking_id=be560c37-9282-4a6a-9521-582550356b55"> <span class="main-title"> Fita Led 5m Ultra Rgb 3528 Prova D'agua + Controle + Fonte </span> </a></h2> <div class="price__container"><div class="item__price"> <span class="price__symbol">R$</span> <span class="price__fraction">24</span> <span class="price__decimals">89</span></div> </div> <div class="item__stack_column highlighted"> <div class="item__stack_column__info"> <div class="stack_column_item installments highlighted"><span class="item-installments showInterest"> <span class="item-installments-multiplier"> 4x </span> <span class="item-installments-price"> R$ 6 <sup class="installment__decimals">72</sup> </span></span> </div> <div class="stack_column_item shipping highlighted"> <div class="item__shipping highlighted"> <p class="stack-item-info item--has-fulfillment"> </p> </div> </div> <div class="stack_column_item status"><div class="item__status"> <div class="item__condition"> 1138 vendidos </div></div> </div> </div> </div> <div class="stack_colum_right without-attributes without-reviews"> <div class="stack_column_right__bottom"> </div> </div> </div>,
#  <div class="item__info item--hide-right-col"><h2 class="item__title list-view-item-title"> <a class="item__info-title" href="https://produto.mercadolivre.com.br/MLB-696084662-luminaria-luz-solar-spot-super-led-grama-jardim-promoco-_JM#position=22&amp;type=item&amp;tracking_id=be560c37-9282-4a6a-9521-582550356b55"> <span class="main-title"> Luminária Luz Solar Spot Super Led Grama Jardim Promoção </span> </a></h2> <div class="price__container"><div class="item__price"> <span class="price__symbol">R$</span> <span class="price__fraction">39</span> <span class="price__decimals">80</span></div> </div> <div class="item__stack_column highlighted"> <div class="item__stack_column__info"> <div class="stack_column_item installments highlighted"><span class="item-installments showInterest"> <span class="item-installments-multiplier"> 6x </span> <span class="item-installments-price"> R$ 7 <sup class="installment__decimals">36</sup> </span></span> </div> <div class="stack_column_item shipping highlighted"> <div class="item__shipping highlighted"> <p class="stack-item-info item--has-fulfillment"> </p> </div> </div> <div class="stack_column_item status"><div class="item__status"> <div class="item__condition"> 27983 vendidos </div></div> </div> </div> </div> <div class="stack_colum_right without-attributes without-reviews"> <div class="stack_column_right__bottom"> </div> </div> </div>,
#  <div class="item__info item--hide-right-col"><h2 class="item__title list-view-item-title"> <a class="item__info-title" href="https://produto.mercadolivre.com.br/MLB-716805688-kit-20-spot-super-led-3w-branco-frio-embutir-gesso-sanca-_JM#position=23&amp;type=item&amp;tracking_id=be560c37-9282-4a6a-9521-582550356b55"> <span class="main-title"> Kit 20 Spot Super Led 3w Branco Frio Embutir Gesso Sanca </span> </a></h2> <div class="price__container"><div class="item__price"> <span class="price__symbol">R$</span> <span class="price__fraction">119</span> <span class="price__decimals">90</span></div> </div> <div class="item__stack_column highlighted"> <div class="item__stack_column__info"> <div class="stack_column_item installments highlighted"><span class="item-installments showInterest"> <span class="item-installments-multiplier"> 12x </span> <span class="item-installments-price"> R$ 11 <sup class="installment__decimals">46</sup> </span></span> </div> <div class="stack_column_item shipping highlighted"> <div class="item__shipping free-shipping highlighted"> <p class="stack-item-info item--has-fulfillment"> Frete grátis</p> </div> </div> <div class="stack_column_item status"><div class="item__status"> <div class="item__condition"> 5496 vendidos </div></div> </div> </div> </div> <div class="stack_colum_right without-attributes without-reviews"> <div class="stack_column_right__bottom"> </div> </div> </div>,
#  <div class="item__info item--hide-right-col"><h2 class="item__title list-view-item-title"> <a class="item__info-title" href="https://produto.mercadolivre.com.br/MLB-916154575-kit-4-farol-milha-redondo-42w-12v24v-14-leds-carro-jeep-_JM#position=24&amp;type=item&amp;tracking_id=be560c37-9282-4a6a-9521-582550356b55"> <span class="main-title"> Kit 4 Farol Milha Redondo 42w 12v/24v 14 Leds Carro Jeep </span> </a></h2> <div class="price__container"><div class="item__price"> <span class="price__symbol">R$</span> <span class="price__fraction">159</span> <span class="price__decimals">99</span></div> </div> <div class="item__stack_column highlighted"> <div class="item__stack_column__info"> <div class="stack_column_item installments highlighted"><span class="item-installments showInterest"> <span class="item-installments-multiplier"> 12x </span> <span class="item-installments-price"> R$ 15 <sup class="installment__decimals">29</sup> </span></span> </div> <div class="stack_column_item shipping highlighted"> <div class="item__shipping free-shipping highlighted"> <p class="stack-item-info item--has-fulfillment"> Frete grátis</p> </div> </div> <div class="stack_column_item status"><div class="item__status"> <div class="item__condition"> 2461 vendidos </div></div> </div> </div> </div> <div class="stack_colum_right without-attributes without-reviews"> <div class="stack_column_right__bottom"> </div> </div> </div>,
#  <div class="item__info item--hide-right-col"><h2 class="item__title list-view-item-title"> <a class="item__info-title" href="https://produto.mercadolivre.com.br/MLB-1291964515-kit-super-led-plus-ultra-cinoy-12000-lumens-12v-24v-h1-h3-h7-h11-hb3-hb4-_JM#position=25&amp;type=item&amp;tracking_id=be560c37-9282-4a6a-9521-582550356b55"> <span class="main-title"> Kit Super Led Plus Ultra Cinoy 12000 Lumens 12v 24v H1 H3 H7 H11 Hb3 Hb4 </span> </a></h2> <div class="price__container"><div class="item__price"> <span class="price__symbol">R$</span> <span class="price__fraction">129</span> <span class="price__decimals">99</span></div> </div> <div class="item__stack_column highlighted"> <div class="item__stack_column__info"> <div class="stack_column_item installments highlighted"><span class="item-installments showInterest"> <span class="item-installments-multiplier"> 12x </span> <span class="item-installments-price"> R$ 12 <sup class="installment__decimals">42</sup> </span></span> </div> <div class="stack_column_item shipping highlighted"> <div class="item__shipping free-shipping highlighted"> <p class="stack-item-info item--has-fulfillment"> Frete grátis</p> </div> </div> <div class="stack_column_item status"><div class="item__status"> <div class="item__condition"> 1576 vendidos </div></div> </div> </div> </div> <div class="stack_colum_right without-attributes without-reviews"> <div class="stack_column_right__bottom"> </div> </div> </div>,
#  <div class="item__info item--hide-right-col"><h2 class="item__title list-view-item-title"> <a class="item__info-title" href="https://produto.mercadolivre.com.br/MLB-963528235-fita-led-digital-6803-rgb-com-controle-328-efeitos-3-vias-_JM#position=26&amp;type=item&amp;tracking_id=be560c37-9282-4a6a-9521-582550356b55"> <span class="main-title"> Fita Led Digital 6803 Rgb Com Controle 328 Efeitos 3 Vias </span> </a></h2> <div class="price__container"><div class="item__price"> <span class="price__symbol">R$</span> <span class="price__fraction">59</span></div> </div> <div class="item__stack_column highlighted"> <div class="item__stack_column__info"> <div class="stack_column_item installments highlighted"><span class="item-installments free-interest"> <span class="item-installments-multiplier"> 10x </span> <span class="item-installments-price"> R$ 5 <sup class="installment__decimals">90</sup> </span> <span class="item-installments-interest"> sem juros </span></span> </div> <div class="stack_column_item status"><div class="item__status"> <div class="item__condition"> 3112 vendidos - São Paulo </div></div> </div> </div> </div> <div class="stack_colum_right without-attributes without-reviews"> <div class="stack_column_right__bottom"> </div> </div> </div>,
#  <div class="item__info item--hide-right-col"><h2 class="item__title list-view-item-title"> <a class="item__info-title" href="https://produto.mercadolivre.com.br/MLB-716835975-refletor-led-holofote-100w-slim-branco-frio-bivolt-ip66-_JM#position=27&amp;type=item&amp;tracking_id=be560c37-9282-4a6a-9521-582550356b55"> <span class="main-title"> Refletor Led Holofote 100w Slim Branco Frio Bivolt Ip66 </span> </a></h2> <div class="price__container"><div class="item__price"> <span class="price__symbol">R$</span> <span class="price__fraction">50</span> <span class="price__decimals">90</span></div> </div> <div class="item__stack_column highlighted"> <div class="item__stack_column__info"> <div class="stack_column_item installments highlighted"><span class="item-installments showInterest"> <span class="item-installments-multiplier"> 10x </span> <span class="item-installments-price"> R$ 5 <sup class="installment__decimals">78</sup> </span></span> </div> <div class="stack_column_item shipping highlighted"> <div class="item__shipping highlighted"> <p class="stack-item-info item--has-fulfillment"> </p> </div> </div> <div class="stack_column_item status"><div class="item__status"> <div class="item__condition"> 37445 vendidos </div></div> </div> </div> </div> <div class="stack_colum_right without-attributes without-reviews"> <div class="stack_column_right__bottom"> </div> </div> </div>,
# ...
#  <div class="item__info item--hide-right-col"><h2 class="item__title list-view-item-title"> <a class="item__info-title" href="https://produto.mercadolivre.com.br/MLB-1036167118-lampada-farol-led-h4-moto-carro-8000k-super-branca-_JM#position=45&amp;type=item&amp;tracking_id=be560c37-9282-4a6a-9521-582550356b55"> <span class="main-title"> Lampada Farol Led H4 Moto / Carro 8000k Super Branca </span> </a></h2> <div class="price__container"><div class="item__price"> <span class="price__symbol">R$</span> <span class="price__fraction">29</span> <span class="price__decimals">50</span></div> </div> <div class="item__stack_column highlighted"> <div class="item__stack_column__info"> <div class="stack_column_item installments highlighted"><span class="item-installments free-interest"> <span class="item-installments-multiplier"> 5x </span> <span class="item-installments-price"> R$ 5 <sup class="installment__decimals">90</sup> </span> <span class="item-installments-interest"> sem juros </span></span> </div> <div class="stack_column_item shipping highlighted"> <div class="item__shipping highlighted"> <p class="stack-item-info item--has-fulfillment"> </p> </div> </div> <div class="stack_column_item status"><div class="item__status"> <div class="item__condition"> 2912 vendidos </div></div> </div> </div> </div> <div class="stack_colum_right without-attributes without-reviews"> <div class="stack_column_right__bottom"> </div> </div> </div>,
#  <div class="item__info item--hide-right-col"><h2 class="item__title list-view-item-title"> <a class="item__info-title" href="https://produto.mercadolivre.com.br/MLB-1234098394-fita-led-rgb-5m-5050-pro-dagua-fonte-controle-16-cores-_JM#position=46&amp;type=item&amp;tracking_id=be560c37-9282-4a6a-9521-582550356b55"> <span class="main-title"> Fita Led Rgb 5m 5050 Pro D'agua + Fonte + Controle 16 Cores </span> </a></h2> <div class="price__container"><div class="item__price"> <span class="price__symbol">R$</span> <span class="price__fraction">31</span> <span class="price__decimals">99</span></div> </div> <div class="item__stack_column highlighted"> <div class="item__stack_column__info"> <div class="stack_column_item installments highlighted"><span class="item-installments showInterest"> <span class="item-installments-multiplier"> 6x </span> <span class="item-installments-price"> R$ 5 <sup class="installment__decimals">92</sup> </span></span> </div> <div class="stack_column_item status"><div class="item__status"> <div class="item__condition"> 1912 vendidos - São Paulo </div></div> </div> </div> </div> <div class="stack_colum_right without-attributes without-reviews"> <div class="stack_column_right__bottom"> </div> </div> </div>,
#  <div class="item__info item--hide-right-col"><h2 class="item__title list-view-item-title"> <a class="item__info-title" href="https://produto.mercadolivre.com.br/MLB-814170221-kit-10-lmpada-bulbo-super-led-16w-branco-frio-e27-bivolt-_JM#position=47&amp;type=item&amp;tracking_id=be560c37-9282-4a6a-9521-582550356b55"> <span class="main-title"> Kit 10 Lâmpada Bulbo Super Led 16w Branco Frio E27 Bivolt </span> </a></h2> <div class="price__container"> <span class="price-old" itemprop="price-old"> <del> R$ 118 </del> </span><div class="item__price item__price-discount"> <span class="price__symbol">R$</span> <span class="price__fraction">79</span> <span class="price__decimals">90</span></div> <div class="item__discount">32% OFF</div> </div> <div class="item__stack_column highlighted"> <div class="item__stack_column__info"> <div class="stack_column_item installments highlighted"><span class="item-installments showInterest"> <span class="item-installments-multiplier"> 12x </span> <span class="item-installments-price"> R$ 7 <sup class="installment__decimals">64</sup> </span></span> </div> <div class="stack_column_item shipping highlighted"> <div class="item__shipping highlighted"> <p class="stack-item-info item--has-fulfillment"> </p> </div> </div> <div class="stack_column_item status"><div class="item__status"> <div class="item__condition"> 14128 vendidos </div></div> </div> </div> </div> <div class="stack_colum_right without-attributes without-reviews"> <div class="stack_column_right__bottom"> </div> </div> </div>,
#  <div class="item__info item--hide-right-col"><h2 class="item__title list-view-item-title"> <a class="item__info-title" href="https://produto.mercadolivre.com.br/MLB-1065716799-refletor-led-50w-bivolt-brando-frio-6000k-economico-_JM#position=48&amp;type=item&amp;tracking_id=be560c37-9282-4a6a-9521-582550356b55"> <span class="main-title"> Refletor Led 50w Bivolt Brando Frio 6000k Economico </span> </a></h2> <div class="price__container"><div class="item__price"> <span class="price__symbol">R$</span> <span class="price__fraction">35</span> <span class="price__decimals">99</span></div> </div> <div class="item__stack_column highlighted"> <div class="item__stack_column__info"> <div class="stack_column_item installments highlighted"><span class="item-installments showInterest"> <span class="item-installments-multiplier"> 6x </span> <span class="item-installments-price"> R$ 6 <sup class="installment__decimals">66</sup> </span></span> </div> <div class="stack_column_item shipping highlighted"> <div class="item__shipping highlighted"> <p class="stack-item-info item--has-fulfillment"> </p> </div> </div> <div class="stack_column_item status"><div class="item__status"> <div class="item__condition"> 5168 vendidos </div></div> </div> </div> </div> <div class="stack_colum_right without-attributes without-reviews"> <div class="stack_column_right__bottom"> </div> </div> </div>,
#  <div class="item__info item--show-right-col"><h2 class="item__title list-view-item-title"> <a class="item__info-title" href="https://produto.mercadolivre.com.br/MLB-1231773789-fita-super-led-5050-branco-quentefrio-300-leds-5m-fonte-_JM#position=49&amp;type=item&amp;tracking_id=be560c37-9282-4a6a-9521-582550356b55"> <span class="main-title"> Fita Super Led 5050 Branco Quente/frio 300 Leds 5m + Fonte </span> </a></h2> <div class="price__container"><div class="item__price"> <span class="price__symbol">R$</span> <span class="price__fraction">24</span> <span class="price__decimals">99</span></div> </div> <div class="item__stack_column highlighted"> <div class="item__stack_column__info"> <div class="stack_column_item installments highlighted"><span class="item-installments showInterest"> <span class="item-installments-multiplier"> 4x </span> <span class="item-installments-price"> R$ 6 <sup class="installment__decimals">75</sup> </span></span> </div> <div class="stack_column_item status"><div class="item__status"> <div class="item__condition"> 1626 vendidos - São Paulo </div></div> </div> </div> </div> <div class="stack_colum_right without-attributes without-reviews"> <div class="stack_column_right__bottom item__has-variations"> <div class="variation-picker__container"> <div class="ui-dropdown custom"> <input autocomplete="off" class="dropdown-trigger variation-picker__trigger" hidden="" id="dropdown-variations-48" type="checkbox"/> <label class="ui-dropdown__link" for="dropdown-variations-48"> <span class="variation-picker__label">Cor: </span> <span class="ui-dropdown__display variation-picker__label variation-picker__label-bold">Branco Frio</span> <div class="ui-dropdown__indicator"></div> </label> <div class="ui-dropdown__content dropdown__variations-content variation-picker cursor-wait variation-picker__size-5" data-size="5"> <ul class="variation-picker__sekeleton"> <li class="attrBox skeleton__box--0 selected-option" id="44610673418"> <img class="variation-picker__img hidden" data-src="https://http2.mlstatic.com/D_Q_NP_744990-MLB32476136680_102019-S.jpg" height="36" title="Branco Frio" width="36"/></li> <li class="attrBox skeleton__box--1" id="44610673443"> <img class="variation-picker__img hidden" data-src="https://http2.mlstatic.com/D_Q_NP_656728-MLB32476111999_102019-S.jpg" height="36" title="Branco Quente" width="36"/></li> <li class="attrBox skeleton__box--2" id="44610673473"> <img class="variation-picker__img hidden" data-src="https://http2.mlstatic.com/D_Q_NP_710062-MLB32476150102_102019-S.jpg" height="36" title="Verde" width="36"/></li> <li class="attrBox skeleton__box--3" id="44610673500"> <img class="variation-picker__img hidden" data-src="https://http2.mlstatic.com/D_Q_NP_867945-MLB32476133839_102019-S.jpg" height="36" title="Vermelho" width="36"/></li> <li class="attrBox skeleton__box--4" id="44610673526"> <img class="variation-picker__img hidden" data-src="https://http2.mlstatic.com/D_Q_NP_665926-MLB32476133892_102019-S.jpg" height="36" title="Azul" width="36"/></li></ul> </div> </div> </div> </div> </div> </div>,
#  <div class="item__info item--hide-right-col"><h2 class="item__title list-view-item-title"> <a class="item__info-title" href="https://produto.mercadolivre.com.br/MLB-1186692441-monitor-lg-led-195-lg-20m37aa-1366-x-768-vesa-frete-gratis-_JM#position=50&amp;type=item&amp;tracking_id=be560c37-9282-4a6a-9521-582550356b55"> <span class="main-title"> Monitor Lg Led 19,5 Lg 20m37aa 1366 X 768 Vesa Frete Gratis </span> </a></h2> <div class="price__container"><div class="item__price"> <span class="price__symbol">R$</span> <span class="price__fraction">342</span> <span class="price__decimals">95</span></div> </div> <div class="item__stack_column highlighted"> <div class="item__stack_column__info"> <div class="stack_column_item installments highlighted"><span class="item-installments free-interest"> <span class="item-installments-multiplier"> 12x </span> <span class="item-installments-price"> R$ 28 <sup class="installment__decimals">58</sup> </span> <span class="item-installments-interest"> sem juros </span></span> </div> <div class="stack_column_item shipping highlighted"> <div class="item__shipping free-shipping highlighted"> <p class="stack-item-info item--has-fulfillment"> Frete grátis</p> </div> </div> <div class="stack_column_item status"><div class="item__status"> <div class="item__condition"> 3342 vendidos </div></div> </div> </div> </div> <div class="stack_colum_right without-attributes without-reviews"> <div class="stack_column_right__bottom"> </div> </div> </div>,
#  <div class="item__info item--hide-right-col"><h2 class="item__title list-view-item-title"> <a class="item__info-title" href="https://produto.mercadolivre.com.br/MLB-859279473-kit-lampada-led-automotiva-ultra-led-shock-light-encaixe-h11-_JM#position=51&amp;type=item&amp;tracking_id=be560c37-9282-4a6a-9521-582550356b55"> <span class="main-title"> Kit Lampada Led Automotiva Ultra Led Shock Light Encaixe H11 </span> </a> <div class="item__brand"> <a class="item__brand-link" href="https://loja.mercadolivre.com.br/auto-equip"> <span class="item__brand-title-tos"> por Auto Equip </span> </a> </div></h2> <div class="price__container"> <span class="price-old" itemprop="price-old"> <del> R$ 159 </del> </span><div class="item__price item__price-discount"> <span class="price__symbol">R$</span> <span class="price__fraction">138</span> <span class="price__decimals">90</span></div> <div class="item__discount">13% OFF</div> </div> <div class="item__stack_column highlighted"> <div class="item__stack_column__info"> <div class="stack_column_item installments highlighted"><span class="item-installments free-interest"> <span class="item-installments-multiplier"> 12x </span> <span class="item-installments-price"> R$ 11 <sup class="installment__decimals">58</sup> </span> <span class="item-installments-interest"> sem juros </span></span> </div> <div class="stack_column_item shipping highlighted"> <div class="item__shipping free-shipping highlighted"> <p class="stack-item-info item--has-fulfillment"> Frete grátis</p> </div> </div> <div class="stack_column_item status"><div class="item__status"> <div class="item__condition"> 658 vendidos </div></div> </div> </div> </div> <div class="stack_colum_right without-attributes without-reviews"> <div class="stack_column_right__bottom"> </div> </div> </div>,
#  <div class="item__info item--hide-right-col"><h2 class="item__title list-view-item-title"> <a class="item__info-title" href="https://produto.mercadolivre.com.br/MLB-1232169157-smart-tv-32-samsung-un32j4290ag-conversor-2hdmi-1usb-wifi-_JM#position=52&amp;type=item&amp;tracking_id=be560c37-9282-4a6a-9521-582550356b55"> <span class="main-title"> Smart Tv 32 Samsung Un32j4290ag Conversor 2hdmi 1usb Wifi </span> </a> <div class="item__brand"> <a class="item__brand-link" href="https://loja.mercadolivre.com.br/mm-santos"> <span class="item__brand-title-tos"> por Mm Santos </span> </a> </div></h2> <div class="price__container"> <span class="price-old" itemprop="price-old"> <del> R$ 1.249 </del> </span><div class="item__price item__price-discount"> <span class="price__symbol">R$</span> <span class="price__fraction">899</span></div> <div class="item__discount">28% OFF</div> </div> <div class="item__stack_column highlighted"> <div class="item__stack_column__info"> <div class="stack_column_item installments highlighted"><span class="item-installments free-interest"> <span class="item-installments-multiplier"> 12x </span> <span class="item-installments-price"> R$ 74 <sup class="installment__decimals">92</sup> </span> <span class="item-installments-interest"> sem juros </span></span> </div> <div class="stack_column_item shipping highlighted"> <div class="item__shipping free-shipping highlighted"> <p class="stack-item-info item--has-fulfillment"> Frete grátis</p> </div> </div> <div class="stack_column_item status"><div class="item__status"> <div class="item__condition"> 2467 vendidos </div></div> </div> </div> </div> <div class="stack_colum_right without-attributes without-reviews"> <div class="stack_column_right__bottom"> </div> </div> </div>,
#  <div class="item__info item--hide-right-col"><h2 class="item__title list-view-item-title"> <a class="item__info-title" href="https://produto.mercadolivre.com.br/MLB-1274302549-smart-tv-32-aoc-32s5295-hd-c-conversor-3-hdmi-1-usb-wifi-_JM#position=53&amp;type=item&amp;tracking_id=be560c37-9282-4a6a-9521-582550356b55"> <span class="main-title"> Smart Tv 32 Aoc 32s5295 Hd C Conversor 3 Hdmi 1 Usb Wifi </span> </a> <div class="item__brand"> <a class="item__brand-link" href="https://loja.mercadolivre.com.br/mm-santos"> <span class="item__brand-title-tos"> por Mm Santos </span> </a> </div></h2> <div class="price__container"> <span class="price-old" itemprop="price-old"> <del> R$ 1.299 </del> </span><div class="item__price item__price-discount"> <span class="price__symbol">R$</span> <span class="price__fraction">899</span></div> <div class="item__discount">30% OFF</div> </div> <div class="item__stack_column highlighted"> <div class="item__stack_column__info"> <div class="stack_column_item installments highlighted"><span class="item-installments free-interest"> <span class="item-installments-multiplier"> 12x </span> <span class="item-installments-price"> R$ 74 <sup class="installment__decimals">92</sup> </span> <span class="item-installments-interest"> sem juros </span></span> </div> <div class="stack_column_item shipping highlighted"> <div class="item__shipping free-shipping highlighted"> <p class="stack-item-info item--has-fulfillment"> Frete grátis</p> </div> </div> <div class="stack_column_item status"><div class="item__status"> <div class="item__condition"> 1363 vendidos </div></div> </div> </div> </div> <div class="stack_colum_right without-attributes without-reviews"> <div class="stack_column_right__bottom"> </div> </div> </div>]

# %%
items[0]
# Out:
# <div class="item__info item--hide-right-col"><h2 class="item__title list-view-item-title"> <a class="item__info-title" href="https://produto.mercadolivre.com.br/MLB-687925636-holofote-refletor-super-led-duplo-100w-bivolt-bco-frio-_JM#position=1&amp;type=item&amp;tracking_id=be560c37-9282-4a6a-9521-582550356b55"> <span class="main-title"> Holofote Refletor Super Led Duplo 100w Bivolt - Bco Frio </span> </a> <div class="item__brand"> <a class="item__brand-link" href="https://loja.mercadolivre.com.br/coruja-mix"> <span class="item__brand-title-tos"> por Coruja Mix </span> </a> </div></h2> <div class="price__container"><div class="item__price"> <span class="price__symbol">R$</span> <span class="price__fraction">52</span> <span class="price__decimals">90</span></div> </div> <div class="item__stack_column highlighted"> <div class="item__stack_column__info"> <div class="stack_column_item installments highlighted"><span class="item-installments showInterest"> <span class="item-installments-multiplier"> 10x </span> <span class="item-installments-price"> R$ 6 <sup class="installment__decimals">01</sup> </span></span> </div> <div class="stack_column_item shipping highlighted"> <div class="item__shipping highlighted"> <p class="stack-item-info item--has-fulfillment"> </p> </div> </div> <div class="stack_column_item status"><div class="item__status"> <div class="item__condition"> 9171 vendidos </div></div> </div> </div> </div> <div class="stack_colum_right without-attributes without-reviews"> <div class="stack_column_right__bottom"> </div> </div> </div>

# %%
items[0].find('span', {'class':'main-title'})
# Out:
# <span class="main-title"> Holofote Refletor Super Led Duplo 100w Bivolt - Bco Frio </span>

# %%
class ItemML():
    def __init__(self, nome, fraction, decimal):
        self.nome = nome
        self.fraction = fraction
        self.decimal = decimal
    
    def __repr__(self):
        return f'{self.nome}, preço: R${self.fraction},{self.decimal}'

items = soup.find_all('div', {'class':'item__info'})
ml_items = []
for item in items:
    nome = item.find('span', {'class':'main-title'}).text
    fraction = item.find('span', {'class': 'price__fraction'}).text
    decimal = item.find('span', {'class': 'price__decimals'})
    if decimal is None:
        decimal = '00'
    else:
        decimal = decimal.text
    
    ml_items.append(ItemML(nome, fraction, decimal))

# %%
ml_items
# Out:
# [ Holofote Refletor Super Led Duplo 100w Bivolt - Bco Frio , preço: R$52,90,
#   Lustre Luminária Redondo Pendente De Madeira De E-27 21x18cm , preço: R$54,99,
#   Fita Led 3528 Rolo 5m 300 Leds Sanca Teto Dupla Face 3m , preço: R$18,90,
#   Par Barra Led Super Farol Drl Luz Diurna 12v Carro Moto 17cm , preço: R$16,85,
#   Fita Led 5m Rgb 16 Cores 5050 Pro D'agua + Fonte + Controle , preço: R$38,45,
#   Mangueira Led Alto Brilho Decoração Sanca Gesso E Marcenaria , preço: R$16,78,
#   Fita Led Digital 6803 Rgb C/ Controle 133 Efeitos Ip67 5050 , preço: R$56,90,
#   Lustre Luminária Redondo Pendente De Madeira De E-27 21x18cm , preço: R$54,99,
#   Fita Led 3528 Rolo 5m 300 Leds Várias Cores Prova Dágua - Sf , preço: R$17,50,
#   Kit Lâmpadas Ultra Led Full 7600l Efeito Xenon Super Branca , preço: R$45,99,
#   C6 Lampada Led Automotiva H1/h3/h4/h7/hb3/hb4/h27 Xenon , preço: R$39,99,
#   Fita Led 5 Metros Silicone Prova Dagua Diversas Cores 12v , preço: R$16,49,
#   Fita Led 5m Ultra Rgb 5050 Prova D'agua + Controle + Fonte , preço: R$39,90,
#   Mangueira Led Alto Brilho Decoração Sanca Gesso E Marcenaria , preço: R$16,78,
#   Lampada Bluetooth Led Rgb Branco Caixa Som Musical Bulbo , preço: R$30,99,
#   Fita Led Digital Cor 6803 Rgb 133 Efeitos+controle , preço: R$52,99,
#   Fita Led 5m Rgb 16 Cores 5050 Prova D'agua + Fonte+ Controle , preço: R$32,33,
#   Fita Super Led 5050 Branco Frio 300 Leds 5m + Fonte Grátis , preço: R$36,90,
#   Arandela 2 Focos E Frisos Externa Parede Muro St327 , preço: R$29,90,
#   Kit 2 Lampada Led H1 H3 H4 H7 Hb3 Hb4 H11 Branca , preço: R$34,99,
#   Fita Led 5m Ultra Rgb 3528 Prova D'agua + Controle + Fonte , preço: R$24,89,
#   Luminária Luz Solar Spot Super Led Grama Jardim Promoção , preço: R$39,80,
#   Kit 20 Spot Super Led 3w Branco Frio Embutir Gesso Sanca , preço: R$119,90,
#   Kit 4 Farol Milha Redondo 42w 12v/24v 14 Leds Carro Jeep , preço: R$159,99,
#   Kit Super Led Plus Ultra Cinoy 12000 Lumens 12v 24v H1 H3 H7 H11 Hb3 Hb4 , preço: R$129,99,
#   Fita Led Digital 6803 Rgb Com Controle 328 Efeitos 3 Vias , preço: R$59,00,
#   Refletor Led Holofote 100w Slim Branco Frio Bivolt Ip66 , preço: R$50,90,
#   Kit 2 Lampada Led H1 H3 H4 H7 Hb3 Hb4 H11 Branca , preço: R$34,99,
#   Fita Led 3528 Rolo 5m 300 Led Vária Cor Prova Dágua Fonte 2a , preço: R$22,88,
#   Par Farol Milha Universal Led U5 Auxiliar Moto 12v , preço: R$61,05,
#   Lampada Philips Pingo Led Ultinon 6000k W5w T10 Super Branc , preço: R$37,50,
#   Fita Led Rolo 5m 5050 Branco Frio Dupla Face A Prova D'agua , preço: R$26,99,
#   Smart Tv Led 32 Samsung Lh32benelga 2 Hdmi 1 Usb Wifi , preço: R$879,00,
#   Balizador Luminária Led Chão Piso 3w Blindado Branco Quente , preço: R$35,90,
#   Fita Led 5050 Rolo 5m 300 Leds Dupla Face 3m Frete Barato , preço: R$21,90,
#   Smart Tv 43 Samsung Un43j5290a Fhd Conversor 2 Hdmi 1 Usb , preço: R$1.349,00,
#   Balizador Luminária Led Chão Piso 7w Embutir Blindado Fita , preço: R$44,90,
#   Smart Tv 58 Polegadas Samsung 58ru7100 Uhd 4k 3hdmi 2usb , preço: R$2.649,00,
#   Painel Plafon 25w Led Quadrado Sobrepor Branco Frio Teto , preço: R$34,90,
#   Painel Plafon Led 18w Quadrado Embutir Branco Frio Luminária , preço: R$22,90,
#   Fita Super Led 5050 Branco Quente/frio 300 Leds 5m + Fonte , preço: R$24,99,
#   Refletor Led 30w Bivol Holofote Brando Frio A Prova D'água , preço: R$27,99,
#   Fita Led Rolo 5m 300 Leds 5050 Prova D'água , preço: R$21,81,
#   Farol Led Milha Redondo 27w Troller Jeep 12v 24v Off Road , preço: R$21,49,
#   Lampada Farol Led H4 Moto / Carro 8000k Super Branca , preço: R$29,50,
#   Fita Led Rgb 5m 5050 Pro D'agua + Fonte + Controle 16 Cores , preço: R$31,99,
#   Kit 10 Lâmpada Bulbo Super Led 16w Branco Frio E27 Bivolt , preço: R$79,90,
#   Refletor Led 50w Bivolt Brando Frio 6000k Economico , preço: R$35,99,
#   Fita Super Led 5050 Branco Quente/frio 300 Leds 5m + Fonte , preço: R$24,99,
#   Monitor Lg Led 19,5 Lg 20m37aa 1366 X 768 Vesa Frete Gratis , preço: R$342,95,
#   Kit Lampada Led Automotiva Ultra Led Shock Light Encaixe H11 , preço: R$138,90,
#   Smart Tv 32 Samsung Un32j4290ag Conversor 2hdmi 1usb Wifi , preço: R$899,00,
#   Smart Tv 32 Aoc 32s5295 Hd C Conversor 3 Hdmi 1 Usb Wifi , preço: R$899,00]

# %%
next_button = soup.find('li', {'class': 'andes-pagination__button--next'})

# %%
next_button.find('a')['href']
# Out:
# 'https://lista.mercadolivre.com.br/led_Desde_51'

# %% [markdown]
# ## Training Zone

# %% [markdown]
# 1. Acesse o link da wikipedia sobre HTML (https://en.wikipedia.org/wiki/HTML) e faça um script python que retorne a tabela do índice do conteúdo da página, como abaixo:
#
#     `1. History (https://en.wikipedia.org/wiki/HTML#History)
#     1.1 Development (https://en.wikipedia.org/wiki/HTML#Development)
#     1.2 HTML versions timeline (https://en.wikipedia.org/wiki/HTML#HTML_versions_timeline)
#     ...`

# %%
import requests
from bs4 import BeautifulSoup

wikipedia = []

# Buscando a página 
page = requests.get('https://en.wikipedia.org/wiki/HTML')
# Criar o objeto BeautifulSoup
soup = BeautifulSoup(page.text, 'html.parser')

# %% [markdown]
# 2. Transforme o seu código acima em uma classe, WikiPage, com o método `get_content_table`, que retorne o que você fez anteriormente
